# %%
# stored here just for reference. 
# those are the scripts that I used to runn all past models.
# their run history and checkpoints can be found in checkpoints dir.

# %% [markdown]
# ### runs

# %%
import datetime
from torch.utils.tensorboard import SummaryWriter

# Setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
domains = df['domain'].unique()
domain_to_idx = {d: i for i, d in enumerate(domains)}

# # For baseline model
# baseline_model = LGRBaseline().to(device)
# optimizer = torch.optim.Adam(baseline_model.parameters(), lr=1e-3)
# buffer = NaiveRehearsalBuffer(buffer_size=1000)
# exp_name = f"baselinemodel_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
# writer = SummaryWriter(log_dir=f"../tensorboard/{exp_name}")

# baseline_kwargs = {'mse_criterion': nn.MSELoss()}
# unified_train_loop(
#     model=baseline_model,
#     domains=domains,
#     domain_dataloaders=domain_dataloaders,
#     buffer=buffer,
#     optimizer=optimizer,
#     writer=writer,
#     device=device,
#     batch_fn=baseline_batch,
#     batch_kwargs=baseline_kwargs,
#     num_epochs=10,
#     exp_name=exp_name
# )

# For DualBranchNet
dual_model = DualBranchNet(num_domains=len(domains)).to(device)
optimizer = torch.optim.Adam(dual_model.parameters(), lr=1e-3)
buffer = NaiveRehearsalBuffer(buffer_size=1000)

def cos_criterion(a, b):
    return (1 - torch.abs(nn.CosineSimilarity()(a, b))).mean()
    # return (nn.CosineSimilarity()(a, b) ** 2).mean()

exp_name = f"nores_dualbranchmodel_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
writer = SummaryWriter(log_dir=f"../tensorboard/{exp_name}")

dualbranch_kwargs = {
    'mse_criterion': nn.MSELoss(),
    'ce_criterion': nn.CrossEntropyLoss(),
    'cos_criterion': cos_criterion,
    'domain_to_idx': domain_to_idx
}
unified_train_loop(
    model=dual_model,
    domains=domains,
    domain_dataloaders=domain_dataloaders,
    buffer=buffer,
    optimizer=optimizer,
    writer=writer,
    device=device,
    batch_fn=dualbranch_batch,
    batch_kwargs=dualbranch_kwargs,
    num_epochs=10,
    exp_name=exp_name,
    gradient_clipping=False
)


# For DualBranchNet
dual_model = DualBranchNet(num_domains=len(domains)).to(device)
optimizer = torch.optim.Adam(dual_model.parameters(), lr=1e-3)
buffer = NaiveRehearsalBuffer(buffer_size=1000)

def cos_criterion(a, b):
    return (1 - torch.abs(nn.CosineSimilarity()(a, b))).mean()
    # return (nn.CosineSimilarity()(a, b) ** 2).mean()

exp_name = f"nores_gradclip_dualbranchmodel_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
writer = SummaryWriter(log_dir=f"../tensorboard/{exp_name}")

dualbranch_kwargs = {
    'mse_criterion': nn.MSELoss(),
    'ce_criterion': nn.CrossEntropyLoss(),
    'cos_criterion': cos_criterion,
    'domain_to_idx': domain_to_idx
}
unified_train_loop(
    model=dual_model,
    domains=domains,
    domain_dataloaders=domain_dataloaders,
    buffer=buffer,
    optimizer=optimizer,
    writer=writer,
    device=device,
    batch_fn=dualbranch_batch,
    batch_kwargs=dualbranch_kwargs,
    num_epochs=10,
    exp_name=exp_name,
    gradient_clipping=True
)

# For DualBranchNet
dual_model = DualBranchNet(weights_init=True, weights_norm=True).to(device)
optimizer = torch.optim.Adam(dual_model.parameters(), lr=1e-3)
buffer = NaiveRehearsalBuffer(buffer_size=1000)

def cos_criterion(a, b):
    return (1 - torch.abs(nn.CosineSimilarity()(a, b))).mean()
    # return (nn.CosineSimilarity()(a, b) ** 2).mean()

exp_name = f"nores_winit_wnorm_dualbranchmodel_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
writer = SummaryWriter(log_dir=f"../tensorboard/{exp_name}")

dualbranch_kwargs = {
    'mse_criterion': nn.MSELoss(),
    'ce_criterion': nn.CrossEntropyLoss(),
    'cos_criterion': cos_criterion,
    'domain_to_idx': domain_to_idx
}
unified_train_loop(
    model=dual_model,
    domains=domains,
    domain_dataloaders=domain_dataloaders,
    buffer=buffer,
    optimizer=optimizer,
    writer=writer,
    device=device,
    batch_fn=dualbranch_batch,
    batch_kwargs=dualbranch_kwargs,
    num_epochs=10,
    exp_name=exp_name,
    gradient_clipping=False
)

# For DualBranchNet
dual_model = DualBranchNet(weights_init=True, weights_norm=True).to(device)
optimizer = torch.optim.Adam(dual_model.parameters(), lr=1e-3)
buffer = NaiveRehearsalBuffer(buffer_size=1000)

def cos_criterion(a, b):
    return (1 - torch.abs(nn.CosineSimilarity()(a, b))).mean()
    # return (nn.CosineSimilarity()(a, b) ** 2).mean()

exp_name = f"nores_gradclip_winit_wnorm_dualbranchmodel_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
writer = SummaryWriter(log_dir=f"../tensorboard/{exp_name}")

dualbranch_kwargs = {
    'mse_criterion': nn.MSELoss(),
    'ce_criterion': nn.CrossEntropyLoss(),
    'cos_criterion': cos_criterion,
    'domain_to_idx': domain_to_idx
}
unified_train_loop(
    model=dual_model,
    domains=domains,
    domain_dataloaders=domain_dataloaders,
    buffer=buffer,
    optimizer=optimizer,
    writer=writer,
    device=device,
    batch_fn=dualbranch_batch,
    batch_kwargs=dualbranch_kwargs,
    num_epochs=10,
    exp_name=exp_name,
    gradient_clipping = True
)

# %%
import datetime
from torch.utils.tensorboard import SummaryWriter

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
domains = df['domain'].unique()
domain_to_idx = {d: i for i, d in enumerate(domains)}

dual_model = DualBranchNet_deep(weights_init=True, weights_norm=False).to(device)
optimizer = torch.optim.Adam(dual_model.parameters(), lr=1e-3)
buffer = NaiveRehearsalBuffer(buffer_size=1000)

def cos_criterion(a, b):
    return (1 - torch.abs(nn.CosineSimilarity()(a, b))).mean()
    # return (nn.CosineSimilarity()(a, b) ** 2).mean()

exp_name = f"deep_dualbranchmodel_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
writer = SummaryWriter(log_dir=f"../tensorboard/{exp_name}")

dualbranch_kwargs = {
    'mse_criterion': nn.MSELoss(),
    'ce_criterion': nn.CrossEntropyLoss(),
    'cos_criterion': cos_criterion,
    'domain_to_idx': domain_to_idx
}
unified_train_loop(
    model=dual_model,
    domains=domains,
    domain_dataloaders=domain_dataloaders,
    buffer=buffer,
    optimizer=optimizer,
    writer=writer,
    device=device,
    batch_fn=dualbranch_batch,
    batch_kwargs=dualbranch_kwargs,
    num_epochs=10,
    exp_name=exp_name,
    gradient_clipping=True
)


dual_model = DualBranchNet_deep(weights_init=True, weights_norm=True).to(device)
optimizer = torch.optim.Adam(dual_model.parameters(), lr=1e-3)
buffer = NaiveRehearsalBuffer(buffer_size=1000)

def cos_criterion(a, b):
    return (1 - torch.abs(nn.CosineSimilarity()(a, b))).mean()
    # return (nn.CosineSimilarity()(a, b) ** 2).mean()

exp_name = f"deep_norm_dualbranchmodel_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
writer = SummaryWriter(log_dir=f"../tensorboard/{exp_name}")

dualbranch_kwargs = {
    'mse_criterion': nn.MSELoss(),
    'ce_criterion': nn.CrossEntropyLoss(),
    'cos_criterion': cos_criterion,
    'domain_to_idx': domain_to_idx
}
unified_train_loop(
    model=dual_model,
    domains=domains,
    domain_dataloaders=domain_dataloaders,
    buffer=buffer,
    optimizer=optimizer,
    writer=writer,
    device=device,
    batch_fn=dualbranch_batch,
    batch_kwargs=dualbranch_kwargs,
    num_epochs=10,
    exp_name=exp_name,
    gradient_clipping=True
)

# %%
import datetime
from torch.utils.tensorboard import SummaryWriter

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
domains = df['domain'].unique()
domain_to_idx = {d: i for i, d in enumerate(domains)}

dual_model = DualBranchNet_deep(weights_init=False, weights_norm=False, layer_norm=False, detach_base=True).to(device)
optimizer = torch.optim.Adam(dual_model.parameters(), lr=1e-3)
buffer = NaiveRehearsalBuffer(buffer_size=1000)

def cos_criterion(a, b):
    return (1 - torch.abs(nn.CosineSimilarity()(a, b))).mean()
    # return (nn.CosineSimilarity()(a, b) ** 2).mean()

exp_name = f"bbdetach_deep_dualbranchmodel_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
writer = SummaryWriter(log_dir=f"../tensorboard/{exp_name}")

dualbranch_kwargs = {
    'mse_criterion': nn.MSELoss(),
    'ce_criterion': nn.CrossEntropyLoss(),
    'cos_criterion': cos_criterion,
    'domain_to_idx': domain_to_idx
}
unified_train_loop(
    model=dual_model,
    domains=domains,
    domain_dataloaders=domain_dataloaders,
    buffer=buffer,
    optimizer=optimizer,
    writer=writer,
    device=device,
    batch_fn=dualbranch_batch,
    batch_kwargs=dualbranch_kwargs,
    num_epochs=10,
    exp_name=exp_name,
    gradient_clipping=True
)

# %%
import datetime
from torch.utils.tensorboard import SummaryWriter

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
domains = df['domain'].unique()
domain_to_idx = {d: i for i, d in enumerate(domains)}

dual_model = DualBranchNet_deep(weights_init=True, weights_norm=False, layer_norm=False, detach_base=True).to(device)
optimizer = torch.optim.Adam(dual_model.parameters(), lr=1e-3)
buffer = NaiveRehearsalBuffer(buffer_size=1000)

def cos_criterion(a, b):
    return (1 - torch.abs(nn.CosineSimilarity()(a, b))).mean()
    # return (nn.CosineSimilarity()(a, b) ** 2).mean()

exp_name = f"bdetach_batch16_dualbranchmodel_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
writer = SummaryWriter(log_dir=f"../tensorboard/{exp_name}")

dualbranch_kwargs = {
    'mse_criterion': nn.MSELoss(),
    'ce_criterion': nn.CrossEntropyLoss(),
    'cos_criterion': cos_criterion,
    'domain_to_idx': domain_to_idx
}

domain_dataloaders = {}
for domain in domains:
    domain_df = df[df['domain'] == domain]
    loaders = create_dataloaders(domain_df, batch_sizes=(16, 64, 64), resize_img_to=(128, 128), seed=SEED)  #TODO should be (384, 216) to retain scale or (224, 224) for best performance on MobileNet
    domain_dataloaders[domain] = loaders

unified_train_loop(
    model=dual_model,
    domains=domains,
    domain_dataloaders=domain_dataloaders,
    buffer=buffer,
    optimizer=optimizer,
    writer=writer,
    device=device,
    batch_fn=dualbranch_batch,
    batch_kwargs=dualbranch_kwargs,
    num_epochs=10,
    exp_name=exp_name,
    gradient_clipping=True,
    detach_base=True
)

domain_dataloaders = {}
for domain in domains:
    domain_df = df[df['domain'] == domain]
    loaders = create_dataloaders(domain_df, batch_sizes=(32, 64, 64), resize_img_to=(128, 128), seed=SEED)  #TODO should be (384, 216) to retain scale or (224, 224) for best performance on MobileNet
    domain_dataloaders[domain] = loaders


dual_model = DualBranchNet_deep(weights_init=False, weights_norm=False, layer_norm=False, detach_base=True, freeze_base='partial').to(device)
optimizer = torch.optim.Adam(dual_model.parameters(), lr=1e-3)
buffer = NaiveRehearsalBuffer(buffer_size=1000)

def cos_criterion(a, b):
    return (1 - torch.abs(nn.CosineSimilarity()(a, b))).mean()
    # return (nn.CosineSimilarity()(a, b) ** 2).mean()

exp_name = f"bdetach_pfrozen_dualbranchmodel_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
writer = SummaryWriter(log_dir=f"../tensorboard/{exp_name}")

dualbranch_kwargs = {
    'mse_criterion': nn.MSELoss(),
    'ce_criterion': nn.CrossEntropyLoss(),
    'cos_criterion': cos_criterion,
    'domain_to_idx': domain_to_idx
}
unified_train_loop(
    model=dual_model,
    domains=domains,
    domain_dataloaders=domain_dataloaders,
    buffer=buffer,
    optimizer=optimizer,
    writer=writer,
    device=device,
    batch_fn=dualbranch_batch,
    batch_kwargs=dualbranch_kwargs,
    num_epochs=10,
    exp_name=exp_name,
    gradient_clipping=True,
    detach_base=True
)

dual_model = DualBranchNet_deep(weights_init=False, weights_norm=False, layer_norm=False, detach_base=False, freeze_base='full').to(device)
optimizer = torch.optim.Adam(dual_model.parameters(), lr=1e-3)
buffer = NaiveRehearsalBuffer(buffer_size=1000)

def cos_criterion(a, b):
    return (1 - torch.abs(nn.CosineSimilarity()(a, b))).mean()
    # return (nn.CosineSimilarity()(a, b) ** 2).mean()

exp_name = f"ffrozen_dualbranchmodel_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
writer = SummaryWriter(log_dir=f"../tensorboard/{exp_name}")

dualbranch_kwargs = {
    'mse_criterion': nn.MSELoss(),
    'ce_criterion': nn.CrossEntropyLoss(),
    'cos_criterion': cos_criterion,
    'domain_to_idx': domain_to_idx
}
unified_train_loop(
    model=dual_model,
    domains=domains,
    domain_dataloaders=domain_dataloaders,
    buffer=buffer,
    optimizer=optimizer,
    writer=writer,
    device=device,
    batch_fn=dualbranch_batch,
    batch_kwargs=dualbranch_kwargs,
    num_epochs=10,
    exp_name=exp_name,
    gradient_clipping=True,
    detach_base=False
)

# %%
import datetime
from torch.utils.tensorboard import SummaryWriter

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
domains = df['domain'].unique()
domain_to_idx = {d: i for i, d in enumerate(domains)}

dual_model = DualBranchNet_binary(weights_init=False, weights_norm=False, layer_norm=False, detach_base=False, freeze_base='full', explicit_grl=False).to(device)
optimizer = torch.optim.Adam(dual_model.parameters(), lr=1e-3)
buffer = NaiveRehearsalBuffer(buffer_size=1000)

def cos_criterion(a, b):
    return (1 - torch.abs(nn.CosineSimilarity()(a, b))).mean()
    # return (nn.CosineSimilarity()(a, b) ** 2).mean()

exp_name = f"ffrozen_binary_dualbranchmodel_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
writer = SummaryWriter(log_dir=f"../tensorboard/{exp_name}")

dualbranch_kwargs = {
    'mse_criterion': nn.MSELoss(),
    'ce_criterion': nn.CrossEntropyLoss(),
    'cos_criterion': cos_criterion,
    'domain_to_idx': domain_to_idx,
    'bce_criterion': nn.BCEWithLogitsLoss()
}
unified_train_loop(
    model=dual_model,
    domains=domains,
    domain_dataloaders=domain_dataloaders,
    buffer=buffer,
    optimizer=optimizer,
    writer=writer,
    device=device,
    batch_fn=dualbranch_batch,
    batch_kwargs=dualbranch_kwargs,
    num_epochs=10,
    exp_name=exp_name,
    gradient_clipping=True,
    detach_base=False,
    binary = True,
    full_replay = False
)

dual_model = DualBranchNet_binary(weights_init=False, weights_norm=False, layer_norm=False, detach_base=False, freeze_base='full', explicit_grl=False).to(device)
optimizer = torch.optim.Adam(dual_model.parameters(), lr=1e-3)
buffer = NaiveRehearsalBuffer(buffer_size=1000)

def cos_criterion(a, b):
    return (1 - torch.abs(nn.CosineSimilarity()(a, b))).mean()
    # return (nn.CosineSimilarity()(a, b) ** 2).mean()

exp_name = f"ffrozen_binary_explicitgrl_dualbranchmodel_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
writer = SummaryWriter(log_dir=f"../tensorboard/{exp_name}")

dualbranch_kwargs = {
    'mse_criterion': nn.MSELoss(),
    'ce_criterion': nn.CrossEntropyLoss(),
    'cos_criterion': cos_criterion,
    'domain_to_idx': domain_to_idx,
    'bce_criterion': nn.BCEWithLogitsLoss()
}
unified_train_loop(
    model=dual_model,
    domains=domains,
    domain_dataloaders=domain_dataloaders,
    buffer=buffer,
    optimizer=optimizer,
    writer=writer,
    device=device,
    batch_fn=dualbranch_batch,
    batch_kwargs=dualbranch_kwargs,
    num_epochs=10,
    exp_name=exp_name,
    gradient_clipping=True,
    detach_base=False,
    binary=True,
    full_replay = False
)


dual_model = DualBranchNet_binary(weights_init=True, weights_norm=False, layer_norm=False, detach_base=False, freeze_base='full', explicit_grl=True).to(device)
optimizer = torch.optim.Adam(dual_model.parameters(), lr=1e-3)
buffer = NaiveRehearsalBuffer(buffer_size=1000)

def cos_criterion(a, b):
    return (1 - torch.abs(nn.CosineSimilarity()(a, b))).mean()
    # return (nn.CosineSimilarity()(a, b) ** 2).mean()

exp_name = f"freplay_ffrozen_binary_explicitgrl_dualbranchmodel_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
writer = SummaryWriter(log_dir=f"../tensorboard/{exp_name}")

dualbranch_kwargs = {
    'mse_criterion': nn.MSELoss(),
    'ce_criterion': nn.CrossEntropyLoss(),
    'cos_criterion': cos_criterion,
    'domain_to_idx': domain_to_idx,
    'bce_criterion': nn.BCEWithLogitsLoss()
}
unified_train_loop(
    model=dual_model,
    domains=domains,
    domain_dataloaders=domain_dataloaders,
    buffer=buffer,
    optimizer=optimizer,
    writer=writer,
    device=device,
    batch_fn=dualbranch_batch,
    batch_kwargs=dualbranch_kwargs,
    num_epochs=10,
    exp_name=exp_name,
    gradient_clipping=True,
    detach_base=False,
    binary=True,
    full_replay = True
)

# %%
from itertools import product
import datetime
from torch.utils.tensorboard import SummaryWriter

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
domains = df['domain'].unique()
domain_to_idx = {d: i for i, d in enumerate(domains)}

testing_scenarios = {
    # 'pretrained_backbone_cnn_branch': ('pretrained', 'simple', 'simple'), 
    # 'linear_branch': ('3conv', 'linear', 'simple'),
    # 'cnn_branch': ('3conv', 'simple', 'simple'),
    # 'adversarial': ('2conv', 'adversarial', 'adversarial'),
    'cnn_specialised_branches': ('3conv', 'special', 'simple')
}

for name, (backbone, branch, end) in testing_scenarios.items():
    print(f"\nTesting: {backbone} + {branch} + {end}")
    dual_model = DualBranchCNNNet(backbone_type=backbone, branch_type=branch, end_type=end, batch_norm=True).to(device)
    optimizer = torch.optim.Adam(dual_model.parameters(), lr=1e-3)
    buffer = NaiveRehearsalBuffer(buffer_size=1000)

    def cos_criterion(a, b):
        return (1 - torch.abs(nn.CosineSimilarity()(a, b))).mean()

    exp_name = f"CNN_{name}_dualbranchmodel_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
    writer = SummaryWriter(log_dir=f"../tensorboard/{exp_name}")

    dualbranch_kwargs = {
        'mse_criterion': nn.MSELoss(),
        'ce_criterion': nn.CrossEntropyLoss(),
        'cos_criterion': cos_criterion,
        'domain_to_idx': domain_to_idx,
        'bce_criterion': nn.BCEWithLogitsLoss()
    }
    unified_train_loop(
        model=dual_model,
        domains=domains,
        domain_dataloaders=domain_dataloaders,
        buffer=buffer,
        optimizer=optimizer,
        writer=writer,
        device=device,
        batch_fn=dualbranch_batch,
        batch_kwargs=dualbranch_kwargs,
        num_epochs=10,
        exp_name=exp_name,
        gradient_clipping=False,
        detach_base=False,
        binary = True,
        full_replay = True,
        collect_tsne_data=False
    )

# %%
import datetime
from torch.utils.tensorboard import SummaryWriter

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
domains = df['domain'].unique()
domain_to_idx = {d: i for i, d in enumerate(domains)}

testing_scenarios = {
    'pretrained_simple': ('pretrained', 'simple', '3linear', False), 
    'pretrained_special': ('pretrained', 'special', '3linear', False),
    '3conv_simple': ('3conv', 'simple', '3linear', True),
    '3conv_special': ('3conv', 'special', '3linear', True),
}

for name, (backbone, branch, end, detach_base) in testing_scenarios.items():
    print(f"\nTesting: {backbone} + {branch} + {end}")
    dual_model = DualBranchCNNNet(backbone_type=backbone, branch_type=branch, end_type=end, batch_norm=True).to(device)
    optimizer = torch.optim.Adam(dual_model.parameters(), lr=1e-3)
    buffer = NaiveRehearsalBuffer(buffer_size=1000)

    def cos_criterion(a, b):
        return (1 - torch.abs(nn.CosineSimilarity()(a, b))).mean()

    exp_name = f"CNN_{name}_dualbranchmodel_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
    writer = SummaryWriter(log_dir=f"../tensorboard/{exp_name}")

    dualbranch_kwargs = {
        'mse_criterion': nn.MSELoss(),
        'ce_criterion': nn.CrossEntropyLoss(),
        'cos_criterion': cos_criterion,
        'domain_to_idx': domain_to_idx,
        'bce_criterion': nn.BCEWithLogitsLoss()
    }
    unified_train_loop(
        model=dual_model,
        domains=domains,
        domain_dataloaders=domain_dataloaders,
        buffer=buffer,
        optimizer=optimizer,
        writer=writer,
        device=device,
        batch_fn=dualbranch_batch,
        batch_kwargs=dualbranch_kwargs,
        num_epochs=10,
        exp_name=exp_name,
        gradient_clipping=True,
        detach_base=detach_base,
        binary = True,
        full_replay = True,
        collect_tsne_data=False
    )

# %%
import datetime
from torch.utils.tensorboard import SummaryWriter

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
domains = df['domain'].unique()
domain_to_idx = {d: i for i, d in enumerate(domains)}

testing_scenarios = {
    'pretrained_simple_0.25branches': ('pretrained', 'simple', '3linear'), 
    # '3conv_adversarial': ('3conv', 'adversarial', 'adversarial'),
}

for name, (backbone, branch, end) in testing_scenarios.items():
    print(f"\nTesting: {backbone} + {branch} + {end}")
    dual_model = DualBranchCNNNet(backbone_type=backbone, branch_type=branch, end_type=end, batch_norm=True).to(device)
    optimizer = torch.optim.Adam(dual_model.parameters(), lr=1e-3)
    buffer = NaiveRehearsalBuffer(buffer_size=1000)

    def cos_criterion(a, b):
        return (1 - torch.abs(nn.CosineSimilarity()(a, b))).mean()

    exp_name = f"CNN_{name}_dualbranchmodel_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
    writer = SummaryWriter(log_dir=f"../tensorboard/{exp_name}")

    dualbranch_kwargs = {
        'mse_criterion': nn.MSELoss(),
        'ce_criterion': nn.CrossEntropyLoss(),
        'cos_criterion': cos_criterion,
        'domain_to_idx': domain_to_idx,
        'bce_criterion': nn.BCEWithLogitsLoss()
    }
    unified_train_loop(
        model=dual_model,
        domains=domains,
        domain_dataloaders=domain_dataloaders,
        buffer=buffer,
        optimizer=optimizer,
        writer=writer,
        device=device,
        batch_fn=dualbranch_batch,
        batch_kwargs=dualbranch_kwargs,
        num_epochs=10,
        exp_name=exp_name,
        gradient_clipping=True,
        detach_base=False,
        binary = True,
        full_replay = True,
        collect_tsne_data=False,
        loss_params = {'head': 0.5, 'social': 0.25, 'room': 0.25}
    )

# %%
import datetime
from torch.utils.tensorboard import SummaryWriter
from tqdm.notebook import tqdm

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
domains = df['domain'].unique()
domain_to_idx = {d: i for i, d in enumerate(domains)}

testing_scenarios = {
    # 'pretrained_simple': ('pretrained', 'simple', '3linear'), 
    '3conv_adversarial': ('3conv', 'adversarial', 'adversarial'),
}

for name, (backbone, branch, end) in testing_scenarios.items():
    print(f"\nTesting: {backbone} + {branch} + {end}")
    fold_history = {}
    for fold_num, domain_dataloaders in tqdm(fold_loaders.items()):
        dual_model = DualBranchCNNNet(backbone_type=backbone, branch_type=branch, end_type=end, batch_norm=True).to(device)
        optimizer = torch.optim.Adam(dual_model.parameters(), lr=1e-3)
        buffer = NaiveRehearsalBuffer(buffer_size=1000)

        def cos_criterion(a, b):
            return (1 - torch.abs(nn.CosineSimilarity()(a, b))).mean()

        exp_name = f"fold{fold_num}_CNN_{name}_dualbranchmodel_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
        writer = SummaryWriter(log_dir=f"../tensorboard/{exp_name}")

        dualbranch_kwargs = {
            'mse_criterion': nn.MSELoss(),
            'ce_criterion': nn.CrossEntropyLoss(),
            'cos_criterion': cos_criterion,
            'domain_to_idx': domain_to_idx,
            'bce_criterion': nn.BCEWithLogitsLoss()
        }
        history = unified_train_loop(
            model=dual_model,
            domains=domains,
            domain_dataloaders=domain_dataloaders,
            buffer=buffer,
            optimizer=optimizer,
            writer=writer,
            device=device,
            batch_fn=dualbranch_batch,
            batch_kwargs=dualbranch_kwargs,
            num_epochs=10,
            exp_name=exp_name,
            gradient_clipping=True,
            detach_base=False,
            binary = True,
            full_replay = True,
            collect_tsne_data=False,
            loss_params = {'head': 0.5, 'social': 0.25, 'room': 0.25}
        )
        fold_history[fold_num] = history
    with open(f"../checkpoints/5foldcrossval_{exp_name}_history.pkl", "wb") as f:
        pickle.dump(fold_history, f)

# %%
import datetime
from torch.utils.tensorboard import SummaryWriter
from tqdm.notebook import tqdm

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
domains = df['domain'].unique()
domain_to_idx = {d: i for i, d in enumerate(domains)}


dual_model = DualBranchNet_DANN().to(device)
optimizer = torch.optim.Adam(dual_model.parameters(), lr=1e-3)
buffer = NaiveRehearsalBuffer(buffer_size=1000)

def cos_criterion(a, b):
    return (1 - torch.abs(nn.CosineSimilarity()(a, b))).mean()

exp_name = f"DANN_dualbranchmodel_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
writer = SummaryWriter(log_dir=f"../tensorboard/{exp_name}")

dualbranch_kwargs = {
    'mse_criterion': nn.MSELoss(),
    'domain_to_idx': domain_to_idx,
    'bce_criterion': nn.BCEWithLogitsLoss()
}
history = unified_train_loop(
    model=dual_model,
    domains=domains,
    domain_dataloaders=domain_dataloaders,
    buffer=buffer,
    optimizer=optimizer,
    writer=writer,
    device=device,
    batch_fn=dann_batch,
    batch_kwargs=dualbranch_kwargs,
    num_epochs=10,
    exp_name=exp_name,
    gradient_clipping=True,
    detach_base=False,
    binary = True,
    full_replay = True,
    collect_tsne_data=False,
    loss_params = {'head': 1, 'social': 2}
)

# %%
import datetime
from torch.utils.tensorboard import SummaryWriter

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
domains = df['domain'].unique()
domain_to_idx = {d: i for i, d in enumerate(domains)}

domain_dataloaders = {}
for domain in domains:
    domain_df = df[df['domain'] == domain]
    loaders, split_idx = create_dataloaders(domain_df, batch_sizes=(32, 64, 64), resize_img_to=(512,288), seed=SEED, return_splits=True)  #512, 288 # 352,128 #LGR had 128,128 MobileNetv2 had 224, 224
    domain_dataloaders[domain] = loaders

baseline_model = LGRBaseline().to(device)
optimizer = torch.optim.Adam(baseline_model.parameters(), lr=1e-3)
buffer = NaiveRehearsalBuffer(buffer_size=1000)

exp_name = f"baselinemodel_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
writer = SummaryWriter(log_dir=f"../tensorboard/{exp_name}")

baseline_kwargs = {'mse_criterion': nn.MSELoss()}
unified_train_loop(
    model=baseline_model,
    domains=domains,
    domain_dataloaders=domain_dataloaders,
    buffer=buffer,
    optimizer=optimizer,
    writer=writer,
    device=device,
    batch_fn=baseline_batch,
    batch_kwargs=baseline_kwargs,
    num_epochs=10,
    exp_name=exp_name,
    loss_params={}
)

domain_dataloaders = {}
for domain in domains:
    domain_df = df[df['domain'] == domain]
    loaders, split_idx = create_dataloaders(domain_df, batch_sizes=(32, 64, 64), resize_img_to=(256,144), seed=SEED, return_splits=True)  #512, 288 # 352,128 #LGR had 128,128 MobileNetv2 had 224, 224
    domain_dataloaders[domain] = loaders

testing_scenarios = {
    'simple': ('3conv', 'simple', False, 1000), 
    'simple_buffer05': ('3conv', 'simple', False, 500),
    'special': ('3conv', 'special', False, 1000),
    'special_bnorm': ('3conv', 'special', True, 1000)
}

for name, (backbone, branch, batch_norm, buffer_size) in testing_scenarios.items():
    print(f"\nTesting: {backbone=} {branch=} {batch_norm=} {buffer_size=}")
    dual_model = DualBranchNet_minimal(backbone_type=backbone, branch_type=branch, head_type='3layer', batch_norm=batch_norm).to(device)
    optimizer = torch.optim.Adam(dual_model.parameters(), lr=1e-3)
    buffer = NaiveRehearsalBuffer(buffer_size=buffer_size)

    exp_name = f"minimal_{name}_dualbranchmodel_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
    writer = SummaryWriter(log_dir=f"../tensorboard/{exp_name}")

    baseline_kwargs = {'mse_criterion': nn.MSELoss()}
    unified_train_loop(
        model=dual_model,
        domains=domains,
        domain_dataloaders=domain_dataloaders,
        buffer=buffer,
        optimizer=optimizer,
        writer=writer,
        device=device,
        batch_fn=baseline_batch,
        batch_kwargs=baseline_kwargs,
        num_epochs=10,
        exp_name=exp_name,
        gradient_clipping=True,
        detach_base=False,
        binary = True,
        full_replay = True,
        collect_tsne_data=False,
        loss_params={}
    )

# %%
import datetime
from torch.utils.tensorboard import SummaryWriter

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
domains = df['domain'].unique()
domain_to_idx = {d: i for i, d in enumerate(domains)}

testing_scenarios = {
    # 'dualbranch_CNN_1epoch': (DualBranchCNNNet('3conv', 'simple', 'simple'), 500, 1), 
    'minimal_absurd_buff500': (DualBranchNet_minimal(backbone_type='absurd', branch_type='absurd', head_type='absurd'), 500, 10),
}

for name, (model, buffer_size, epochs) in testing_scenarios.items():
    print(f"\nTesting: {name}")
    dual_model = model.to(device)
    optimizer = torch.optim.Adam(dual_model.parameters(), lr=1e-3)
    buffer = NaiveRehearsalBuffer(buffer_size=buffer_size)

    exp_name = f"{name}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
    writer = SummaryWriter(log_dir=f"../tensorboard/{exp_name}")

    def cos_criterion(a, b):
        return (1 - torch.abs(nn.CosineSimilarity()(a, b))).mean()
    
    baseline_kwargs = {'mse_criterion': nn.MSELoss()}
    dualbranch_kwargs = {
            'mse_criterion': nn.MSELoss(),
            'ce_criterion': nn.CrossEntropyLoss(),
            'cos_criterion': cos_criterion,
            'domain_to_idx': domain_to_idx,
            'bce_criterion': nn.BCEWithLogitsLoss()
        }
    
    unified_train_loop(
        model=dual_model,
        domains=domains,
        domain_dataloaders=domain_dataloaders,
        buffer=buffer,
        optimizer=optimizer,
        writer=writer,
        device=device,
        batch_fn=baseline_batch,
        batch_kwargs=dualbranch_kwargs,
        num_epochs=epochs,
        exp_name=exp_name,
        gradient_clipping=True,
        detach_base=False,
        binary = True,
        full_replay = True,
        collect_tsne_data=False,
        loss_params={}
    )

# %%
import datetime
from torch.utils.tensorboard import SummaryWriter

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
domains = df['domain'].unique()
domain_to_idx = {d: i for i, d in enumerate(domains)}

testing_scenarios = {
    'DANN_notrain1dom': (DualBranchNet_DANN(), 500, 10, 1)
}

for name, (model, buffer_size, epochs, alpha) in testing_scenarios.items():
    print(f"\nTesting: {name}")
    dual_model = model.to(device)
    optimizer = torch.optim.Adam(dual_model.parameters(), lr=1e-3)
    buffer = NaiveRehearsalBuffer(buffer_size=buffer_size)

    exp_name = f"{name}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
    writer = None #SummaryWriter(log_dir=f"../tensorboard/{exp_name}")

    def cos_criterion(a, b):
        return (1 - torch.abs(nn.CosineSimilarity()(a, b))).mean()
    
    dualbranch_kwargs = {
            'mse_criterion': nn.MSELoss(),
            'ce_criterion': nn.CrossEntropyLoss(),
            'cos_criterion': cos_criterion,
            'domain_to_idx': domain_to_idx,
            'bce_criterion': nn.BCEWithLogitsLoss(),
            'alpha': alpha,
        }
    
    unified_train_loop(
        model=dual_model,
        domains=domains,
        domain_dataloaders=domain_dataloaders,
        buffer=buffer,
        optimizer=optimizer,
        writer=writer,
        device=device,
        batch_fn=dann_batch,
        batch_kwargs=dualbranch_kwargs,
        num_epochs=epochs,
        exp_name=exp_name,
        gradient_clipping=True,
        detach_base=False,
        binary = True,
        full_replay = True,
        collect_tsne_data=False,
        loss_params={'head':0.5, 'social':0.5}
    )

testing_scenarios = {
    'dualbranch_CNN_1epoch': (DualBranchCNNNet(backbone_type='3conv', branch_type='simple', end_type='3linear'), 500, 1, 1), 
    'dualbranch_CNN_dynamicalpha': (DualBranchCNNNet(backbone_type='3conv', branch_type='simple', end_type='3linear'), 500, 10, 0), 
}

for name, (model, buffer_size, epochs, alpha) in testing_scenarios.items():
    print(f"\nTesting: {name}")
    dual_model = model.to(device)
    optimizer = torch.optim.Adam(dual_model.parameters(), lr=1e-3)
    buffer = NaiveRehearsalBuffer(buffer_size=buffer_size)

    exp_name = f"{name}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
    writer = None #SummaryWriter(log_dir=f"../tensorboard/{exp_name}")

    def cos_criterion(a, b):
        return (1 - torch.abs(nn.CosineSimilarity()(a, b))).mean()
    
    dualbranch_kwargs = {
            'mse_criterion': nn.MSELoss(),
            'ce_criterion': nn.CrossEntropyLoss(),
            'cos_criterion': cos_criterion,
            'domain_to_idx': domain_to_idx,
            'bce_criterion': nn.BCEWithLogitsLoss(),
            'alpha': alpha,
        }
    
    unified_train_loop(
        model=dual_model,
        domains=domains,
        domain_dataloaders=domain_dataloaders,
        buffer=buffer,
        optimizer=optimizer,
        writer=writer,
        device=device,
        batch_fn=dualbranch_batch,
        batch_kwargs=dualbranch_kwargs,
        num_epochs=epochs,
        exp_name=exp_name,
        gradient_clipping=True,
        detach_base=False,
        binary = True,
        full_replay = True,
        collect_tsne_data=False,
        loss_params={'head':1, 'social':1, 'room':1}
    )

# %%
import datetime
from torch.utils.tensorboard import SummaryWriter

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
domains = df['domain'].unique()
domain_to_idx = {d: i for i, d in enumerate(domains)}

testing_scenarios = {
    '3conv_simple_simple_bnorm_nogradclip': (DualBranchCNNNet(backbone_type='3conv', branch_type='simple', end_type='simple', batch_norm=True), 500, 10, 1, False), 
    '3conv_simple_simple_nogradclip': (DualBranchCNNNet(backbone_type='3conv', branch_type='simple', end_type='simple', batch_norm=False), 500, 10, 1, False), 
    '3conv_simple_simple_bnorm': (DualBranchCNNNet(backbone_type='3conv', branch_type='simple', end_type='simple', batch_norm=True), 500, 10, 1, True),
    '3conv_simple_3linear_bnorm_nogradclip': (DualBranchCNNNet(backbone_type='3conv', branch_type='simple', end_type='simple', batch_norm=True), 500, 10, 1, False),
}

for name, (model, buffer_size, epochs, alpha, gradient_clip) in testing_scenarios.items():
    print(f"\nTesting: {name}")
    dual_model = model.to(device)
    optimizer = torch.optim.Adam(dual_model.parameters(), lr=1e-3)
    buffer = NaiveRehearsalBuffer(buffer_size=buffer_size)

    exp_name = f"{name}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
    writer = None #SummaryWriter(log_dir=f"../tensorboard/{exp_name}")

    def cos_criterion(a, b):
        return (1 - torch.abs(nn.CosineSimilarity()(a, b))).mean()
    
    dualbranch_kwargs = {
            'mse_criterion': nn.MSELoss(),
            'ce_criterion': nn.CrossEntropyLoss(),
            'cos_criterion': cos_criterion,
            'domain_to_idx': domain_to_idx,
            'bce_criterion': nn.BCEWithLogitsLoss(),
            'alpha': alpha,
        }
    
    unified_train_loop(
        model=dual_model,
        domains=domains,
        domain_dataloaders=domain_dataloaders,
        buffer=buffer,
        optimizer=optimizer,
        writer=writer,
        device=device,
        batch_fn=dualbranch_batch,
        batch_kwargs=dualbranch_kwargs,
        num_epochs=epochs,
        exp_name=exp_name,
        gradient_clipping=gradient_clip,
        detach_base=False,
        binary = True,
        full_replay = True,
        collect_tsne_data=False,
        loss_params={'head':1, 'social':1, 'room':1}
    )

# %%
df = pd.read_pickle("../data/pepper_data.pkl")
domain_dataloaders = get_dataloader(df, batch_sizes=(32, 64, 64), resize_img_to=(224,224), return_splits=False, double_img=False)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
domains = df['domain'].unique()
domain_to_idx = {d: i for i, d in enumerate(domains)}

testing_scenarios = {
    'deeplabv3mobilenetv3_dann': (DANN_classifier_poc(), 500, 30, 0, True),
}

for name, (model, buffer_size, epochs, alpha, gradient_clip) in testing_scenarios.items():
    print(f"\nTesting: {name}")
    dual_model = model.to(device)
    optimizer = torch.optim.Adam(dual_model.parameters(), lr=1e-3)
    buffer = NaiveRehearsalBuffer(buffer_size=buffer_size)

    exp_name = f"{name}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
    writer = None #SummaryWriter(log_dir=f"../tensorboard/{exp_name}")

    def cos_criterion(a, b):
        return (1 - torch.abs(nn.CosineSimilarity()(a, b))).mean()
    
    dualbranch_kwargs = {
            'mse_criterion': nn.MSELoss(),
            'ce_criterion': nn.CrossEntropyLoss(),
            'cos_criterion': cos_criterion,
            'domain_to_idx': domain_to_idx,
            'bce_criterion': nn.BCEWithLogitsLoss(),
            'alpha': alpha,
        }
    
    unified_train_loop(
        model=dual_model,
        domains=domains,
        domain_dataloaders=domain_dataloaders,
        buffer=buffer,
        optimizer=optimizer,
        writer=writer,
        device=device,
        batch_fn=dann_batch,
        batch_kwargs=dualbranch_kwargs,
        num_epochs=epochs,
        exp_name=exp_name,
        gradient_clipping=gradient_clip,
        detach_base=False,
        binary = True,
        full_replay = True,
        collect_tsne_data=True,
        loss_params={'head':1, 'social':1}
    )

# %%
#didit work, the architecture is flawed. Assesing category of features based on catastrophic forgetting makes no sense, 
# the features are not experiencing CF, the weights are. 
# But passing weights to split branches is not justified.

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
domains = df['domain'].unique()
domain_to_idx = {d: i for i, d in enumerate(domains)}

df = pd.read_pickle("../data/pepper_data.pkl")
domain_dataloaders = get_dataloader(df, batch_sizes=(32, 64, 64), resize_img_to=(224,224), return_splits=False, double_img=False)

# CORRECTED: Initialize model with proper parameter names
cf_model = CatastrophicForgettingDisentanglementModel(
    backbone_output_channels=640,
    branch_hidden_channels=256,
    branch_output_channels=128,
    num_outputs=9
).to(device)

# CORRECTED: Optimizers with proper parameter paths
main_optimizer = torch.optim.Adam([
    {'params': cf_model.forgetting_adapter.adapter.parameters()},
    {'params': cf_model.branch_forgetting.parameters()},
    {'params': cf_model.branch_not_forgetting.parameters()},
    {'params': cf_model.head.parameters()},
    {'params': cf_model.fusion.parameters()}
], lr=1e-3)

gating_optimizer = torch.optim.Adam(
    cf_model.forgetting_adapter.gating.parameters(),
    lr=1e-4
)

# restart = {
# 'global_step':
# 'history':
# 'domain':
# }

# Use your existing buffer and data
buffer = NaiveRehearsalBuffer(buffer_size=1000)

# Modified batch kwargs for our model
cf_kwargs = {
    'mse_criterion': nn.MSELoss(),
    'domain_to_idx': domain_to_idx,
}

# Run training with corrected functions
exp_name = f"forgetinggated_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"

history = catastrophic_forgetting_train_loop(
    model=cf_model,
    domains=domains,
    domain_dataloaders=domain_dataloaders,
    buffer=buffer,
    optimizer=main_optimizer,
    gating_optimizer=gating_optimizer,
    device=device,
    batch_fn=catastrophic_forgetting_batch,
    batch_kwargs=cf_kwargs,
    num_epochs=10,
    exp_name=exp_name,
    gradient_clipping=True,
    loss_params={'main': 1.0, 'adapter': 0.5, 'gating': 0.1},
    restart = restart
)

# %%
df = pd.read_pickle("../data/pepper_data.pkl")
domain_dataloaders = get_dataloader(df, batch_sizes=(32, 64, 64), resize_img_to=(288,512), return_splits=False, double_img=False)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
domains = df['domain'].unique()
domain_to_idx = {d: i for i, d in enumerate(domains)}

testing_scenarios = {
    # 'dann_mobilenet': (DualBranchNet_DANN(backbone_type='mobilenet'), 500, 10, 0, False, dann_batch),
    # 'dual_2conv_adversarial_3linear_detach': (DualBranchCNNNet(9,6,'2conv', 'adversarial', '3linear'), 500, 10, 0, True, dualbranch_batch),
    # 'dual_mobilenet_simple_3linear': (DualBranchCNNNet(9,6,'pretrained', 'simple', '3linear'), 500, 10, 0, False, dualbranch_batch),
    # 'dual_mobilenet_linear_simple': (DualBranchCNNNet(9,6,'pretrained', 'linear', 'simple'), 500, 10, 0, False, dualbranch_batch),
    'baseline': (LGRBaseline(), 500, 10, 0, False, baseline_batch)
}

for name, (model, buffer_size, epochs, alpha, detach_base, batch_fn) in testing_scenarios.items():
    print(f"\nTesting: {name}")
    dual_model = model.to(device)
    optimizer = torch.optim.Adam(dual_model.parameters(), lr=1e-3)
    buffer = NaiveRehearsalBuffer(buffer_size=buffer_size)

    exp_name = f"{name}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
    writer = None

    def cos_criterion(a, b):
        return (1 - torch.abs(nn.CosineSimilarity()(a, b))).mean()
    
    dualbranch_kwargs = {
            'mse_criterion': nn.MSELoss(),
            'ce_criterion': nn.CrossEntropyLoss(),
            'cos_criterion': cos_criterion,
            'domain_to_idx': domain_to_idx,
            'bce_criterion': nn.BCEWithLogitsLoss(),
            'alpha': alpha,
        }
    
    unified_train_loop(
        model=dual_model,
        domains=domains,
        domain_dataloaders=domain_dataloaders,
        buffer=buffer,
        optimizer=optimizer,
        writer=writer,
        device=device,
        batch_fn=batch_fn,
        batch_kwargs=dualbranch_kwargs,
        num_epochs=epochs,
        exp_name=exp_name,
        gradient_clipping=True,
        detach_base=detach_base,
        binary = True,
        full_replay = True,
        collect_tsne_data=False,
        loss_params={'head': 1, 'social': 1, 'room': 0.5}
    )

# %%
df = pd.read_pickle("../data/pepper_data.pkl")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
domains = df['domain'].unique()
domain_to_idx = {d: i for i, d in enumerate(domains)}

domain_dataloaders = get_dataloader(df, batch_sizes=(32, 64, 64), resize_img_to=(288,512), return_splits=False, double_img=False)

testing_scenarios = {
    # 'dann_mobilenet_buff500': (DualBranchNet_DANN(backbone_type='mobilenet'), 500, 10, 0, False, dann_batch),
    'dann_mobilenet_buff120': (DualBranchNet_DANN(backbone_type='mobilenet'), 120, 10, 0, False, dann_batch),
    # 'dual_2conv_adversarial_3linear_detach_buff500': (DualBranchCNNNet(9,6,'2conv', 'adversarial', '3linear'), 500, 10, 0, True, dualbranch_batch),
    # 'dual_2conv_adversarial_3linear_detach_buff120': (DualBranchCNNNet(9,6,'2conv', 'adversarial', '3linear'), 120, 10, 0, True, dualbranch_batch),
    # 'dual_mobilenet_simple_3linear_buff500': (DualBranchCNNNet(9,6,'pretrained', 'simple', '3linear'), 500, 10, 0, False, dualbranch_batch),
    # 'dual_mobilenet_simple_3linear_buff120': (DualBranchCNNNet(9,6,'pretrained', 'simple', '3linear'), 120, 10, 0, False, dualbranch_batch),
    # 'dual_mobilenet_linear_simple_buff120': (DualBranchCNNNet(9,6,'pretrained', 'linear', 'simple'), 120, 10, 0, False, dualbranch_batch),
    # 'baseline_buff500': (LGRBaseline(), 500, 10, 0, False, baseline_batch),
    # 'baseline_buff120': (LGRBaseline(), 120, 10, 0, False, baseline_batch)
}

for name, (model, buffer_size, epochs, alpha, detach_base, batch_fn) in testing_scenarios.items():
    print(f"\nTesting: {name}")
    dual_model = model.to(device)
    optimizer = torch.optim.Adam(dual_model.parameters(), lr=1e-3)
    buffer = NaiveRehearsalBuffer(buffer_size=buffer_size)

    exp_name = f"{name}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
    writer = None

    def cos_criterion(a, b):
        return (1 - torch.abs(nn.CosineSimilarity()(a, b))).mean()
    
    dualbranch_kwargs = {
            'mse_criterion': nn.MSELoss(),
            'ce_criterion': nn.CrossEntropyLoss(),
            'cos_criterion': cos_criterion,
            'domain_to_idx': domain_to_idx,
            'bce_criterion': nn.BCEWithLogitsLoss(),
            'alpha': alpha,
        }
    
    unified_train_loop(
        model=dual_model,
        domains=domains,
        domain_dataloaders=domain_dataloaders,
        buffer=buffer,
        optimizer=optimizer,
        writer=writer,
        device=device,
        batch_fn=batch_fn,
        batch_kwargs=dualbranch_kwargs,
        num_epochs=epochs,
        exp_name=exp_name,
        gradient_clipping=True,
        detach_base=detach_base,
        binary = True,
        full_replay = True,
        collect_tsne_data=False,
        loss_params={'head': 1, 'social': 1, 'room': 0.5}
    )

# import subprocess

# model_names = [
#     'dann_mobilenet_buff500',
#     'dann_mobilenet_buff120',
#     'dual_2conv_adversarial_3linear_detach_buff500',
#     'dual_2conv_adversarial_3linear_detach_buff120',
#     'dual_mobilenet_simple_3linear_buff500',
#     'dual_mobilenet_simple_3linear_buff120',
#     'dual_mobilenet_linear_simple_buff120',
#     'baseline_buff500',
#     'baseline_buff120'
#  ]

# for model_name in model_names:
#     print(f"Running {model_name}")
#     result = subprocess.run(
#         ["python", "train_models.py", "--model_name", model_name],
#         capture_output=True, text=True
#     )
#     print(result.stdout)
#     if result.stderr:
#         print("Error:", result.stderr)

# %%
testing_scenarios = {
    # 'heuristic_small_env': (DualBranchModel(), [(288,512), (144,256)], False),
    # 'heuristic_square_img': (DualBranchModel(), [(224,224)]*2, False),
    'heuristic_eval_buffer': (DualBranchModel(), [(288,512)]*2, True)
}

for name, (model, img_size, eval_buffer) in testing_scenarios.items():

    transform_soc = transforms.Compose([
        transforms.Resize(img_size[0]),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], 
                            std=[0.229, 0.224, 0.225])
    ])
    transform_env = transforms.Compose([
        transforms.Resize(img_size[1]),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], 
                            std=[0.229, 0.224, 0.225])
    ])

    df = pd.read_pickle("../data/pepper_data.pkl")
    df['image_path_env'] = df['image_path'].apply(lambda p: str(Path('../data/masked/environment') / Path(p).name))
    df['image_path_social'] = df['image_path'].apply(lambda p: str(Path('../data/masked/social') / Path(p).name))
    domain_dataloaders = get_dataloader(df, batch_sizes=(16, 64, 64), return_splits=False, double_img=True, transforms=[transform_soc, transform_env], num_workers=0)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    domains = df['domain'].unique()
    domain_to_idx = {d: i for i, d in enumerate(domains)}


    print(f"\nTesting: {name}")
    dual_model = model.to(device)
    # optimizer = torch.optim.Adam(dual_model.parameters(), lr=1e-3)
    optimizer = optim.Adam([
        {'params': dual_model.social_branch.parameters()},
        {'params': dual_model.env_branch.parameters()},
        {'params': dual_model.head.parameters()},
    ], lr=1e-3)
    classifier_optimizer = optim.Adam([ 
        {'params': dual_model.social_classifier.parameters()},
        {'params': dual_model.env_classifier.parameters()}
    ], lr=1e-3)

    buffer = NaiveRehearsalBuffer(buffer_size=120)
    if eval_buffer:
        eval_buffer = NaiveRehearsalBuffer(buffer_size=120)

    exp_name = f"{name}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
    writer = None

    def cos_criterion(a, b):
        return (1 - torch.abs(nn.CosineSimilarity()(a, b))).mean()
    
    dualbranch_kwargs = {
            'mse_criterion': nn.MSELoss(),
            'ce_criterion': nn.CrossEntropyLoss(),
            'cos_criterion': cos_criterion,
            'domain_to_idx': domain_to_idx,
            'bce_criterion': nn.BCEWithLogitsLoss(),
            'alpha': 0,
            'class_optimizer': classifier_optimizer
        }
    
    unified_train_loop(
        model=dual_model,
        domains=domains,
        domain_dataloaders=domain_dataloaders,
        buffer=buffer,
        optimizer=optimizer,
        writer=writer,
        device=device,
        batch_fn=heuristic_dualbranch_batch,
        batch_kwargs=dualbranch_kwargs,
        num_epochs=10,
        exp_name=exp_name,
        gradient_clipping=True,
        detach_base=False,
        binary = True,
        full_replay = True,
        collect_tsne_data=False,
        loss_params={'head': 1, 'social': 1, 'room': 0.5},
        eval_buffer=eval_buffer
    )

# %%
testing_scenarios = {
    'heuristic__small_imgs': (DualBranchModel(), [(144,256)]*2)
}

for name, (model, img_size) in testing_scenarios.items():

    transform = transforms.Compose([
        transforms.Resize((144,256)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], 
                            std=[0.229, 0.224, 0.225])
    ])

    df = pd.read_pickle("../data/pepper_data.pkl")
    df['image_path_env'] = df['image_path'].apply(lambda p: str(Path('../data/masked/environment') / Path(p).name))
    df['image_path_social'] = df['image_path'].apply(lambda p: str(Path('../data/masked/social') / Path(p).name))
    domain_dataloaders = get_dataloader(df, batch_sizes=(16, 64, 64), return_splits=False, double_img=True, transforms=[transform]*2, num_workers=0)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    domains = ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']


    print(f"\nTesting: {name}")
    dual_model = model.to(device)
    # optimizer = torch.optim.Adam(dual_model.parameters(), lr=1e-3)
    optimizer = optim.Adam([
        {'params': dual_model.social_branch.parameters()},
        {'params': dual_model.env_branch.parameters()},
        {'params': dual_model.head.parameters()},
    ], lr=1e-3)
    classifier_optimizer = optim.Adam([ 
        {'params': dual_model.social_classifier.parameters()},
        {'params': dual_model.env_classifier.parameters()}
    ], lr=1e-3)

    buffer = NaiveRehearsalBuffer(buffer_size=120)

    exp_name = f"{name}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
    
    dualbranch_kwargs = {
            'mse_criterion': nn.MSELoss(),
            'ce_criterion': nn.CrossEntropyLoss(),
            'class_optimizer': classifier_optimizer
        }
    
    unified_train_loop(
        model=dual_model,
        domains=domains,
        domain_dataloaders=domain_dataloaders,
        buffer=buffer,
        optimizer=optimizer,
        device=device,
        batch_fn=heuristic_dualbranch_batch,
        batch_kwargs=dualbranch_kwargs,
        num_epochs=10,
        exp_name=exp_name,
        gradient_clipping=True,
        collect_tsne_data=False,
        checkpoint_dir="../checkpoints"
    )

# %%
transform = transforms.Compose([
        transforms.Resize((144,256)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], 
                            std=[0.229, 0.224, 0.225])
    ])

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
domains = ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']

testing_scenarios = {
    # 'heuristic_HB2B3HlMS': (DualBranchModel()),
    # 'heuristic_og_img': (DualBranchModel(architecture={'env':'ablated', 'head':'deep'}),10),
    # 'heuristic_soc_img': (DualBranchModel(architecture={'env':'ablated', 'head':'deep'}),10),
    # 'heuristic_env_img': (DualBranchModel(architecture={'env':'ablated', 'head':'deep'}),10),
    'heuristic_HB2B3HlMS_epoch30': (DualBranchModel(),30),
}

for name, (model,epochs) in testing_scenarios.items():  
    df = pd.read_pickle("../data/pepper_data.pkl")
    df['image_path_env'] = df['image_path'].apply(lambda p: str(Path('../data/masked/environment') / Path(p).name))
    df['image_path_social'] = df['image_path'].apply(lambda p: str(Path('../data/masked/social') / Path(p).name))

    if name == 'heuristic_HB2B3HlMS_epoch30':
        domain_dataloaders = get_dataloader(df, batch_sizes=(32, 64, 64), return_splits=False, double_img=True, transforms=[transform]*2, num_workers=0)
    elif name == 'heuristic_og_img':
        domain_dataloaders = get_dataloader(df, batch_sizes=(32, 64, 64), return_splits=False, double_img=False, transforms=transform, num_workers=0)
    elif name == 'heuristic_soc_img':
        df['image_path'] = df['image_path_social']
        domain_dataloaders = get_dataloader(df, batch_sizes=(32, 64, 64), return_splits=False, double_img=False, transforms=transform, num_workers=0)
    elif name == 'heuristic_env_img':
        df['image_path'] = df['image_path_env']
        domain_dataloaders = get_dataloader(df, batch_sizes=(32, 64, 64), return_splits=False, double_img=False, transforms=transform, num_workers=0)

    print(f"\nTesting: {name}")
    dual_model = model.to(device)
    optimizer = torch.optim.Adam(dual_model.parameters(), lr=1e-3)

    buffer = NaiveRehearsalBuffer(buffer_size=120)

    exp_name = f"{name}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
    
    dualbranch_kwargs = {
            'mse_criterion': nn.MSELoss(),
            'ce_criterion': nn.CrossEntropyLoss(),
        }
    
    unified_train_loop(
        model=dual_model,
        domains=domains,
        domain_dataloaders=domain_dataloaders,
        buffer=buffer,
        optimizer=optimizer,
        device=device,
        batch_fn=heuristic_dualbranch_batch,
        batch_kwargs=dualbranch_kwargs,
        num_epochs=epochs,
        exp_name=exp_name,
        gradient_clipping=True,
        collect_tsne_data=False,
        checkpoint_dir="../checkpoints",
        validation_set='test'
    )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

import clip

transform = transforms.Compose([
        transforms.Resize((144,256)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], 
                            std=[0.229, 0.224, 0.225])
    ])

domains = ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']

testing_scenarios = {
    'mobilenetv2':      (False,),
    'resnet18':         (False,),
    'efficientnetb0':   (False,),
    'clip':             (True,),
}
    
for name, (freeze_branches) in testing_scenarios.items():
    for ablation in ['base', 'no_mask', 'only_soc', 'only_env']:

        # Training Data
        df = pd.read_pickle("../data/pepper_data_train.pkl")

        if name == 'clip':
            clip_model, transform = clip.load("ViT-B/32", device=device)

        if ablation == 'base':
            domain_dataloaders = get_domain_dataloaders(df, batch_sizes=(32, 64, 64), double_img=True, transforms=[transform]*2, num_workers=0, include_test=None)
        elif ablation == 'no_mask':
            domain_dataloaders = get_domain_dataloaders(df, batch_sizes=(32, 64, 64), double_img=False, transforms=transform, num_workers=0, include_test=None)
        elif ablation == 'only_soc':
            df['image_path'] = df['image_path_social']
            domain_dataloaders = get_domain_dataloaders(df, batch_sizes=(32, 64, 64), double_img=False, transforms=transform, num_workers=0, include_test=None)
        elif ablation == 'only_env':
            df['image_path'] = df['image_path_env']
            domain_dataloaders = get_domain_dataloaders(df, batch_sizes=(32, 64, 64), double_img=False, transforms=transform, num_workers=0, include_test=None)

        print(f"\nTesting: {name} Ablation: {ablation}")
        setup = {'branch':name} if ablation == 'base' else {'branch': name, 'env': 'ablated'}
        auxilary_model = clip_model if name == 'clip' else None
        model = DualBranchModel(dropout_rate=0.1, setup=setup, freeze_branches=freeze_branches, clip_model=auxilary_model)
        dual_model = model.to(device)
        trainable_params = [p for p in dual_model.parameters() if p.requires_grad]
        optimizer = torch.optim.Adam(trainable_params, lr=1e-3)
        buffer = NaiveRehearsalBuffer(buffer_size=120)

        epochs = 20

        exp_name = f"{name}_{ablation}_dropout{0.1}_epochs{epochs}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
        
        dualbranch_kwargs = {
                'mse_criterion': nn.MSELoss(),
                'ce_criterion': nn.CrossEntropyLoss(),
            }
        
        
        unified_train_loop(
            model=dual_model,
            domains=domains,
            domain_dataloaders=domain_dataloaders,
            buffer=buffer,
            optimizer=optimizer,
            device=device,
            batch_fn=heuristic_dualbranch_batch,
            batch_kwargs=dualbranch_kwargs,
            num_epochs=epochs,
            exp_name=exp_name,
            gradient_clipping=True,
            collect_tsne_data=False,
            checkpoint_dir="../checkpoints",
            validation_set='val',
        )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

transform = transforms.Compose([
        transforms.Resize((144,256)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], 
                            std=[0.229, 0.224, 0.225])
    ])

domains = ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']

testing_scenarios = {
    'simplebranch':      (False, 30, {'branch':'simple'}),
    # 'simplebranch_branchnorm':      (True, 30, {'branch':'simple'}),
    # 'mobilenetv2_branchnorm':      (True, 30, {'branch':'mobilenetv2'}),
    # 'mobilenetv2':       (False, 3, {'branch':'mobilenetv2'}),
}
    
for name, (branch_norm, epochs, setup) in testing_scenarios.items():

        # Training Data
        df = pd.read_pickle("../data/pepper_data_train.pkl")

        domain_dataloaders = get_domain_dataloaders(df, batch_sizes=(32, 64, 64), double_img=True, transforms=[transform]*2, num_workers=0, include_test=None)
        

        print(f"\nTesting: {name}")
        model = DualBranchModel(dropout_rate=0.1, setup=setup, branch_norm=branch_norm)
        dual_model = model.to(device)
        trainable_params = [p for p in dual_model.parameters() if p.requires_grad]
        optimizer = torch.optim.Adam(trainable_params, lr=1e-3)
        buffer = NaiveRehearsalBuffer(buffer_size=120)

        #restarting
        pt_file = torch.load('../checkpoints/simplebranch_epochs30_dropout0.1__20250805_215448_domainHallway_epoch29_step1290.pt')
        model.load_state_dict(pt_file['model_state_dict'])
        optimizer.load_state_dict(pt_file['optimizer_state_dict'])
        restart={
            'history': pt_file['history'],
            'global_step': 1290,
            'domain': 'MeetingRoom',
        }

        exp_name = f"{name}_epochs{epochs}_dropout{0.1}__{'20250805_215448'}"
        
        dualbranch_kwargs = {
                'mse_criterion': nn.MSELoss(),
                'ce_criterion': nn.CrossEntropyLoss(),
            }
        
        
        unified_train_loop(
            model=dual_model,
            domains=domains,
            domain_dataloaders=domain_dataloaders,
            buffer=buffer,
            optimizer=optimizer,
            device=device,
            batch_fn=heuristic_dualbranch_batch,
            batch_kwargs=dualbranch_kwargs,
            num_epochs=epochs,
            exp_name=exp_name,
            gradient_clipping=True,
            collect_tsne_data=False,
            checkpoint_dir="../checkpoints",
            validation_set='val',
            restart=restart
        )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

transform = transforms.Compose([
        transforms.Resize((144,256)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], 
                            std=[0.229, 0.224, 0.225])
    ])

domains = ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']

testing_scenarios = {
    'mobilenetv2_drop01_lr0.001':      (0.1, 1e-3),
    # 'mobilenetv2_drop03_lr0.001':      (0.3, 1e-3),
    'mobilenetv2_drop01_lr0.002':      (0.1, 2e-3),
    # 'mobilenetv2_drop01_lr0.003':      (0.1, 3e-3),
}

for name, (dropout, lr) in testing_scenarios.items():

        # Training Data
        df = pd.read_pickle("../data/pepper_data_train.pkl")

        domain_dataloaders = get_domain_dataloaders(df, batch_sizes=(32, 64, 64), double_img=True, transforms=[transform]*2, num_workers=0, include_test=None)

        print(f"\nTesting: {name}")
        model = DualBranchModel(dropout_rate=dropout, branch_norm=True)
        dual_model = model.to(device)
        trainable_params = [p for p in dual_model.parameters() if p.requires_grad]
        optimizer = torch.optim.Adam(trainable_params, lr=lr)
        buffer = NaiveRehearsalBuffer(buffer_size=120)

        epochs=30
        exp_name = f"dynamiclr_{name}_dropout0{int(dropout*10)}_epochs{epochs}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
        
        dualbranch_kwargs = {
                'mse_criterion': nn.MSELoss(),
                'ce_criterion': nn.CrossEntropyLoss(),
            }
        
        
        unified_train_loop(
            model=dual_model,
            domains=domains,
            domain_dataloaders=domain_dataloaders,
            buffer=buffer,
            optimizer=optimizer,
            device=device,
            batch_fn=heuristic_dualbranch_batch,
            batch_kwargs=dualbranch_kwargs,
            num_epochs=epochs,
            exp_name=exp_name,
            gradient_clipping=True,
            collect_tsne_data=False,
            checkpoint_dir="../data/checkpoints",
            validation_set='val',
            scheduler=get_linear_schedule_with_warmup
        )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

transform = transforms.Compose([
        transforms.Resize((144,256)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], 
                            std=[0.229, 0.224, 0.225])
    ])

domains = ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']

testing_scenarios = {
    # 'mobilenetv2_lr0.001_warmup10':      (1e-3, 0.1),
    # 'mobilenetv2_lr0.002_warmup10':      (2e-3, 0.1),
    # 'mobilenetv2_lr0.001_warmup20':      (1e-3, 0.2),
    'mobilenetv2_lr0.002_warmup20':      (2e-3, 0.2),
}

for name, (lr, warmup) in testing_scenarios.items():

        # Training Data
        df = pd.read_pickle("../data/pepper_data_train.pkl")

        domain_dataloaders = get_domain_dataloaders(df, batch_sizes=(32, 64, 64), double_img=True, transforms=[transform]*2, num_workers=0, include_test=None)

        print(f"\nTesting: {name}")
        model = DualBranchModel(dropout_rate=0.3, branch_norm=True)
        dual_model = model.to(device)
        trainable_params = [p for p in dual_model.parameters() if p.requires_grad]
        optimizer = torch.optim.Adam(trainable_params, lr=lr)
        buffer = NaiveRehearsalBuffer(buffer_size=120)

        epochs=30
        exp_name = f"dynamiclr_{name}_dropout03_epochs{epochs}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
        
        dualbranch_kwargs = {
                'mse_criterion': nn.MSELoss(),
                'ce_criterion': nn.CrossEntropyLoss(),
            }
        
        
        unified_train_loop(
            model=dual_model,
            domains=domains,
            domain_dataloaders=domain_dataloaders,
            buffer=buffer,
            optimizer=optimizer,
            device=device,
            batch_fn=heuristic_dualbranch_batch,
            batch_kwargs=dualbranch_kwargs,
            num_epochs=epochs,
            exp_name=exp_name,
            gradient_clipping=True,
            collect_tsne_data=False,
            checkpoint_dir="../data/checkpoints",
            validation_set='val',
            scheduler=(get_linear_schedule_with_warmup, warmup)
        )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

import clip

transform = transforms.Compose([
        transforms.Resize((144,256)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], 
                            std=[0.229, 0.224, 0.225])
    ])

domains = ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']

testing_scenarios = {
    # 'mobilenetv2':      (False,),
    'resnet18':         (False,),
}
    
for name, (freeze_branches) in testing_scenarios.items():
    for ablation in ['base', 'nomask', 'onlysoc', 'onlyenv']:

        # Training Data
        df = pd.read_pickle("../data/pepper_data_train.pkl")
        test_df = pd.read_pickle("../data/pepper_data_test_equal.pkl")

        if name == 'clip':
            clip_model, transform = clip.load("ViT-B/32", device=device)

        if ablation == 'base':
            domain_dataloaders = get_domain_dataloaders(df, batch_sizes=(32, 64, 64), double_img=True, transforms=[transform]*2, num_workers=2, include_test=test_df)
        elif ablation == 'nomask':
            domain_dataloaders = get_domain_dataloaders(df, batch_sizes=(32, 64, 64), double_img=False, transforms=transform, num_workers=2, include_test=test_df)
        elif ablation == 'onlysoc':
            df['image_path'] = df['image_path_social']
            domain_dataloaders = get_domain_dataloaders(df, batch_sizes=(32, 64, 64), double_img=False, transforms=transform, num_workers=2, include_test=test_df)
        elif ablation == 'onlyenv':
            df['image_path'] = df['image_path_env']
            domain_dataloaders = get_domain_dataloaders(df, batch_sizes=(32, 64, 64), double_img=False, transforms=transform, num_workers=2, include_test=test_df)

        print(f"\nTesting: {name} Ablation: {ablation}")
        setup = {'branch':name} if ablation == 'base' else {'branch': name, 'env': 'ablated'}
        auxilary_model = clip_model if name == 'clip' else None
        model = DualBranchModel(dropout_rate=0.3, setup=setup, freeze_branches=freeze_branches, clip_model=auxilary_model, branch_norm=True)
        dual_model = model.to(device)
        trainable_params = [p for p in dual_model.parameters() if p.requires_grad]
        optimizer = torch.optim.Adam(trainable_params, lr=1e-3)
        buffer = NaiveRehearsalBuffer(buffer_size=120)

        epochs = 30

        exp_name = f"{name}_ablation{ablation}_epochs{epochs}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
        
        dualbranch_kwargs = {
                'mse_criterion': nn.MSELoss(),
                'ce_criterion': nn.CrossEntropyLoss(),
            }
        
        
        unified_train_loop(
            model=dual_model,
            domains=domains,
            domain_dataloaders=domain_dataloaders,
            buffer=buffer,
            optimizer=optimizer,
            device=device,
            batch_fn=heuristic_dualbranch_batch,
            batch_kwargs=dualbranch_kwargs,
            num_epochs=epochs,
            exp_name=exp_name,
            gradient_clipping=True,
            collect_tsne_data=False,
            checkpoint_dir="../data/checkpoints",
            validation_set='test',
            scheduler=(get_linear_schedule_with_warmup, 0.05),
        )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

transform = transforms.Compose([
        transforms.Resize((144,256)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], 
                            std=[0.229, 0.224, 0.225])
    ])

domains = ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']

testing_scenarios = {
    # 'mobilenetv2':      ('base', False,True,10),
    # 'mobilenetv2':      ('base', False,True,20),
    # 'mobilenetv2_nonorm_base':      ('base', False,False,30),
    # 'mobilenetv2_nonorm_nomask':      ('nomask', False,False,30),
    # 'mobilenetv2_nonorm_onlysoc':      ('onlysoc', False,False,30),
    # 'mobilenetv2_nonorm_onlyenv':      ('onlyenv', False,False,30),
    # 'mobilenetv2_fullfrozen':      ('base', True,True,10),
    'mobilenetv2_fullfrozen':      ('base', 'full',True,10),

}
    
for name, (ablation, freeze_branches, branch_norm, epochs) in testing_scenarios.items():
        branch = 'mobilenetv2'
       
        df = pd.read_pickle("../data/pepper_data_train.pkl")
        test_df = pd.read_pickle("../data/pepper_data_test_equal.pkl")

        if ablation == 'base':
            domain_dataloaders = get_domain_dataloaders(df, batch_sizes=(32, 64, 64), double_img=True, transforms=[transform]*2, num_workers=2, include_test=test_df)
        elif ablation == 'nomask':
            domain_dataloaders = get_domain_dataloaders(df, batch_sizes=(32, 64, 64), double_img=False, transforms=transform, num_workers=2, include_test=test_df)
        elif ablation == 'onlysoc':
            df['image_path'] = df['image_path_social']
            domain_dataloaders = get_domain_dataloaders(df, batch_sizes=(32, 64, 64), double_img=False, transforms=transform, num_workers=2, include_test=test_df)
        elif ablation == 'onlyenv':
            df['image_path'] = df['image_path_env']
            domain_dataloaders = get_domain_dataloaders(df, batch_sizes=(32, 64, 64), double_img=False, transforms=transform, num_workers=2, include_test=test_df)

        print(f"\nTesting: {name} Ablation: {ablation}")
        setup = {'branch':branch} if ablation == 'base' else {'branch': branch, 'env': 'ablated'}
        model = DualBranchModel(dropout_rate=0.3, setup=setup, freeze_branches=freeze_branches, branch_norm=branch_norm)
        dual_model = model.to(device)
        trainable_params = [p for p in dual_model.parameters() if p.requires_grad]
        optimizer = torch.optim.Adam(trainable_params, lr=1e-3)
        buffer = NaiveRehearsalBuffer(buffer_size=120)


        exp_name = f"{name}_ablation{ablation}_epochs{epochs}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
        
        dualbranch_kwargs = {
                'mse_criterion': nn.MSELoss(),
                'ce_criterion': nn.CrossEntropyLoss(),
            }
        
        
        unified_train_loop(
            model=dual_model,
            domains=domains,
            domain_dataloaders=domain_dataloaders,
            buffer=buffer,
            optimizer=optimizer,
            device=device,
            batch_fn=heuristic_dualbranch_batch,
            batch_kwargs=dualbranch_kwargs,
            num_epochs=epochs,
            exp_name=exp_name,
            gradient_clipping=True,
            collect_tsne_data=False,
            checkpoint_dir="../checkpoints",
            validation_set='test',
            scheduler=(get_linear_schedule_with_warmup, 0.05),
        )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

transform = transforms.Compose([
        transforms.Resize((144,256)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], 
                            std=[0.229, 0.224, 0.225])
    ])

domains = ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']

testing_scenarios = {
    # 'mobilenetv2':      ('base', False,True,10),
    # 'mobilenetv2':      ('base', False,True,20),
    # 'mobilenetv2_nonorm_base':      ('base', False,False,30),
    # 'mobilenetv2_nonorm_nomask':      ('nomask', False,False,30),
    # 'mobilenetv2_nonorm_onlysoc':      ('onlysoc', False,False,30),
    # 'mobilenetv2_nonorm_onlyenv':      ('onlyenv', False,False,30),
    # 'mobilenetv2_fullfrozen':      ('base', 'full',True,10),
    'mobilenetv2_layernorm':      ('base', False,False,10),

}
    
for name, (ablation, freeze_branches, branch_norm, epochs) in testing_scenarios.items():
        branch = 'mobilenetv2'
    
        df = pd.read_pickle("../data/pepper_data_train.pkl")
        test_df = pd.read_pickle("../data/pepper_data_test_equal.pkl")

        if ablation == 'base':
            domain_dataloaders = get_domain_dataloaders(df, batch_sizes=(32, 64, 64), double_img=True, transforms=[transform]*2, num_workers=2, include_test=test_df)
        elif ablation == 'nomask':
            domain_dataloaders = get_domain_dataloaders(df, batch_sizes=(32, 64, 64), double_img=False, transforms=transform, num_workers=2, include_test=test_df)
        elif ablation == 'onlysoc':
            df['image_path'] = df['image_path_social']
            domain_dataloaders = get_domain_dataloaders(df, batch_sizes=(32, 64, 64), double_img=False, transforms=transform, num_workers=2, include_test=test_df)
        elif ablation == 'onlyenv':
            df['image_path'] = df['image_path_env']
            domain_dataloaders = get_domain_dataloaders(df, batch_sizes=(32, 64, 64), double_img=False, transforms=transform, num_workers=2, include_test=test_df)

        print(f"\nTesting: {name} Ablation: {ablation}")
        setup = {'branch':branch} if ablation == 'base' else {'branch': branch, 'env': 'ablated'}
        model = DualBranchModel(dropout_rate=0.3, setup=setup, freeze_branches=freeze_branches, branch_norm=branch_norm, norm_type='layer')
        dual_model = model.to(device)
        trainable_params = [p for p in dual_model.parameters() if p.requires_grad]
        optimizer = torch.optim.Adam(trainable_params, lr=1e-3)
        buffer = NaiveRehearsalBuffer(buffer_size=120)


        exp_name = f"{name}_layernorm_epochs{epochs}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
        
        dualbranch_kwargs = {
                'mse_criterion': nn.MSELoss(),
                'ce_criterion': nn.CrossEntropyLoss(),
            }

        unified_train_loop(
            model=dual_model,
            domains=domains,
            domain_dataloaders=domain_dataloaders,
            buffer=buffer,
            optimizer=optimizer,
            device=device,
            batch_fn=heuristic_dualbranch_batch,
            batch_kwargs=dualbranch_kwargs,
            num_epochs=epochs,
            exp_name=exp_name,
            gradient_clipping=True,
            collect_tsne_data=False,
            checkpoint_dir="../checkpoints",
            validation_set='test',
            scheduler=(get_linear_schedule_with_warmup, 0.05),
        )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

transform = transforms.Compose([
        transforms.Resize((144,256)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], 
                            std=[0.229, 0.224, 0.225])
    ])

domains = ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']

testing_scenarios = {
    'mobilenetv2_freshoptimiser_epochs10':      ('base',True,10),
    'mobilenetv2_freshoptimiser_epochs30':      ('base',True,30),

}
    
for name, (ablation, branch_norm, epochs) in testing_scenarios.items():
        branch = 'mobilenetv2'
    
        df = pd.read_pickle("../data/pepper_data_train.pkl")
        test_df = pd.read_pickle("../data/pepper_data_test_equal.pkl")

        if ablation == 'base':
            domain_dataloaders = get_domain_dataloaders(df, batch_sizes=(32, 64, 64), double_img=True, transforms=[transform]*2, num_workers=0, include_test=test_df)
        elif ablation == 'nomask':
            domain_dataloaders = get_domain_dataloaders(df, batch_sizes=(32, 64, 64), double_img=False, transforms=transform, num_workers=0, include_test=test_df)
        elif ablation == 'onlysoc':
            df['image_path'] = df['image_path_social']
            domain_dataloaders = get_domain_dataloaders(df, batch_sizes=(32, 64, 64), double_img=False, transforms=transform, num_workers=0, include_test=test_df)
        elif ablation == 'onlyenv':
            df['image_path'] = df['image_path_env']
            domain_dataloaders = get_domain_dataloaders(df, batch_sizes=(32, 64, 64), double_img=False, transforms=transform, num_workers=0, include_test=test_df)

        print(f"\nTesting: {name} Ablation: {ablation}")
        setup = {'branch':branch} if ablation == 'base' else {'branch': branch, 'env': 'ablated'}
        model = DualBranchModel(dropout_rate=0.3, setup=setup, branch_norm=branch_norm)
        dual_model = model.to(device)
        trainable_params = [p for p in dual_model.parameters() if p.requires_grad]
        optimizer = torch.optim.Adam(trainable_params, lr=1e-3)
        buffer = NaiveRehearsalBuffer(buffer_size=120)


        exp_name = f"{name}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
        
        dualbranch_kwargs = {
                'mse_criterion': nn.MSELoss(),
                'ce_criterion': nn.CrossEntropyLoss(),
            }

        unified_train_loop(
            model=dual_model,
            domains=domains,
            domain_dataloaders=domain_dataloaders,
            buffer=buffer,
            optimizer=optimizer,
            device=device,
            batch_fn=heuristic_dualbranch_batch,
            batch_kwargs=dualbranch_kwargs,
            num_epochs=epochs,
            exp_name=exp_name,
            gradient_clipping=True,
            collect_tsne_data=False,
            checkpoint_dir="../checkpoints",
            validation_set='test',
            scheduler=(get_linear_schedule_with_warmup, 0.05),
            refresh_optimiser=True,
        )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

transform = transforms.Compose([
        transforms.Resize((144,256)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], 
                            std=[0.229, 0.224, 0.225])
    ])

domains = ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']

testing_scenarios = {
    'mobilenetv2_earlystopping':      ('base',True,40),
}
    
for name, (ablation, branch_norm, epochs) in testing_scenarios.items():
        branch = 'mobilenetv2'
    
        df = pd.read_pickle("../data/pepper_data_train.pkl")
        test_df = pd.read_pickle("../data/pepper_data_test_equal.pkl")

        if ablation == 'base':
            domain_dataloaders = get_domain_dataloaders(df, batch_sizes=(32, 64, 64), double_img=True, transforms=[transform]*2, num_workers=0, include_test=test_df)
        elif ablation == 'nomask':
            domain_dataloaders = get_domain_dataloaders(df, batch_sizes=(32, 64, 64), double_img=False, transforms=transform, num_workers=0, include_test=test_df)
        elif ablation == 'onlysoc':
            df['image_path'] = df['image_path_social']
            domain_dataloaders = get_domain_dataloaders(df, batch_sizes=(32, 64, 64), double_img=False, transforms=transform, num_workers=0, include_test=test_df)
        elif ablation == 'onlyenv':
            df['image_path'] = df['image_path_env']
            domain_dataloaders = get_domain_dataloaders(df, batch_sizes=(32, 64, 64), double_img=False, transforms=transform, num_workers=0, include_test=test_df)

        print(f"\nTesting: {name} Ablation: {ablation}")
        setup = {'branch':branch} if ablation == 'base' else {'branch': branch, 'env': 'ablated'}
        model = DualBranchModel(setup=setup, branch_norm=branch_norm, norm_type='layer')
        dual_model = model.to(device)
        trainable_params = [p for p in dual_model.parameters() if p.requires_grad]
        optimizer = torch.optim.Adam(trainable_params, lr=1e-3)
        buffer = NaiveRehearsalBuffer(buffer_size=120)


        exp_name = f"{name}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
        
        dualbranch_kwargs = {
                'mse_criterion': nn.MSELoss(),
                'ce_criterion': nn.CrossEntropyLoss(),
            }

        unified_train_loop(
            model=dual_model,
            domains=domains,
            domain_dataloaders=domain_dataloaders,
            buffer=buffer,
            optimizer=optimizer,
            device=device,
            batch_fn=heuristic_dualbranch_batch,
            batch_kwargs=dualbranch_kwargs,
            num_epochs=epochs,
            exp_name=exp_name,
            gradient_clipping=True,
            checkpoint_dir="../checkpoints",
            validation_set='val',
            scheduler=(get_linear_schedule_with_warmup, 0.05),
            refresh_optimiser=False,
            early_stopping=True,
        )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

transform = transforms.Compose([
        transforms.Resize((144,256)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], 
                            std=[0.229, 0.224, 0.225])
    ])

domains = ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']

testing_scenarios = {
    'mobilenetv2_base':         ('base','mobilenetv2', True, 32, 120),
    'mobilenetv2_nomask':       ('nomask','mobilenetv2', True, 32, 120),
    'mobilenetv2_onlysoc':      ('onlysoc','mobilenetv2', True, 32, 120),
    'mobilenetv2_onlyenv':      ('onlyenv','mobilenetv2', True, 32, 120),
    'simple_base':              ('base','simple', True, 32, 120),
    'mobilenetv2_nogradclip':   ('base','mobilenetv2', False, 32, 120),
    'mobilenetv2_batch16':      ('base','mobilenetv2', True, 16, 120),
    'mobilenetv2_buffer72':     ('base','mobilenetv2', True, 32, 72),
    'mobilenetv2_buffer12':     ('base','mobilenetv2', True, 32, 12),
}
    
for name, (ablation, branch, grad_clipping, batches, buffer_size) in testing_scenarios.items():
    
        df = pd.read_pickle("../data/pepper_data_train.pkl")
        test_df = pd.read_pickle("../data/pepper_data_test_equal.pkl")

        if ablation == 'base':
            domain_dataloaders = get_domain_dataloaders(df, batch_sizes=(32, 64, 64), double_img=True, transforms=[transform]*2, num_workers=0, include_test=test_df)
        elif ablation == 'nomask':
            domain_dataloaders = get_domain_dataloaders(df, batch_sizes=(32, 64, 64), double_img=False, transforms=transform, num_workers=0, include_test=test_df)
        elif ablation == 'onlysoc':
            df['image_path'] = df['image_path_social']
            domain_dataloaders = get_domain_dataloaders(df, batch_sizes=(32, 64, 64), double_img=False, transforms=transform, num_workers=0, include_test=test_df)
        elif ablation == 'onlyenv':
            df['image_path'] = df['image_path_env']
            domain_dataloaders = get_domain_dataloaders(df, batch_sizes=(32, 64, 64), double_img=False, transforms=transform, num_workers=0, include_test=test_df)

        print(f"\nTesting: {name} Ablation: {ablation}")
        setup = {'branch':branch} if ablation == 'base' else {'branch': branch, 'env': 'ablated'}
        model = DualBranchModel(setup=setup, branch_norm=True, norm_type='layer')
        dual_model = model.to(device)
        trainable_params = [p for p in dual_model.parameters() if p.requires_grad]
        optimizer = torch.optim.Adam(trainable_params, lr=1e-3)
        buffer = NaiveRehearsalBuffer(buffer_size=buffer_size)

        epochs=40
        exp_name = f"{name}_epochsES_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
        
        dualbranch_kwargs = {
                'mse_criterion': nn.MSELoss(),
                'ce_criterion': nn.CrossEntropyLoss(),
            }

        unified_train_loop(
            model=dual_model,
            domains=domains,
            domain_dataloaders=domain_dataloaders,
            buffer=buffer,
            optimizer=optimizer,
            device=device,
            batch_fn=heuristic_dualbranch_batch,
            batch_kwargs=dualbranch_kwargs,
            num_epochs=epochs,
            exp_name=exp_name,
            gradient_clipping=grad_clipping,
            checkpoint_dir="../checkpoints",
            validation_set='val',
            scheduler=(get_linear_schedule_with_warmup, 0.05),
            refresh_optimiser=False,
            early_stopping=True,
        )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

transform = transforms.Compose([
        transforms.Resize((144,256)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], 
                            std=[0.229, 0.224, 0.225])
    ])

domains = ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']

testing_scenarios = {
    'mobilenetv2_branchnorme10':            ('onlysoc','mobilenetv2', True, 'batch', False, 10), #10e base had normal 0.8, 0.2 results
    'mobilenetv2_layernorme10':             ('onlysoc','mobilenetv2', False, 'layer', False, 10), #layer norm base had normal 0.8, 0.2 results
    'mobilenetv2_rbanchnormlayernorme10':   ('onlysoc','mobilenetv2', True, 'layer', False, 10), # both norms untested
    'mobilenetv2_branchnormES':             ('onlysoc','mobilenetv2', True, 'batch', True, 40),
    'mobilenetv2_nonormES':                 ('onlysoc','mobilenetv2', False, 'batch', True, 40),
    'mobilenetv2_layernormES':              ('onlysoc','mobilenetv2', False, 'layer', True, 40),
    'mobilenetv2_rbanchnormlayernormES':    ('onlysoc','mobilenetv2', True, 'layer', True, 40),
    'mobilenetv2_branchnorm':               ('onlysoc','mobilenetv2', True, 'batch', False, 30), #old bad results
    'mobilenetv2_nonorm':                   ('onlysoc','mobilenetv2', False, 'batch', False, 30), #nonorm bad results
    
    
}
    
for name, (ablation, branch, branch_norm, norm_type, earlystopping, epochs) in testing_scenarios.items():
        grad_clipping=True
        batches=32
        buffer_size=120
    
        df = pd.read_pickle("../data/pepper_data_train.pkl")
        test_df = pd.read_pickle("../data/pepper_data_test_equal.pkl")

        if ablation == 'base':
            domain_dataloaders = get_domain_dataloaders(df, batch_sizes=(32, 64, 64), double_img=True, transforms=[transform]*2, num_workers=0, include_test=test_df)
        elif ablation == 'nomask':
            domain_dataloaders = get_domain_dataloaders(df, batch_sizes=(32, 64, 64), double_img=False, transforms=transform, num_workers=0, include_test=test_df)
        elif ablation == 'onlysoc':
            df['image_path'] = df['image_path_social']
            domain_dataloaders = get_domain_dataloaders(df, batch_sizes=(32, 64, 64), double_img=False, transforms=transform, num_workers=0, include_test=test_df)
        elif ablation == 'onlyenv':
            df['image_path'] = df['image_path_env']
            domain_dataloaders = get_domain_dataloaders(df, batch_sizes=(32, 64, 64), double_img=False, transforms=transform, num_workers=0, include_test=test_df)

        print(f"\nTesting: {name} Ablation: {ablation}")
        setup = {'branch':branch} if ablation == 'base' else {'branch': branch, 'env': 'ablated'}
        model = DualBranchModel(setup=setup, branch_norm=branch_norm, norm_type=norm_type)
        dual_model = model.to(device)
        trainable_params = [p for p in dual_model.parameters() if p.requires_grad]
        optimizer = torch.optim.Adam(trainable_params, lr=1e-3)
        buffer = NaiveRehearsalBuffer(buffer_size=buffer_size)

        epochs=epochs
        exp_name = f"{name}_epochs{epochs}_ES{earlystopping}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
        
        dualbranch_kwargs = {
                'mse_criterion': nn.MSELoss(),
                'ce_criterion': nn.CrossEntropyLoss(),
            }

        unified_train_loop(
            model=dual_model,
            domains=domains,
            domain_dataloaders=domain_dataloaders,
            buffer=buffer,
            optimizer=optimizer,
            device=device,
            batch_fn=heuristic_dualbranch_batch,
            batch_kwargs=dualbranch_kwargs,
            num_epochs=epochs,
            exp_name=exp_name,
            gradient_clipping=grad_clipping,
            checkpoint_dir="../checkpoints",
            validation_set='val',
            scheduler=(get_linear_schedule_with_warmup, 0.05),
            refresh_optimiser=False,
            early_stopping=earlystopping,
        )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

transform = transforms.Compose([
        transforms.Resize((144,256)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], 
                            std=[0.229, 0.224, 0.225])
    ])

domains = ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']

testing_scenarios = {
    # 'mobilenetv2_base':         ('base','mobilenetv2', 42),
    'mobilenetv2_nomask':       ('nomask','mobilenetv2', 42),
    'mobilenetv2_onlysoc':      ('onlysoc','mobilenetv2', 42),
    'mobilenetv2_onlyenv':      ('onlyenv','mobilenetv2', 42),
    'simple_base':              ('base','simple', 42),
    # 'mobilenetv2_base':         ('base','mobilenetv2', 66),
    # 'mobilenetv2_nomask':       ('nomask','mobilenetv2', 66),
    # 'mobilenetv2_onlysoc':      ('onlysoc','mobilenetv2', 66),
    # 'mobilenetv2_onlyenv':      ('onlyenv','mobilenetv2', 66),
    # 'simple_base':              ('base','simple', 66),
    
}
    
for name, (ablation, branch, seed) in testing_scenarios.items():
        set_seed(seed)
        grad_clipping=True
        batches=32
        buffer_size=120
        branch_norm=False
        norm_type='layer'
        earlystopping=True
        epochs=20
    
        df = pd.read_pickle("../data/pepper_data_train.pkl")
        test_df = pd.read_pickle("../data/pepper_data_test_equal.pkl")

        if ablation == 'base':
            domain_dataloaders = get_domain_dataloaders(df, seed=seed, batch_sizes=(32, 64, 64), double_img=True, transforms=[transform]*2, num_workers=0, include_test=test_df)
        elif ablation == 'nomask':
            domain_dataloaders = get_domain_dataloaders(df, seed=seed, batch_sizes=(32, 64, 64), double_img=False, transforms=transform, num_workers=0, include_test=test_df)
        elif ablation == 'onlysoc':
            df['image_path'] = df['image_path_social']
            domain_dataloaders = get_domain_dataloaders(df, seed=seed, batch_sizes=(32, 64, 64), double_img=False, transforms=transform, num_workers=0, include_test=test_df)
        elif ablation == 'onlyenv':
            df['image_path'] = df['image_path_env']
            domain_dataloaders = get_domain_dataloaders(df, seed=seed, batch_sizes=(32, 64, 64), double_img=False, transforms=transform, num_workers=0, include_test=test_df)

        print(f"\nTesting: {name} Ablation: {ablation}")
        setup = {'branch':branch} if ablation == 'base' else {'branch': branch, 'env': 'ablated'}
        model = DualBranchModel(setup=setup, branch_norm=branch_norm, norm_type=norm_type)
        dual_model = model.to(device)
        trainable_params = [p for p in dual_model.parameters() if p.requires_grad]
        optimizer = torch.optim.Adam(trainable_params, lr=1e-3)
        buffer = NaiveRehearsalBuffer(buffer_size=buffer_size)

        epochs=epochs
        exp_name = f"{name}_epochs{epochs}_ES{earlystopping}_seed{seed}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
        
        dualbranch_kwargs = {
                'mse_criterion': nn.MSELoss(),
                'ce_criterion': nn.CrossEntropyLoss(),
            }

        unified_train_loop(
            model=dual_model,
            domains=domains,
            domain_dataloaders=domain_dataloaders,
            buffer=buffer,
            optimizer=optimizer,
            device=device,
            batch_fn=heuristic_dualbranch_batch,
            batch_kwargs=dualbranch_kwargs,
            num_epochs=epochs,
            exp_name=exp_name,
            gradient_clipping=grad_clipping,
            checkpoint_dir="../checkpoints",
            validation_set='val',
            scheduler=(get_linear_schedule_with_warmup, 0.05),
            refresh_optimiser=False,
            early_stopping=earlystopping,
        )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

transform = transforms.Compose([
        transforms.Resize((144,256)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], 
                            std=[0.229, 0.224, 0.225])
    ])
#seeds  42, 66, 101010, 15, 1379,
domains = ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']

testing_scenarios = {
    'mobilenetv2_base_seed15':         ('base','mobilenetv2', 15),
    'mobilenetv2_nomask_seed15':       ('nomask','mobilenetv2', 15),
    'mobilenetv2_onlysoc_seed15':      ('onlysoc','mobilenetv2', 15),
    'mobilenetv2_onlyenv_seed15':      ('onlyenv','mobilenetv2', 15),
    'mobilenetv2_base_seed1379':         ('base','mobilenetv2', 1379),
    'mobilenetv2_nomask_seed1379':       ('nomask','mobilenetv2', 1379),
    'mobilenetv2_onlysoc_seed1379':      ('onlysoc','mobilenetv2', 1379),
    'mobilenetv2_onlyenv_seed1379':      ('onlyenv','mobilenetv2', 1379),
    'mobilenetv2_base_seed101010':         ('base','mobilenetv2', 101010),
    'mobilenetv2_nomask_seed101010':       ('nomask','mobilenetv2', 101010),
    'mobilenetv2_onlysoc_seed101010':      ('onlysoc','mobilenetv2', 101010),
    'mobilenetv2_onlyenv_seed101010':      ('onlyenv','mobilenetv2', 101010),    
}
    
for name, (ablation, branch, seed) in testing_scenarios.items():
        set_seed(seed)
        grad_clipping=True
        batches=32
        buffer_size=120
        branch_norm=False
        norm_type='layer'
        earlystopping=True
        epochs=20
    
        df = pd.read_pickle("../data/pepper_data_train.pkl")
        test_df = pd.read_pickle("../data/pepper_data_test_equal.pkl")

        if ablation == 'base':
            domain_dataloaders = get_domain_dataloaders(df, seed=seed, batch_sizes=(32, 64, 64), double_img=True, transforms=[transform]*2, num_workers=0, include_test=test_df)
        elif ablation == 'nomask':
            domain_dataloaders = get_domain_dataloaders(df, seed=seed, batch_sizes=(32, 64, 64), double_img=False, transforms=transform, num_workers=0, include_test=test_df)
        elif ablation == 'onlysoc':
            df['image_path'] = df['image_path_social']
            domain_dataloaders = get_domain_dataloaders(df, seed=seed, batch_sizes=(32, 64, 64), double_img=False, transforms=transform, num_workers=0, include_test=test_df)
        elif ablation == 'onlyenv':
            df['image_path'] = df['image_path_env']
            domain_dataloaders = get_domain_dataloaders(df, seed=seed, batch_sizes=(32, 64, 64), double_img=False, transforms=transform, num_workers=0, include_test=test_df)

        print(f"\nTesting: {name} Ablation: {ablation}")
        setup = {'branch':branch} if ablation == 'base' else {'branch': branch, 'env': 'ablated'}
        model = DualBranchModel(setup=setup, branch_norm=branch_norm, norm_type=norm_type)
        dual_model = model.to(device)
        trainable_params = [p for p in dual_model.parameters() if p.requires_grad]
        optimizer = torch.optim.Adam(trainable_params, lr=1e-3)
        buffer = NaiveRehearsalBuffer(buffer_size=buffer_size)

        epochs=epochs
        exp_name = f"{name}_epochs{epochs}_ES{earlystopping}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
        
        dualbranch_kwargs = {
                'mse_criterion': nn.MSELoss(),
                'ce_criterion': nn.CrossEntropyLoss(),
            }

        unified_train_loop(
            model=dual_model,
            domains=domains,
            domain_dataloaders=domain_dataloaders,
            buffer=buffer,
            optimizer=optimizer,
            device=device,
            batch_fn=heuristic_dualbranch_batch,
            batch_kwargs=dualbranch_kwargs,
            num_epochs=epochs,
            exp_name=exp_name,
            gradient_clipping=grad_clipping,
            checkpoint_dir="../checkpoints",
            validation_set='val',
            scheduler=(get_linear_schedule_with_warmup, 0.05),
            refresh_optimiser=False,
            early_stopping=earlystopping,
        )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

input_img_resize={
    'scene': (144,256), 
    'focus': (128,128)
}

transform_scene = transforms.Compose([
        transforms.Resize(input_img_resize['scene']),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], 
                            std=[0.229, 0.224, 0.225])
    ])
transform_focus = transforms.Compose([
        transforms.Resize(input_img_resize['focus']),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], 
                            std=[0.229, 0.224, 0.225])
    ])

domains = ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']


testing_scenarios = {
    # 'dualbranch_zoom.base':         ('base','mobilenetv2'),
    # 'dualbranch_zoom.nomask':         ('nomask','mobilenetv2'),
    'dualbranch_zoom.onlysoc':         ('onlysoc','mobilenetv2')  
}
    
for name, (ablation, branch) in testing_scenarios.items():
        seed=42
        set_seed(seed)
        grad_clipping=True
        batch=(32, 64, 64)
        buffer_size=69
        branch_norm=True
        earlystopping=True
        epochs=20
        alldomains=False

        # df["image_path"] = df["image_path"].str.replace(
        #     r"^../data/images/",
        #     "../data/perturbations/environment/",
        #     regex=True
        # )
        # df['image_path_env'] = df['image_path']
    
        # df = pd.read_pickle("../data/pepper_data_train.pkl")
        # test_df = pd.read_pickle("../data/pepper_data_test_equal.pkl")
        train_val_path = "../data/pepper_data_robotzoom_train.pkl"
        test_path = "../data/pepper_data_robotzoom_test_equal.pkl"

        df = pd.read_pickle(train_val_path)
        test_df = pd.read_pickle(test_path)

        if ablation == 'base':
            domain_dataloaders = get_domain_dataloaders(df, seed=seed, batch_sizes=batch, img_path_cols=['image_path', 'image_path_focus'], transforms=[transform_scene, transform_focus], num_workers=0, include_test=test_df)
        elif ablation == 'nomask':
            domain_dataloaders = get_domain_dataloaders(df, seed=seed, batch_sizes=batch, img_path_cols=['image_path'], transforms=[transform_scene], num_workers=0, include_test=test_df)
        elif ablation == 'onlysoc':
            domain_dataloaders = get_domain_dataloaders(df, seed=seed, batch_sizes=batch, img_path_cols=['image_path_focus'], transforms=[transform_focus], num_workers=0, include_test=test_df)
        # elif ablation == 'onlyenv':
        #     df['image_path'] = df['image_path_env']
        #     domain_dataloaders = get_domain_dataloaders(df, seed=seed, batch_sizes=(32, 64, 64), double_img=False, transforms=transformA, num_workers=0, include_test=test_df)

        if alldomains:
            domain_dataloaders = combine_all_dataloaders(domain_dataloaders)
            domains = ['AllDomains']

        print(f"\nTesting: {name} Ablation: {ablation}")
        setup = {'branch':branch} if ablation == 'base' else {'branch':branch, 'ablation':True}
        dropout_rate=0.3
        model = DualBranchModel(dropout_rate=dropout_rate, setup=setup, branch_norm=branch_norm)
        dual_model = model.to(device)
        trainable_params = [p for p in dual_model.parameters() if p.requires_grad]
        lr=1e-3
        optimizer = torch.optim.Adam(trainable_params, lr=lr)
        buffer = NaiveRehearsalBuffer(buffer_size=buffer_size)

        epochs=epochs
        exp_name = f"{name}_{grad_clipping=}_{batch=}_{buffer_size=}_{branch_norm=}_{earlystopping=}_{epochs=}_{alldomains=}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
        
        scheduler=(get_linear_schedule_with_warmup, 0.05)
        refresh_optimiser=False

        dualbranch_kwargs = {
                'mse_criterion': nn.MSELoss(),
                'ce_criterion': nn.CrossEntropyLoss(),
            }

        config = {
            "model": {
                 "name": type(model),
                 "setup": setup,
                 "branch_norm":branch_norm,
                 "dropout_rate":dropout_rate,
            },
            "buffer": type(buffer),
            "buffer_size": buffer_size,
            "optimizer": type(optimizer),
            "learning_rate": lr,
            "scheduler": {
                "type": "transformers.get_linear_schedule_with_warmup",
                "warmup": scheduler[1],
            },
            "device": device,
            "loss": dualbranch_kwargs['mse_criterion'],
            "training_mode": "noCL" if alldomains else "CL",
            "seed": seed,
            "train_val_df": train_val_path,
            "test_df": test_path,
            "input_transforms_resize": input_img_resize,
            "batch_size": batch,
            "epochs": epochs,
            "early_stopping": {
                 "patience":15,
                 "delta":1e-3,
            },
            "gradient_clipping": grad_clipping,
            "refresh_optimiser": refresh_optimiser,
        }

        with open(f"../checkpoints/{exp_name}_config.json", "w") as f:
            json.dump(config, f, indent=4)

        unified_train_loop(
            model=dual_model,
            domains=domains,
            domain_dataloaders=domain_dataloaders,
            buffer=buffer,
            optimizer=optimizer,
            device=device,
            batch_fn=heuristic_dualbranch_batch,
            batch_kwargs=dualbranch_kwargs,
            num_epochs=epochs,
            exp_name=exp_name,
            gradient_clipping=grad_clipping,
            checkpoint_dir="../checkpoints",
            validation_set='val',
            scheduler=scheduler,
            refresh_optimiser=refresh_optimiser,
            early_stopping=earlystopping,
        )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")    

domains = ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']

testing_scenarios = {
        #  'heuristicsplit.base': ('base', 120, "../data/pepper_data_train.pkl", False, [get_transform((144,256), IMAGENET_NORM), get_transform((144,256), IMAGENET_NORM)], ['image_path_env', 'image_path_soc']),
        #  'heuristicsplit.base': ('base', 120, "../data/pepper_data_train.pkl", False, [get_transform((144,256), None), get_transform((144,256), None)], ['image_path_env', 'image_path_soc']),
    'heuristicsplit_elipses.base': ('base', 120, "../data/pepper_data_train.pkl", False, [get_transform((144,256), IMAGENET_NORM), get_transform((144,256), IMAGENET_NORM)], ['image_path_env_elipses', 'image_path_soc']),
    'heuristicsplit_elipses.nomask': ('nomask', 120, "../data/pepper_data_train.pkl", False, [get_transform((144,256), IMAGENET_NORM)], ['image_path']),
    'heuristicsplit_elipses.onlysoc': ('onlysoc', 120, "../data/pepper_data_train.pkl", False, [get_transform((144,256), IMAGENET_NORM)], ['image_path_soc']),
    'heuristicsplit_elipses.onlyenv': ('onlyenv', 120, "../data/pepper_data_train.pkl", False, [get_transform((144,256), IMAGENET_NORM)], ['image_path_env_elipses']),

    'heuristicsplit_elipsesplus.base': ('base', 120, "../data/pepper_data_train.pkl", False, [get_transform((144,256), IMAGENET_NORM), get_transform((144,256), IMAGENET_NORM)], ['image_path_env_plus', 'image_path_soc']),
    'heuristicsplit_elipsesplus.onlyenv': ('onlyenv', 120, "../data/pepper_data_train.pkl", False, [get_transform((144,256), IMAGENET_NORM)], ['image_path_env_plus']),

    'heuristicsplit_empty.base': ('base', 120, "../data/pepper_data_train.pkl", False, [get_transform((144,256), IMAGENET_NORM), get_transform((144,256), IMAGENET_NORM)], ['image_path_env_empty', 'image_path_soc']),
    'heuristicsplit_empty.onlyenv': ('onlyenv', 120, "../data/pepper_data_train.pkl", False, [get_transform((144,256), IMAGENET_NORM)], ['image_path_env_empty']),
    # #  .label
    'robotfocus_128_x2.base': ('base', 94, "../data/robotfocus_pepper_data_train.pkl", False, [get_transform((144,256), IMAGENET_NORM), get_transform((128,128), IMAGENET_NORM)], ['image_path_scene', 'image_path_focus_x2']),
    'robotfocus_128_x2.onlyenv': ('onlyenv', 94, "../data/robotfocus_pepper_data_train.pkl", False, [get_transform((144,256), IMAGENET_NORM)], ['image_path_scene']),
    'robotfocus_128_x2.onlysoc': ('onlysoc', 94, "../data/robotfocus_pepper_data_train.pkl", False, [get_transform((128,128), IMAGENET_NORM)], ['image_path_focus_x2']),
        # 'robotfocus_x2.base': ('base', 94, "../data/robotfocus_pepper_data_train.pkl", False, [get_transform((144,256), None),          get_transform((128,128), None)],          ['image_path_scene', 'image_path_focus_x2']),
        # 'robotfocus_x2.base': ('base', 94, "../data/robotfocus_pepper_data_train.pkl", False, [get_transform((144,256), IMAGENET_NORM), get_transform((256,256), IMAGENET_NORM)], ['image_path_scene', 'image_path_focus_x2']),
    'robotfocus_512_x2.base': ('base', 94, "../data/robotfocus_pepper_data_train.pkl", False, [get_transform((144,256), IMAGENET_NORM), get_transform((512,512), IMAGENET_NORM)], ['image_path_scene', 'image_path_focus_x2']),
    'robotfocus_512_x2.onlysoc': ('onlysoc', 94, "../data/robotfocus_pepper_data_train.pkl", False, [get_transform((512,512), IMAGENET_NORM)], ['image_path_focus_x2']),

        # 'robotfocus_x15.base': ('base', 94, "../data/robotfocus_pepper_data_train.pkl", False, [get_transform((144,256), IMAGENET_NORM), get_transform((128,128), IMAGENET_NORM)], ['image_path_scene', 'image_path_focus_x1.5']),
    'robotfocus_128_x4.base': ('base', 94, "../data/robotfocus_pepper_data_train.pkl", False, [get_transform((144,256), IMAGENET_NORM), get_transform((128,128), IMAGENET_NORM)], ['image_path_scene', 'image_path_focus_x4']),
    'robotfocus_128_x4.onlysoc': ('onlysoc', 94, "../data/robotfocus_pepper_data_train.pkl", False, [get_transform((128,128), IMAGENET_NORM)], ['image_path_focus_x4']),
}
    
for name, (ablation, buffer_size, train_val_path, test_path, transform_list, img_path_cols) in testing_scenarios.items():
        train_df = pd.read_pickle(train_val_path)
        test_df = False
        branch='mobilenetv2'
        seed=42
        set_seed(seed)
        grad_clipping=True
        batch=(32, 64, 64)
        buffer_size=buffer_size
        branch_norm=True
        earlystopping=True
        epochs=20
        alldomains=False

        # df["image_path"] = df["image_path"].str.replace(
        #     r"^../data/images/",
        #     "../data/perturbations/environment/",
        #     regex=True
        # )
        # df['image_path_env'] = df['image_path']

        if ablation == 'base':
            domain_dataloaders = get_domain_dataloaders(train_df, seed=seed, batch_sizes=batch, img_path_cols=img_path_cols, transforms=transform_list, num_workers=0, include_test=test_df)
        elif ablation == 'nomask':
            domain_dataloaders = get_domain_dataloaders(train_df, seed=seed, batch_sizes=batch, img_path_cols=img_path_cols, transforms=transform_list, num_workers=0, include_test=test_df)
        elif ablation == 'onlysoc':
            domain_dataloaders = get_domain_dataloaders(train_df, seed=seed, batch_sizes=batch, img_path_cols=img_path_cols, transforms=transform_list, num_workers=0, include_test=test_df)
        elif ablation == 'onlyenv':
            domain_dataloaders = get_domain_dataloaders(train_df, seed=seed, batch_sizes=batch, img_path_cols=img_path_cols, transforms=transform_list, num_workers=0, include_test=test_df)

        if alldomains:
            domain_dataloaders = combine_all_dataloaders(domain_dataloaders)
            domains = ['AllDomains']

        print(f"\nTesting: {name} Ablation: {ablation}")
        setup = {'branch':branch} if ablation == 'base' else {'branch':branch, 'ablation':True}
        dropout_rate=0.3
        model = DualBranchModel(dropout_rate=dropout_rate, setup=setup, branch_norm=branch_norm)
        dual_model = model.to(device)
        trainable_params = [p for p in dual_model.parameters() if p.requires_grad]
        lr=1e-3
        optimizer = torch.optim.Adam(trainable_params, lr=lr)
        buffer = NaiveRehearsalBuffer(buffer_size=buffer_size)

        epochs=epochs
        exp_name = f"{name}_{buffer_size=}_{epochs=}_{seed=}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
        
        scheduler=(get_linear_schedule_with_warmup, 0.05)
        refresh_optimiser=False

        dualbranch_kwargs = {
                'mse_criterion': nn.MSELoss(),
            }

        config = {
            "model": {
                 "name": str(type(model)),
                 "setup": setup,
                 "branch_norm":branch_norm,
                 "dropout_rate":dropout_rate,
            },
            "buffer": str(type(buffer)),
            "buffer_size": buffer_size,
            "optimizer": str(type(optimizer)),
            "learning_rate": lr,
            "scheduler": {
                "type": "transformers.get_linear_schedule_with_warmup",
                "warmup": scheduler[1],
            },
            "device": str(device),
            "loss": str(dualbranch_kwargs['mse_criterion']),
            "training_mode": "noCL" if alldomains else "CL",
            "seed": seed,
            "train_val_df": train_val_path,
            "test_df": test_path,
            "input_columns": img_path_cols,
            "input_transforms": [str(x) for x in transform_list],
            "batch_size": batch,
            "epochs": epochs,
            "early_stopping": {
                 "patience":15,
                 "delta":1e-3,
            },
            "gradient_clipping": grad_clipping,
            "refresh_optimiser": refresh_optimiser,
        }

        with open(f"../checkpoints/{exp_name}_config.json", "w") as f:
            json.dump(config, f, indent=4)

        unified_train_loop(
            model=dual_model,
            domains=domains,
            domain_dataloaders=domain_dataloaders,
            buffer=buffer,
            optimizer=optimizer,
            device=device,
            batch_fn=heuristic_dualbranch_batch,
            batch_kwargs=dualbranch_kwargs,
            num_epochs=epochs,
            exp_name=exp_name,
            gradient_clipping=grad_clipping,
            checkpoint_dir="../checkpoints",
            validation_set='val',
            scheduler=scheduler,
            refresh_optimiser=refresh_optimiser,
            early_stopping=earlystopping,
        )

# %%
def serialize_transform(transform):
    steps = []
    for sub in transform.transforms:
        cls_name = sub.__class__.__name__
        if isinstance(sub, T.Resize):
            args = {"size": sub.size}
        elif isinstance(sub, T.Normalize):
            args = {"mean": sub.mean, "std": sub.std}
        elif isinstance(sub, T.ToTensor):
            args = {}
        else:
            raise NotImplementedError(f"Serialization not implemented for {cls_name}")
        steps.append({"type": cls_name, "args": args})
    return steps

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")    

domains = ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']

testing_scenarios = {
    # 'heuristicsplit.base': ('base', 120, "../data/all_pepper_data_train.pkl", "../data/all_pepper_data_test_equal.pkl", [get_transform((144,256), IMAGENET_NORM), get_transform((144,256), IMAGENET_NORM)], ['image_path_env', 'image_path_soc'], False),
    # 'heuristicsplit.nomask': ('nomask', 120, "../data/all_pepper_data_train.pkl", "../data/all_pepper_data_test_equal.pkl", [get_transform((144,256), IMAGENET_NORM)], ['image_path'], False),
    # 'heuristicsplit.onlysoc': ('onlysoc', 120, "../data/all_pepper_data_train.pkl", "../data/all_pepper_data_test_equal.pkl", [get_transform((144,256), IMAGENET_NORM)], ['image_path_soc'], False),
    'heuristicsplit_label.base': ('base', 120, "../data/all_pepper_data_train.pkl", "../data/all_pepper_data_test_equal.pkl", [get_transform((144,256), IMAGENET_NORM)], ['image_path_soc'], True),
    'heuristicsplit_label.onlyenv': ('onlyenv', 120, "../data/all_pepper_data_train.pkl", "../data/all_pepper_data_test_equal.pkl", [], [], True),
    'heuristicsplit_elipsesplus.base': ('base', 120, "../data/all_pepper_data_train.pkl", "../data/all_pepper_data_test_equal.pkl", [get_transform((144,256), IMAGENET_NORM), get_transform((144,256), IMAGENET_NORM)], ['image_path_env_plus', 'image_path_soc'], False),
    'heuristicsplit_elipsesplus.onlyenv': ('onlyenv', 120, "../data/all_pepper_data_train.pkl", "../data/all_pepper_data_test_equal.pkl", [get_transform((144,256), IMAGENET_NORM)], ['image_path_env_plus'], False),
}
    
for name, (ablation, buffer_size, train_val_path, test_path, transform_list, img_path_cols, scene_as_label) in testing_scenarios.items():
        train_df = pd.read_pickle(train_val_path)
        test_df = pd.read_pickle(test_path)
        branch='mobilenetv2'
        seed=42
        set_seed(seed)
        grad_clipping=True
        batch=(32, 64, 64)
        buffer_size=buffer_size
        branch_norm=True
        earlystopping=True
        epochs=20
        alldomains=False
        scene_as_label=scene_as_label

        # df["image_path"] = df["image_path"].str.replace(
        #     r"^../data/images/",
        #     "../data/perturbations/environment/",
        #     regex=True
        # )
        # df['image_path_env'] = df['image_path']


        domain_dataloaders = get_domain_dataloaders(train_df, seed=seed, batch_sizes=batch, img_path_cols=img_path_cols, transforms=transform_list, num_workers=0, include_test=test_df, set_first_element_as_domain_label=scene_as_label)

        if alldomains:
            domain_dataloaders = combine_all_dataloaders(domain_dataloaders)
            domains = ['AllDomains']

        print(f"\nTesting: {name} Ablation: {ablation}")
        setup = {'branch':branch} 
        if ablation != 'base':
            setup['ablation'] = 'focus'

        if ablation == 'onlysoc':
            setup['ablation'] = 'scene'
        elif ablation == 'onlyenv':
            setup['ablation'] = 'focus'

        if scene_as_label:
            setup['scene'] = 'label'
        dropout_rate=0.3
        model = DualBranchModel(dropout_rate=dropout_rate, setup=setup, branch_norm=branch_norm)
        dual_model = model.to(device)
        trainable_params = [p for p in dual_model.parameters() if p.requires_grad]
        lr=1e-3
        optimizer = torch.optim.Adam(trainable_params, lr=lr)
        buffer = NaiveRehearsalBuffer(buffer_size=buffer_size)

        epochs=epochs
        exp_name = f"{name}_{buffer_size=}_{epochs=}_{seed=}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
        
        scheduler=(get_linear_schedule_with_warmup, 0.05)
        refresh_optimiser=False

        dualbranch_kwargs = {
                'mse_criterion': nn.MSELoss(),
            }

        config = {
            "model": {
                 "name": str(type(model)),
                 "setup": setup,
                 "branch_norm":branch_norm,
                 "dropout_rate":dropout_rate,
            },
            "buffer": str(type(buffer)),
            "buffer_size": buffer_size,
            "optimizer": str(type(optimizer)),
            "learning_rate": lr,
            "scheduler": {
                "type": "transformers.get_linear_schedule_with_warmup",
                "warmup": scheduler[1],
            },
            "device": str(device),
            "loss": str(dualbranch_kwargs['mse_criterion']),
            "training_mode": "noCL" if alldomains else "CL",
            "seed": seed,
            "train_val_df": train_val_path,
            "test_df": test_path,
            "input_columns": img_path_cols,
            "input_transforms": [serialize_transform(x) for x in transform_list],
            "batch_size": batch,
            "epochs": epochs,
            "early_stopping": {
                 "patience":15,
                 "delta":1e-3,
            },
            "gradient_clipping": grad_clipping,
            "refresh_optimiser": refresh_optimiser,
        }

        with open(f"../checkpoints/{exp_name}_config.json", "w") as f:
            json.dump(config, f, indent=4)

        unified_train_loop(
            model=dual_model,
            domains=domains,
            domain_dataloaders=domain_dataloaders,
            buffer=buffer,
            optimizer=optimizer,
            device=device,
            batch_fn=heuristic_dualbranch_batch,
            batch_kwargs=dualbranch_kwargs,
            num_epochs=epochs,
            exp_name=exp_name,
            gradient_clipping=grad_clipping,
            checkpoint_dir="../checkpoints",
            validation_set='val',
            scheduler=scheduler,
            refresh_optimiser=refresh_optimiser,
            early_stopping=earlystopping,
        )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")    

domains = ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']

testing_scenarios = {
    'heuristicsplit_elipsesplus.base': ('base', 120, "../data/pepper_data.pkl", "../data/pepper_data.pkl", [get_transform((144,256), IMAGENET_NORM), get_transform((144,256), IMAGENET_NORM)], ['image_path_env_plus', 'image_path_soc'], False),
    'heuristicsplit.nomask': ('nomask', 120, "../data/pepper_data.pkl", "../data/pepper_data.pkl", [get_transform((144,256), IMAGENET_NORM)], ['image_path'], False),
    'heuristicsplit_elipsesplus.onlyenv': ('onlyenv', 120, "../data/pepper_data.pkl", "../data/pepper_data.pkl", [get_transform((144,256), IMAGENET_NORM)], ['image_path_env_plus'], False),
    'heuristicsplit.onlysoc': ('onlysoc', 120, "../data/pepper_data.pkl", "../data/pepper_data.pkl", [get_transform((144,256), IMAGENET_NORM)], ['image_path_soc'], False),
    'robotfocus.base': ('base', 94, "../data/robotfocus_pepper_data.pkl", "../data/robotfocus_pepper_data.pkl", [get_transform((144,256), IMAGENET_NORM), get_transform((128,128), IMAGENET_NORM)], ['image_path_scene', 'image_path_focus_x2'], False),
    'robotfocus.onlysoc': ('onlysoc', 94, "../data/robotfocus_pepper_data.pkl", "../data/robotfocus_pepper_data.pkl", [get_transform((128,128), IMAGENET_NORM)], ['image_path_focus_x2'], False),
}
    
for name, (ablation, buffer_size, train_val_path, test_path, transform_list, img_path_cols, scene_as_label) in testing_scenarios.items():
        train_df = pd.read_pickle(train_val_path)
        test_df = pd.read_pickle(test_path)
        branch='mobilenetv2'
        seed=42
        set_seed(seed)
        grad_clipping=True
        batch=(32, 64, 64)
        buffer_size=buffer_size
        branch_norm=True
        earlystopping=True
        epochs=20
        alldomains=False
        scene_as_label=scene_as_label

        # df["image_path"] = df["image_path"].str.replace(
        #     r"^../data/images/",
        #     "../data/perturbations/environment/",
        #     regex=True
        # )
        # df['image_path_env'] = df['image_path']

        fold_dataloaders = get_crossvalidation_domain_loaders(train_df, folds=5, seed=seed, batch_sizes=batch, img_path_cols=img_path_cols, transforms=transform_list, num_workers=0, set_first_element_as_domain_label=scene_as_label, pin_memory=False)
        for fold, domain_dataloaders in fold_dataloaders.items():
        # domain_dataloaders = get_domain_dataloaders(train_df, seed=seed, batch_sizes=batch, img_path_cols=img_path_cols, transforms=transform_list, num_workers=0, include_test=test_df, set_first_element_as_domain_label=scene_as_label)

            if alldomains:
                domain_dataloaders = combine_all_dataloaders(domain_dataloaders)
                domains = ['AllDomains']

            print(f"\nTesting: {name} Ablation: {ablation}")
            setup = {'branch':branch} 
            if ablation != 'base':
                setup['ablation'] = 'focus'

            if ablation == 'onlysoc':
                setup['ablation'] = 'scene'
            elif ablation == 'onlyenv':
                setup['ablation'] = 'focus'

            if scene_as_label:
                setup['scene'] = 'label'
            dropout_rate=0.3
            model = DualBranchModel(dropout_rate=dropout_rate, setup=setup, branch_norm=branch_norm)
            dual_model = model.to(device)
            trainable_params = [p for p in dual_model.parameters() if p.requires_grad]
            lr=1e-3
            optimizer = torch.optim.Adam(trainable_params, lr=lr)
            buffer = NaiveRehearsalBuffer(buffer_size=buffer_size)

            epochs=epochs
            exp_name = f"{name}_{buffer_size=}_{epochs=}_{seed=}_{fold=}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
            
            scheduler=(get_linear_schedule_with_warmup, 0.05)
            refresh_optimiser=False

            dualbranch_kwargs = {
                    'mse_criterion': nn.MSELoss(),
                }

            config = {
                "model": {
                    "name": str(type(model)),
                    "setup": setup,
                    "branch_norm":branch_norm,
                    "dropout_rate":dropout_rate,
                },
                "buffer": str(type(buffer)),
                "buffer_size": buffer_size,
                "optimizer": str(type(optimizer)),
                "learning_rate": lr,
                "scheduler": {
                    "type": "transformers.get_linear_schedule_with_warmup",
                    "warmup": scheduler[1],
                },
                "device": str(device),
                "loss": str(dualbranch_kwargs['mse_criterion']),
                "training_mode": "noCL" if alldomains else "CL",
                "seed": seed,
                "train_val_df": train_val_path,
                "test_df": test_path,
                "input_columns": img_path_cols,
                "input_transforms": [serialize_transform(x) for x in transform_list],
                "batch_size": batch,
                "epochs": epochs,
                "early_stopping": {
                    "patience":15,
                    "delta":1e-3,
                },
                "gradient_clipping": grad_clipping,
                "refresh_optimiser": refresh_optimiser,
            }

            with open(f"../checkpoints/{exp_name}_config.json", "w") as f:
                json.dump(config, f, indent=4)

            unified_train_loop(
                model=dual_model,
                domains=domains,
                domain_dataloaders=domain_dataloaders,
                buffer=buffer,
                optimizer=optimizer,
                device=device,
                batch_fn=heuristic_dualbranch_batch,
                batch_kwargs=dualbranch_kwargs,
                num_epochs=epochs,
                exp_name=exp_name,
                gradient_clipping=grad_clipping,
                checkpoint_dir="../checkpoints",
                validation_set='val',
                scheduler=scheduler,
                refresh_optimiser=refresh_optimiser,
                early_stopping=earlystopping,
            )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")    

domains = ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']

testing_scenarios = {
    'heuristicsplit_boxes_plus.base': ('base', 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False),
    # 'heuristicsplit_boxes_plus.nomask': ('nomask', 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)], ['image_path'], False),
    'heuristicsplit_boxes_plus.onlyenv': ('onlyenv', 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)], ['image_path_env_boxes_plus'], False),
    # 'heuristicsplit_boxes_plus.onlysoc': ('onlysoc', 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)], ['image_path_soc'], False),
}
    
for name, (ablation, buffer_size, train_val_path, test_path, hdf5_path, transform_list, img_path_cols, scene_as_label) in testing_scenarios.items():
        train_df = pd.read_pickle(train_val_path) if train_val_path is not None else None
        test_df = pd.read_pickle(test_path) if test_path is not None else None
        hdf5_dataset_path = hdf5_path
        branch='mobilenetv2'
        seed=42
        set_seed(seed)
        grad_clipping=True
        batch=(32, 64, 64)
        buffer_size=buffer_size
        branch_norm=True
        earlystopping=True
        epochs=20
        alldomains=False
        scene_as_label=scene_as_label
        pin_memory=True
        persistent_workers=False
        num_workers=0


        # fold_dataloaders = get_crossvalidation_domain_loaders(train_df, folds=5, seed=seed, batch_sizes=batch, img_path_cols=img_path_cols, transforms=transform_list, num_workers=0, set_first_element_as_domain_label=scene_as_label, pin_memory=False)
        # for fold, domain_dataloaders in fold_dataloaders.items():
        if hdf5_path:
            domain_dataloaders = get_domain_dataloaders_from_hdf5(hdf5_path=hdf5_dataset_path, domains=domains, img_path_cols=img_path_cols, num_workers=num_workers, set_first_element_as_domain_label=scene_as_label, pin_memory=pin_memory, persistent_workers=persistent_workers)
        else:
            domain_dataloaders = get_domain_dataloaders(train_df, seed=seed, batch_sizes=batch, img_path_cols=img_path_cols, transforms=transform_list, num_workers=num_workers, include_test=test_df, set_first_element_as_domain_label=scene_as_label, pin_memory=pin_memory, persistent_workers=persistent_workers)
        
        
        if alldomains:
            domain_dataloaders = combine_all_dataloaders(domain_dataloaders)
            domains = ['AllDomains']

        print(f"\nTesting: {name} Ablation: {ablation}")
        setup = {'branch':branch} 

        if ablation == 'nomask':
            setup['ablation'] = 'focus'
        elif ablation == 'onlysoc':
            setup['ablation'] = 'scene'
        elif ablation == 'onlyenv':
            setup['ablation'] = 'focus'
        else:
            setup['ablation'] = False

        if scene_as_label:
            setup['scene'] = 'label'
        dropout_rate=0.3
        model = DualBranchModel(dropout_rate=dropout_rate, setup=setup, branch_norm=branch_norm)
        dual_model = model.to(device)
        trainable_params = [p for p in dual_model.parameters() if p.requires_grad]
        lr=1e-3
        optimizer = torch.optim.Adam(trainable_params, lr=lr)
        buffer = NaiveRehearsalBuffer(buffer_size=buffer_size)

        epochs=epochs
        exp_name = f"{name}_{buffer_size=}_{epochs=}_{seed=}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
        
        scheduler=(get_linear_schedule_with_warmup, 0.05)
        refresh_optimiser=False

        dualbranch_kwargs = {
                'mse_criterion': nn.MSELoss(),
            }

        config = {
            "model": {
                "name": str(type(model)),
                "setup": setup,
                "branch_norm":branch_norm,
                "dropout_rate":dropout_rate,
            },
            "buffer": str(type(buffer)),
            "buffer_size": buffer_size,
            "optimizer": str(type(optimizer)),
            "learning_rate": lr,
            "scheduler": {
                "type": "transformers.get_linear_schedule_with_warmup",
                "warmup": scheduler[1],
            },
            "device": str(device),
            "loss": str(dualbranch_kwargs['mse_criterion']),
            "training_mode": "noCL" if alldomains else "CL",
            "seed": seed,
            "domains_order": domains,
            "train_val_df": train_val_path,
            "test_df": test_path,
            "hdf5_dataset_path": hdf5_dataset_path,
            "input_columns": img_path_cols,
            "input_transforms": [serialize_transform(x) for x in transform_list],
            "dataloader": {
                "batch_size": batch,
                "num_workers":num_workers,
                "pin_memory": pin_memory,
                "persistent_workers": persistent_workers,
            },
            "epochs": epochs,
            "early_stopping": {
                "patience":15,
                "delta":1e-3,
            },
            "gradient_clipping": grad_clipping,
            "refresh_optimiser": refresh_optimiser,
        }

        with open(f"../checkpoints/{exp_name}_config.json", "w") as f:
            json.dump(config, f, indent=4)

        unified_train_loop(
            model=dual_model,
            domains=domains,
            domain_dataloaders=domain_dataloaders,
            buffer=buffer,
            optimizer=optimizer,
            device=device,
            batch_fn=heuristic_dualbranch_batch,
            batch_kwargs=dualbranch_kwargs,
            num_epochs=epochs,
            exp_name=exp_name,
            gradient_clipping=grad_clipping,
            checkpoint_dir="../checkpoints",
            validation_set='val',
            scheduler=scheduler,
            refresh_optimiser=refresh_optimiser,
            early_stopping=earlystopping,
        )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")    

domains = ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']

testing_scenarios = {
    'boxes_plus_concatfusion.base': ('base', 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2', 'fusion':'concat'}),
    'boxes_plus_sumfusion.base': ('base', 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2', 'fusion':'weighted_sum_alpha'}),
    'boxes_plus_gatefusion.base': ('base', 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2', 'fusion':'gated'}),
    'boxes_plus_cccloss.base': ('base', 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, CCCLoss(), {'branch':'mobilenetv2', 'fusion':'concat'}),
    'boxes_plus_compoundloss.base': ('base', 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, CompoundLossFixedAlpha(alpha=0.4), {'branch':'mobilenetv2', 'fusion':'concat'}),
    'boxes_plus_weighted_mseloss.base': ('base', 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, MSELossWeighted(weighting_func=symmetric_mean_weighting), {'branch':'mobilenetv2', 'fusion':'concat'}),
    'boxes_plus_asymetric_compoundloss.base': ('base', 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, CompoundLossFixedAlpha(alpha=0.4, weighting_func=asymmetric_domain_weighting), {'branch':'mobilenetv2', 'fusion':'concat'}),
    'boxes_plus_learnable_compoundloss.base': ('base', 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, CompoundLossLearnableAlpha().to(device), {'branch':'mobilenetv2', 'fusion':'concat'}),
    'boxes_plus_learnable_asymetric_compoundloss.base': ('base', 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, CompoundLossLearnableAlpha(weighting_func=asymmetric_domain_weighting).to(device), {'branch':'mobilenetv2', 'fusion':'concat'}),
    'boxes_plus_fatefusion_lr_asym_compoundloss.base': ('base', 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, CompoundLossLearnableAlpha(weighting_func=asymmetric_domain_weighting).to(device), {'branch':'mobilenetv2', 'fusion':'gated'}),

}
    
for name, (ablation, buffer_size, train_val_path, test_path, hdf5_path, transform_list, img_path_cols, scene_as_label, loss_fn, setup) in testing_scenarios.items():
        train_df = pd.read_pickle(train_val_path) if train_val_path is not None else None
        test_df = pd.read_pickle(test_path) if test_path is not None else None
        hdf5_dataset_path = hdf5_path
        setup=setup #{'branch':'mobilenetv2'}
        seed=42
        set_seed(seed)
        grad_clipping=True
        batch=(32, 64, 64)
        buffer_size=buffer_size
        branch_norm=True
        earlystopping=True
        epochs=30
        alldomains=False
        scene_as_label=scene_as_label
        pin_memory=True
        persistent_workers=False
        num_workers=0


        # fold_dataloaders = get_crossvalidation_domain_loaders(train_df, folds=5, seed=seed, batch_sizes=batch, img_path_cols=img_path_cols, transforms=transform_list, num_workers=0, set_first_element_as_domain_label=scene_as_label, pin_memory=False)
        # for fold, domain_dataloaders in fold_dataloaders.items():
        if hdf5_path:
            domain_dataloaders = get_domain_dataloaders_from_hdf5(hdf5_path=hdf5_dataset_path, domains=domains, img_path_cols=img_path_cols, num_workers=num_workers, set_first_element_as_domain_label=scene_as_label, pin_memory=pin_memory, persistent_workers=persistent_workers)
        else:
            domain_dataloaders = get_domain_dataloaders(train_df, seed=seed, batch_sizes=batch, img_path_cols=img_path_cols, transforms=transform_list, num_workers=num_workers, include_test=test_df, set_first_element_as_domain_label=scene_as_label, pin_memory=pin_memory, persistent_workers=persistent_workers)
        
        
        if alldomains:
            domain_dataloaders = combine_all_dataloaders(domain_dataloaders)
            domains = ['AllDomains']

        print(f"\nTesting: {name} Ablation: {ablation}")

        if ablation == 'nomask':
            setup['ablation'] = 'focus'
        elif ablation == 'onlysoc':
            setup['ablation'] = 'scene'
        elif ablation == 'onlyenv':
            setup['ablation'] = 'focus'
        else:
            setup['ablation'] = False

        if scene_as_label:
            setup['scene'] = 'label'
        dropout_rate=0.3
        model = DualBranchModel_fusions(dropout_rate=dropout_rate, setup=setup, branch_norm=branch_norm)
        dual_model = model.to(device)
        trainable_params = [p for p in dual_model.parameters() if p.requires_grad]
        lr=1e-3
        optimizer = torch.optim.Adam(trainable_params, lr=lr)
        buffer = NaiveRehearsalBuffer(buffer_size=buffer_size)

        epochs=epochs
        exp_name = f"{name}_{buffer_size=}_{epochs=}_{seed=}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
        
        scheduler=(get_linear_schedule_with_warmup, 0.05)
        refresh_optimiser=False

        dualbranch_kwargs = {
                'mse_criterion': loss_fn #nn.MSELoss(),
            }

        config = {
            "model": {
                "name": str(type(model)),
                "setup": setup,
                "branch_norm":branch_norm,
                "dropout_rate":dropout_rate,
            },
            "buffer": str(type(buffer)),
            "buffer_size": buffer_size,
            "optimizer": str(type(optimizer)),
            "learning_rate": lr,
            "scheduler": {
                "type": "transformers.get_linear_schedule_with_warmup",
                "warmup": scheduler[1],
            },
            "device": str(device),
            "loss": str(dualbranch_kwargs['mse_criterion']),
            "training_mode": "noCL" if alldomains else "CL",
            "seed": seed,
            "domains_order": domains,
            "train_val_df": train_val_path,
            "test_df": test_path,
            "hdf5_dataset_path": hdf5_dataset_path,
            "input_columns": img_path_cols,
            "input_transforms": [serialize_transform(x) for x in transform_list],
            "dataloader": {
                "batch_size": batch,
                "num_workers":num_workers,
                "pin_memory": pin_memory,
                "persistent_workers": persistent_workers,
            },
            "epochs": epochs,
            "early_stopping": {
                "patience":15,
                "delta":1e-3,
            },
            "gradient_clipping": grad_clipping,
            "refresh_optimiser": refresh_optimiser,
        }

        with open(f"../checkpoints/{exp_name}_config.json", "w") as f:
            json.dump(config, f, indent=4)

        unified_train_loop(
            model=dual_model,
            domains=domains,
            domain_dataloaders=domain_dataloaders,
            buffer=buffer,
            optimizer=optimizer,
            device=device,
            batch_fn=heuristic_dualbranch_batch,
            batch_kwargs=dualbranch_kwargs,
            num_epochs=epochs,
            exp_name=exp_name,
            gradient_clipping=grad_clipping,
            checkpoint_dir="../checkpoints",
            validation_set='val',
            scheduler=scheduler,
            refresh_optimiser=refresh_optimiser,
            early_stopping=earlystopping,
        )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")    

domains = ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']

testing_scenarios = {
    'boxes_plus_cccloss.base': ('base', 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, CCCLoss(), {'branch':'mobilenetv2', 'fusion':'concat'}),
    'boxes_plus_04compoundloss.base': ('base', 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, CompoundLossFixedAlpha(alpha=0.4), {'branch':'mobilenetv2', 'fusion':'concat'}),
    'boxes_plus_02compoundloss.base': ('base', 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, CompoundLossFixedAlpha(alpha=0.2), {'branch':'mobilenetv2', 'fusion':'concat'}),
    'boxes_plus_weighted_mseloss.base': ('base', 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, MSELossWeighted(weighting_func=symmetric_extreme_weighting), {'branch':'mobilenetv2', 'fusion':'concat'}),
    'boxes_plus_asymetric_04compoundloss.base': ('base', 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, CompoundLossFixedAlpha(alpha=0.4, weighting_func=asymmetric_extreme_weighting), {'branch':'mobilenetv2', 'fusion':'concat'}),
    'boxes_plus_learnable_asymetric_compoundloss.base': ('base', 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, CompoundLossLearnableAlpha(weighting_func=asymmetric_extreme_weighting).to(device), {'branch':'mobilenetv2', 'fusion':'concat'}),
}
    
for name, (ablation, buffer_size, train_val_path, test_path, hdf5_path, transform_list, img_path_cols, scene_as_label, loss_fn, setup) in testing_scenarios.items():
        train_df = pd.read_pickle(train_val_path) if train_val_path is not None else None
        test_df = pd.read_pickle(test_path) if test_path is not None else None
        hdf5_dataset_path = hdf5_path
        setup=setup #{'branch':'mobilenetv2'}
        seed=42
        set_seed(seed)
        grad_clipping=True
        batch=(32, 64, 64)
        buffer_size=buffer_size
        branch_norm=True
        earlystopping=True
        epochs=40
        alldomains=False
        scene_as_label=scene_as_label
        pin_memory=True
        persistent_workers=False
        num_workers=0


        # fold_dataloaders = get_crossvalidation_domain_loaders(train_df, folds=5, seed=seed, batch_sizes=batch, img_path_cols=img_path_cols, transforms=transform_list, num_workers=0, set_first_element_as_domain_label=scene_as_label, pin_memory=False)
        # for fold, domain_dataloaders in fold_dataloaders.items():
        if hdf5_path:
            domain_dataloaders = get_domain_dataloaders_from_hdf5(hdf5_path=hdf5_dataset_path, domains=domains, img_path_cols=img_path_cols, num_workers=num_workers, set_first_element_as_domain_label=scene_as_label, pin_memory=pin_memory, persistent_workers=persistent_workers)
        else:
            domain_dataloaders = get_domain_dataloaders(train_df, seed=seed, batch_sizes=batch, img_path_cols=img_path_cols, transforms=transform_list, num_workers=num_workers, include_test=test_df, set_first_element_as_domain_label=scene_as_label, pin_memory=pin_memory, persistent_workers=persistent_workers)
        
        
        if alldomains:
            domain_dataloaders = combine_all_dataloaders(domain_dataloaders)
            domains = ['AllDomains']

        print(f"\nTesting: {name} Ablation: {ablation}")

        if ablation == 'nomask':
            setup['ablation'] = 'focus'
        elif ablation == 'onlysoc':
            setup['ablation'] = 'scene'
        elif ablation == 'onlyenv':
            setup['ablation'] = 'focus'
        else:
            setup['ablation'] = False

        if scene_as_label:
            setup['scene'] = 'label'
        dropout_rate=0.3
        model = DualBranchModel_fusions(dropout_rate=dropout_rate, setup=setup, branch_norm=branch_norm)
        dual_model = model.to(device)
        trainable_params = [p for p in dual_model.parameters() if p.requires_grad]
        lr=1e-3
        optimizer = torch.optim.Adam(trainable_params, lr=lr)
        buffer = NaiveRehearsalBuffer(buffer_size=buffer_size)

        epochs=epochs
        exp_name = f"{name}_{buffer_size=}_{epochs=}_{seed=}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
        
        scheduler=(get_linear_schedule_with_warmup, 0.05)
        refresh_optimiser=False

        dualbranch_kwargs = {
                'mse_criterion': loss_fn #nn.MSELoss(),
            }

        config = {
            "model": {
                "name": str(type(model)),
                "setup": setup,
                "branch_norm":branch_norm,
                "dropout_rate":dropout_rate,
            },
            "buffer": str(type(buffer)),
            "buffer_size": buffer_size,
            "optimizer": str(type(optimizer)),
            "learning_rate": lr,
            "scheduler": {
                "type": "transformers.get_linear_schedule_with_warmup",
                "warmup": scheduler[1],
            },
            "device": str(device),
            "loss": str(dualbranch_kwargs['mse_criterion']),
            "training_mode": "noCL" if alldomains else "CL",
            "seed": seed,
            "domains_order": domains,
            "train_val_df": train_val_path,
            "test_df": test_path,
            "hdf5_dataset_path": hdf5_dataset_path,
            "input_columns": img_path_cols,
            "input_transforms": [serialize_transform(x) for x in transform_list],
            "dataloader": {
                "batch_size": batch,
                "num_workers":num_workers,
                "pin_memory": pin_memory,
                "persistent_workers": persistent_workers,
            },
            "epochs": epochs,
            "early_stopping": {
                "patience":15,
                "delta":1e-3,
            },
            "gradient_clipping": grad_clipping,
            "refresh_optimiser": refresh_optimiser,
        }

        with open(f"../checkpoints/{exp_name}_config.json", "w") as f:
            json.dump(config, f, indent=4)

        unified_train_loop(
            model=dual_model,
            domains=domains,
            domain_dataloaders=domain_dataloaders,
            buffer=buffer,
            optimizer=optimizer,
            device=device,
            batch_fn=heuristic_dualbranch_batch,
            batch_kwargs=dualbranch_kwargs,
            num_epochs=epochs,
            exp_name=exp_name,
            gradient_clipping=grad_clipping,
            checkpoint_dir="../checkpoints",
            validation_set='val',
            scheduler=scheduler,
            refresh_optimiser=refresh_optimiser,
            early_stopping=earlystopping,
        )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")    

domains = ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']

testing_scenarios = {
    'boxes_plus_coordconv.base': ('base', 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2', 'coordconv':True, 'fusion':'concat'}),
    'boxes_plus_coordattention.base': ('base', 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2', 'coordattention':True, 'fusion':'concat'}),
    'boxes_plus_coordconv_coordattention.base': ('base', 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2', 'coordconv':True, 'coordattention':True, 'fusion':'concat'}),
}
    
for name, (ablation, buffer_size, train_val_path, test_path, hdf5_path, transform_list, img_path_cols, scene_as_label, loss_fn, setup) in testing_scenarios.items():
        train_df = pd.read_pickle(train_val_path) if train_val_path is not None else None
        test_df = pd.read_pickle(test_path) if test_path is not None else None
        hdf5_dataset_path = hdf5_path
        setup=setup #{'branch':'mobilenetv2'}
        seed=42
        set_seed(seed)
        grad_clipping=True
        batch=(32, 64, 64)
        buffer_size=buffer_size
        branch_norm=True
        earlystopping=True
        epochs=40
        alldomains=False
        scene_as_label=scene_as_label
        pin_memory=True
        persistent_workers=False
        num_workers=0


        # fold_dataloaders = get_crossvalidation_domain_loaders(train_df, folds=5, seed=seed, batch_sizes=batch, img_path_cols=img_path_cols, transforms=transform_list, num_workers=0, set_first_element_as_domain_label=scene_as_label, pin_memory=False)
        # for fold, domain_dataloaders in fold_dataloaders.items():
        if hdf5_path:
            domain_dataloaders = get_domain_dataloaders_from_hdf5(hdf5_path=hdf5_dataset_path, domains=domains, img_path_cols=img_path_cols, num_workers=num_workers, set_first_element_as_domain_label=scene_as_label, pin_memory=pin_memory, persistent_workers=persistent_workers)
        else:
            domain_dataloaders = get_domain_dataloaders(train_df, seed=seed, batch_sizes=batch, img_path_cols=img_path_cols, transforms=transform_list, num_workers=num_workers, include_test=test_df, set_first_element_as_domain_label=scene_as_label, pin_memory=pin_memory, persistent_workers=persistent_workers)
        
        
        if alldomains:
            domain_dataloaders = combine_all_dataloaders(domain_dataloaders)
            domains = ['AllDomains']

        print(f"\nTesting: {name} Ablation: {ablation}")

        if ablation == 'nomask':
            setup['ablation'] = 'focus'
        elif ablation == 'onlysoc':
            setup['ablation'] = 'scene'
        elif ablation == 'onlyenv':
            setup['ablation'] = 'focus'
        else:
            setup['ablation'] = False

        if scene_as_label:
            setup['scene'] = 'label'
        dropout_rate=0.3
        model = DualBranchModel_fusions(dropout_rate=dropout_rate, setup=setup, branch_norm=branch_norm)
        dual_model = model.to(device)
        trainable_params = [p for p in dual_model.parameters() if p.requires_grad]
        lr=1e-3
        optimizer = torch.optim.Adam(trainable_params, lr=lr)
        buffer = NaiveRehearsalBuffer(buffer_size=buffer_size)

        epochs=epochs
        exp_name = f"{name}_{buffer_size=}_{epochs=}_{seed=}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
        
        scheduler=(get_linear_schedule_with_warmup, 0.05)
        refresh_optimiser=False

        dualbranch_kwargs = {
                'mse_criterion': loss_fn #nn.MSELoss(),
            }

        config = {
            "model": {
                "name": str(type(model)),
                "setup": setup,
                "branch_norm":branch_norm,
                "dropout_rate":dropout_rate,
            },
            "buffer": str(type(buffer)),
            "buffer_size": buffer_size,
            "optimizer": str(type(optimizer)),
            "learning_rate": lr,
            "scheduler": {
                "type": "transformers.get_linear_schedule_with_warmup",
                "warmup": scheduler[1],
            },
            "device": str(device),
            "loss": str(dualbranch_kwargs['mse_criterion']),
            "training_mode": "noCL" if alldomains else "CL",
            "seed": seed,
            "domains_order": domains,
            "train_val_df": train_val_path,
            "test_df": test_path,
            "hdf5_dataset_path": hdf5_dataset_path,
            "input_columns": img_path_cols,
            "input_transforms": [serialize_transform(x) for x in transform_list],
            "dataloader": {
                "batch_size": batch,
                "num_workers":num_workers,
                "pin_memory": pin_memory,
                "persistent_workers": persistent_workers,
            },
            "epochs": epochs,
            "early_stopping": {
                "patience":15,
                "delta":1e-3,
            },
            "gradient_clipping": grad_clipping,
            "refresh_optimiser": refresh_optimiser,
        }

        with open(f"../checkpoints/{exp_name}_config.json", "w") as f:
            json.dump(config, f, indent=4)

        unified_train_loop(
            model=dual_model,
            domains=domains,
            domain_dataloaders=domain_dataloaders,
            buffer=buffer,
            optimizer=optimizer,
            device=device,
            batch_fn=heuristic_dualbranch_batch,
            batch_kwargs=dualbranch_kwargs,
            num_epochs=epochs,
            exp_name=exp_name,
            gradient_clipping=grad_clipping,
            checkpoint_dir="../checkpoints",
            validation_set='val',
            scheduler=scheduler,
            refresh_optimiser=refresh_optimiser,
            early_stopping=earlystopping,
        )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")    

domains = ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']

testing_scenarios = {
    'order_default.base': ('base', 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']),
    'order_complexity.base': ('base', 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, ['Hallway', 'SmallOffice', 'MeetingRoom', 'BigOffice-3', 'BigOffice-2', 'Home']),
    'order_diff1.base': ('base', 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, ['MeetingRoom', 'Home', 'Hallway', 'BigOffice-2', 'SmallOffice', 'BigOffice-3']),
    'order_diff2.base': ('base', 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, ['BigOffice-3', 'SmallOffice', 'Home', 'Hallway', 'MeetingRoom', 'BigOffice-2']),
    'order_midhouse.base': ('base', 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, ['BigOffice-2', 'BigOffice-3', 'Hallway', 'Home', 'MeetingRoom', 'SmallOffice']),
    'buffersize0.base': ('base', 0, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']),
}
    
for name, (ablation, buffer_size, train_val_path, test_path, hdf5_path, transform_list, img_path_cols, scene_as_label, loss_fn, setup, domains) in testing_scenarios.items():
        train_df = pd.read_pickle(train_val_path) if train_val_path is not None else None
        test_df = pd.read_pickle(test_path) if test_path is not None else None
        hdf5_dataset_path = hdf5_path
        setup=setup #{'branch':'mobilenetv2'}
        seed=42
        set_seed(seed)
        grad_clipping=True
        batch=(32, 64, 64)
        buffer_size=buffer_size
        branch_norm=True
        earlystopping=True
        epochs=40
        alldomains=False
        scene_as_label=scene_as_label
        pin_memory=True
        persistent_workers=False
        num_workers=0


        # fold_dataloaders = get_crossvalidation_domain_loaders(train_df, folds=5, seed=seed, batch_sizes=batch, img_path_cols=img_path_cols, transforms=transform_list, num_workers=0, set_first_element_as_domain_label=scene_as_label, pin_memory=False)
        # for fold, domain_dataloaders in fold_dataloaders.items():
        if hdf5_path:
            domain_dataloaders = get_domain_dataloaders_from_hdf5(hdf5_path=hdf5_dataset_path, domains=domains, img_path_cols=img_path_cols, num_workers=num_workers, set_first_element_as_domain_label=scene_as_label, pin_memory=pin_memory, persistent_workers=persistent_workers)
        else:
            domain_dataloaders = get_domain_dataloaders(train_df, seed=seed, batch_sizes=batch, img_path_cols=img_path_cols, transforms=transform_list, num_workers=num_workers, include_test=test_df, set_first_element_as_domain_label=scene_as_label, pin_memory=pin_memory, persistent_workers=persistent_workers)
        
        
        if alldomains:
            domain_dataloaders = combine_all_dataloaders(domain_dataloaders)
            domains = ['AllDomains']

        print(f"\nTesting: {name} Ablation: {ablation}")

        if ablation == 'nomask':
            setup['ablation'] = 'focus'
        elif ablation == 'onlysoc':
            setup['ablation'] = 'scene'
        elif ablation == 'onlyenv':
            setup['ablation'] = 'focus'
        else:
            setup['ablation'] = False

        if scene_as_label:
            setup['scene'] = 'label'
        dropout_rate=0.3
        model = DualBranchModel(dropout_rate=dropout_rate, setup=setup, branch_norm=branch_norm)
        dual_model = model.to(device)
        trainable_params = [p for p in dual_model.parameters() if p.requires_grad]
        lr=1e-3
        optimizer = torch.optim.Adam(trainable_params, lr=lr)
        buffer = NaiveRehearsalBuffer(buffer_size=buffer_size)

        epochs=epochs
        exp_name = f"{name}_{buffer_size=}_{epochs=}_{seed=}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
        
        scheduler=(get_linear_schedule_with_warmup, 0.05)
        refresh_optimiser=False

        dualbranch_kwargs = {
                'mse_criterion': loss_fn #nn.MSELoss(),
            }

        config = {
            "model": {
                "name": str(type(model)),
                "setup": setup,
                "branch_norm":branch_norm,
                "dropout_rate":dropout_rate,
            },
            "buffer": str(type(buffer)),
            "buffer_size": buffer_size,
            "optimizer": str(type(optimizer)),
            "learning_rate": lr,
            "scheduler": {
                "type": "transformers.get_linear_schedule_with_warmup",
                "warmup": scheduler[1],
            },
            "device": str(device),
            "loss": str(dualbranch_kwargs['mse_criterion']),
            "training_mode": "noCL" if alldomains else "CL",
            "seed": seed,
            "domains_order": domains,
            "train_val_df": train_val_path,
            "test_df": test_path,
            "hdf5_dataset_path": hdf5_dataset_path,
            "input_columns": img_path_cols,
            "input_transforms": [serialize_transform(x) for x in transform_list],
            "dataloader": {
                "batch_size": batch,
                "num_workers":num_workers,
                "pin_memory": pin_memory,
                "persistent_workers": persistent_workers,
            },
            "epochs": epochs,
            "early_stopping": {
                "patience":15,
                "delta":1e-3,
            },
            "gradient_clipping": grad_clipping,
            "refresh_optimiser": refresh_optimiser,
        }

        with open(f"../checkpoints/{exp_name}_config.json", "w") as f:
            json.dump(config, f, indent=4)

        unified_train_loop(
            model=dual_model,
            domains=domains,
            domain_dataloaders=domain_dataloaders,
            buffer=buffer,
            optimizer=optimizer,
            device=device,
            batch_fn=heuristic_dualbranch_batch,
            batch_kwargs=dualbranch_kwargs,
            num_epochs=epochs,
            exp_name=exp_name,
            gradient_clipping=grad_clipping,
            checkpoint_dir="../checkpoints",
            validation_set='val',
            scheduler=scheduler,
            refresh_optimiser=refresh_optimiser,
            early_stopping=earlystopping,
        )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")    

domains = ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']

testing_scenarios = {
    'test_bbox_plus_e60.base': ('base', 60, 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']),
    'test_bbox_plus_e10.base': ('base', 10, 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']),
    'test_bbox_plus_buff240.base': ('base', 40, 240, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']),
    'test_bbox_plus_buff60.base': ('base', 40, 60, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']),
}
    
for name, (ablation, epochs, buffer_size, train_val_path, test_path, hdf5_path, transform_list, img_path_cols, scene_as_label, loss_fn, setup, domains) in testing_scenarios.items():
        train_df = pd.read_pickle(train_val_path) if train_val_path is not None else None
        test_df = pd.read_pickle(test_path) if test_path is not None else None
        hdf5_dataset_path = hdf5_path
        setup=setup #{'branch':'mobilenetv2'}
        seed=42
        set_seed(seed)
        grad_clipping=True
        batch=(32, 64, 64)
        buffer_size=buffer_size
        branch_norm=True
        earlystopping=True
        epochs=epochs
        alldomains=False
        scene_as_label=scene_as_label
        pin_memory=True
        persistent_workers=False
        num_workers=0


        # fold_dataloaders = get_crossvalidation_domain_loaders(train_df, folds=5, seed=seed, batch_sizes=batch, img_path_cols=img_path_cols, transforms=transform_list, num_workers=0, set_first_element_as_domain_label=scene_as_label, pin_memory=False)
        # for fold, domain_dataloaders in fold_dataloaders.items():
        if hdf5_path:
            domain_dataloaders = get_domain_dataloaders_from_hdf5(hdf5_path=hdf5_dataset_path, domains=domains, img_path_cols=img_path_cols, num_workers=num_workers, set_first_element_as_domain_label=scene_as_label, pin_memory=pin_memory, persistent_workers=persistent_workers)
        else:
            domain_dataloaders = get_domain_dataloaders(train_df, seed=seed, batch_sizes=batch, img_path_cols=img_path_cols, transforms=transform_list, num_workers=num_workers, include_test=test_df, set_first_element_as_domain_label=scene_as_label, pin_memory=pin_memory, persistent_workers=persistent_workers)
        
        
        if alldomains:
            domain_dataloaders = combine_all_dataloaders(domain_dataloaders)
            domains = ['AllDomains']

        print(f"\nTesting: {name} Ablation: {ablation}")

        if ablation == 'nomask':
            setup['ablation'] = 'focus'
        elif ablation == 'onlysoc':
            setup['ablation'] = 'scene'
        elif ablation == 'onlyenv':
            setup['ablation'] = 'focus'
        else:
            setup['ablation'] = False

        if scene_as_label:
            setup['scene'] = 'label'
        dropout_rate=0.3
        model = DualBranchModel(dropout_rate=dropout_rate, setup=setup, branch_norm=branch_norm)
        dual_model = model.to(device)
        trainable_params = [p for p in dual_model.parameters() if p.requires_grad]
        lr=1e-3
        optimizer = torch.optim.Adam(trainable_params, lr=lr)
        buffer = NaiveRehearsalBuffer(buffer_size=buffer_size)

        epochs=epochs
        exp_name = f"{name}_{buffer_size=}_{epochs=}_{seed=}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
        
        scheduler=(get_linear_schedule_with_warmup, 0.05)
        refresh_optimiser=False

        dualbranch_kwargs = {
                'mse_criterion': loss_fn #nn.MSELoss(),
            }

        config = {
            "model": {
                "name": str(type(model)),
                "setup": setup,
                "branch_norm":branch_norm,
                "dropout_rate":dropout_rate,
            },
            "buffer": str(type(buffer)),
            "buffer_size": buffer_size,
            "optimizer": str(type(optimizer)),
            "learning_rate": lr,
            "scheduler": {
                "type": "transformers.get_linear_schedule_with_warmup",
                "warmup": scheduler[1],
            },
            "device": str(device),
            "loss": str(dualbranch_kwargs['mse_criterion']),
            "training_mode": "noCL" if alldomains else "CL",
            "seed": seed,
            "domains_order": domains,
            "train_val_df": train_val_path,
            "test_df": test_path,
            "hdf5_dataset_path": hdf5_dataset_path,
            "input_columns": img_path_cols,
            "input_transforms": [serialize_transform(x) for x in transform_list],
            "dataloader": {
                "batch_size": batch,
                "num_workers":num_workers,
                "pin_memory": pin_memory,
                "persistent_workers": persistent_workers,
            },
            "epochs": epochs,
            "early_stopping": {
                "patience":15,
                "delta":1e-3,
            },
            "gradient_clipping": grad_clipping,
            "refresh_optimiser": refresh_optimiser,
        }

        with open(f"../checkpoints/{exp_name}_config.json", "w") as f:
            json.dump(config, f, indent=4)

        unified_train_loop(
            model=dual_model,
            domains=domains,
            domain_dataloaders=domain_dataloaders,
            buffer=buffer,
            optimizer=optimizer,
            device=device,
            batch_fn=heuristic_dualbranch_batch,
            batch_kwargs=dualbranch_kwargs,
            num_epochs=epochs,
            exp_name=exp_name,
            gradient_clipping=grad_clipping,
            checkpoint_dir="../checkpoints",
            validation_set='val',
            scheduler=scheduler,
            refresh_optimiser=refresh_optimiser,
            early_stopping=earlystopping,
        )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")    

domains = ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']

testing_scenarios = {
    'test_e10.base': ('base', 10, 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}),
    'test_e40.base': ('base', 40, 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}),
    'test_e60.base': ('base', 60, 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}),
    'test_buff1600.base': ('base', 40, 1600, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}),
    'test_buff240.base': ('base', 40, 240, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}),
    'test_buff60.base': ('base', 40, 60, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}),
    'test_buff0.base': ('base', 40, 0, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}),
}
    
for name, (ablation, epochs, buffer_size, train_val_path, test_path, hdf5_path, transform_list, img_path_cols, scene_as_label, loss_fn, setup) in testing_scenarios.items():
        train_df = pd.read_pickle(train_val_path) if train_val_path is not None else None
        test_df = pd.read_pickle(test_path) if test_path is not None else None
        hdf5_dataset_path = hdf5_path
        setup=setup #{'branch':'mobilenetv2'}
        seed=42
        set_seed(seed)
        grad_clipping=True
        batch=(32, 64, 64)
        buffer_size=buffer_size
        branch_norm=True
        earlystopping=True
        epochs=epochs
        alldomains=False
        scene_as_label=scene_as_label
        pin_memory=True
        persistent_workers=False
        num_workers=0


        # fold_dataloaders = get_crossvalidation_domain_loaders(train_df, folds=5, seed=seed, batch_sizes=batch, img_path_cols=img_path_cols, transforms=transform_list, num_workers=0, set_first_element_as_domain_label=scene_as_label, pin_memory=False)
        # for fold, domain_dataloaders in fold_dataloaders.items():
        if hdf5_path:
            domain_dataloaders = get_domain_dataloaders_from_hdf5(hdf5_path=hdf5_dataset_path, domains=domains, img_path_cols=img_path_cols, num_workers=num_workers, set_first_element_as_domain_label=scene_as_label, pin_memory=pin_memory, persistent_workers=persistent_workers)
        else:
            domain_dataloaders = get_domain_dataloaders(train_df, seed=seed, batch_sizes=batch, img_path_cols=img_path_cols, transforms=transform_list, num_workers=num_workers, include_test=test_df, set_first_element_as_domain_label=scene_as_label, pin_memory=pin_memory, persistent_workers=persistent_workers)
        
        
        if alldomains:
            domain_dataloaders = combine_all_dataloaders(domain_dataloaders)
            domains = ['AllDomains']

        print(f"\nTesting: {name} Ablation: {ablation}")

        if ablation == 'nomask':
            setup['ablation'] = 'focus'
        elif ablation == 'onlysoc':
            setup['ablation'] = 'scene'
        elif ablation == 'onlyenv':
            setup['ablation'] = 'focus'
        else:
            setup['ablation'] = False

        if scene_as_label:
            setup['scene'] = 'label'
        dropout_rate=0.3
        model = DualBranchModel(dropout_rate=dropout_rate, setup=setup, branch_norm=branch_norm)
        dual_model = model.to(device)
        trainable_params = [p for p in dual_model.parameters() if p.requires_grad]
        lr=1e-3
        optimizer = torch.optim.Adam(trainable_params, lr=lr)
        buffer = NaiveRehearsalBuffer(buffer_size=buffer_size)

        epochs=epochs
        exp_name = f"{name}_{buffer_size=}_{epochs=}_{seed=}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
        
        scheduler=(get_linear_schedule_with_warmup, 0.05)
        refresh_optimiser=False

        dualbranch_kwargs = {
                'mse_criterion': loss_fn #nn.MSELoss(),
            }

        config = {
            "model": {
                "name": str(type(model)),
                "setup": setup,
                "branch_norm":branch_norm,
                "dropout_rate":dropout_rate,
            },
            "buffer": str(type(buffer)),
            "buffer_size": buffer_size,
            "optimizer": str(type(optimizer)),
            "learning_rate": lr,
            "scheduler": {
                "type": "transformers.get_linear_schedule_with_warmup",
                "warmup": scheduler[1],
            },
            "device": str(device),
            "loss": str(dualbranch_kwargs['mse_criterion']),
            "training_mode": "noCL" if alldomains else "CL",
            "seed": seed,
            "domains_order": domains,
            "train_val_df": train_val_path,
            "test_df": test_path,
            "hdf5_dataset_path": hdf5_dataset_path,
            "input_columns": img_path_cols,
            "input_transforms": [serialize_transform(x) for x in transform_list],
            "dataloader": {
                "batch_size": batch,
                "num_workers":num_workers,
                "pin_memory": pin_memory,
                "persistent_workers": persistent_workers,
            },
            "epochs": epochs,
            "early_stopping": {
                "patience":15,
                "delta":1e-3,
            },
            "gradient_clipping": grad_clipping,
            "refresh_optimiser": refresh_optimiser,
        }

        with open(f"../checkpoints/{exp_name}_config.json", "w") as f:
            json.dump(config, f, indent=4)

        unified_train_loop(
            model=dual_model,
            domains=domains,
            domain_dataloaders=domain_dataloaders,
            buffer=buffer,
            optimizer=optimizer,
            device=device,
            batch_fn=heuristic_dualbranch_batch,
            batch_kwargs=dualbranch_kwargs,
            num_epochs=epochs,
            exp_name=exp_name,
            gradient_clipping=grad_clipping,
            checkpoint_dir="../checkpoints",
            validation_set='val',
            scheduler=scheduler,
            refresh_optimiser=refresh_optimiser,
            early_stopping=earlystopping,
        )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")    

domains = ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']

testing_scenarios = {
    'nodisentanglement_notcontinuous_noreplay.nomask': ('nomask', 60, 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)], ['image_path'], False, nn.MSELoss(), {'branch':'mobilenetv2', 'ablation':'focus'}, True, False),
    'disentanglement_notcontinuous_noreplay.base': ('base', 60, 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, True, False),
    'nodisentanglement_continuous_noreplay.nomask': ('nomask', 60, 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)], ['image_path'], False, nn.MSELoss(), {'branch':'mobilenetv2', 'ablation':'focus'}, False, False),
    'nodisentanglement_continuous_replay.nomask': ('nomask', 60, 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)], ['image_path'], False, nn.MSELoss(), {'branch':'mobilenetv2', 'ablation':'focus'}, False, True),
    'disentanglement_continuous_replay.base': ('base', 60, 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, False, True),
    'disentanglement_continuous_noreplay.base': ('base', 60, 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, False, False),
}
    
for name, (ablation, epochs, buffer_size, train_val_path, test_path, hdf5_path, transform_list, img_path_cols, scene_as_label, loss_fn, setup, joint_training, use_buffer) in testing_scenarios.items():
        train_df = pd.read_pickle(train_val_path) if train_val_path is not None else None
        test_df = pd.read_pickle(test_path) if test_path is not None else None
        hdf5_dataset_path = hdf5_path
        setup=setup #{'branch':'mobilenetv2'}
        seed=42
        set_seed(seed)
        grad_clipping=True
        batch=(32, 64, 64)
        buffer_size=buffer_size
        branch_norm=True
        earlystopping=True
        epochs=epochs
        joint_training=joint_training
        scene_as_label=scene_as_label
        pin_memory=True
        persistent_workers=False
        num_workers=0
        use_buffer=use_buffer


        # fold_dataloaders = get_crossvalidation_domain_loaders(train_df, folds=5, seed=seed, batch_sizes=batch, img_path_cols=img_path_cols, transforms=transform_list, num_workers=0, set_first_element_as_domain_label=scene_as_label, pin_memory=False)
        # for fold, domain_dataloaders in fold_dataloaders.items():
        if hdf5_path:
            domain_dataloaders = get_domain_dataloaders_from_hdf5(hdf5_path=hdf5_dataset_path, domains=domains, img_path_cols=img_path_cols, num_workers=num_workers, set_first_element_as_domain_label=scene_as_label, pin_memory=pin_memory, persistent_workers=persistent_workers)
        else:
            domain_dataloaders = get_domain_dataloaders(train_df, seed=seed, batch_sizes=batch, img_path_cols=img_path_cols, transforms=transform_list, num_workers=num_workers, include_test=test_df, set_first_element_as_domain_label=scene_as_label, pin_memory=pin_memory, persistent_workers=persistent_workers)
        
        if joint_training:
            domain_dataloaders = pool_domain_dataloaders(domain_dataloaders)

        print(f"\nTesting: {name} Ablation: {ablation}")

        if ablation == 'nomask':
            setup['ablation'] = 'focus'
        elif ablation == 'onlysoc':
            setup['ablation'] = 'scene'
        elif ablation == 'onlyenv':
            setup['ablation'] = 'focus'
        else:
            setup['ablation'] = False

        if scene_as_label:
            setup['scene'] = 'label'
        dropout_rate=0.3
        model = DualBranchModel(dropout_rate=dropout_rate, setup=setup, branch_norm=branch_norm)
        dual_model = model.to(device)
        trainable_params = [p for p in dual_model.parameters() if p.requires_grad]
        lr=1e-3
        optimizer = torch.optim.Adam(trainable_params, lr=lr)
        buffer = NaiveRehearsalBuffer(buffer_size=buffer_size) if use_buffer else None

        epochs=epochs
        exp_name = f"{name}_{buffer_size=}_{epochs=}_{seed=}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
        
        scheduler=(get_linear_schedule_with_warmup, 0.05)
        refresh_optimiser=False

        dualbranch_kwargs = {
                'mse_criterion': loss_fn #nn.MSELoss(),
            }

        config = {
            "model": {
                "name": str(type(model)),
                "setup": setup,
                "branch_norm":branch_norm,
                "dropout_rate":dropout_rate,
            },
            "buffer": str(type(buffer)),
            "buffer_size": buffer_size,
            "optimizer": str(type(optimizer)),
            "learning_rate": lr,
            "scheduler": {
                "type": "transformers.get_linear_schedule_with_warmup",
                "warmup": scheduler[1],
            },
            "device": str(device),
            "loss": str(dualbranch_kwargs['mse_criterion']),
            "joint_training": joint_training, #trained on pooled domains, not continual learning
            "seed": seed,
            "domains_order": domains,
            "train_val_df": train_val_path,
            "test_df": test_path,
            "hdf5_dataset_path": hdf5_dataset_path,
            "input_columns": img_path_cols,
            "input_transforms": [serialize_transform(x) for x in transform_list],
            "dataloader": {
                "batch_size": batch,
                "num_workers":num_workers,
                "pin_memory": pin_memory,
                "persistent_workers": persistent_workers,
            },
            "epochs": epochs,
            "early_stopping": {
                "patience":15,
                "delta":1e-3,
            },
            "gradient_clipping": grad_clipping,
            "refresh_optimiser": refresh_optimiser,
        }

        with open(f"../checkpoints/{exp_name}_config.json", "w") as f:
            json.dump(config, f, indent=4)

        unified_train_loop(
            model=dual_model,
            domains=domains if not joint_training else ['joint'],
            domain_dataloaders=domain_dataloaders,
            buffer=buffer,
            optimizer=optimizer,
            device=device,
            batch_fn=heuristic_dualbranch_batch,
            batch_kwargs=dualbranch_kwargs,
            num_epochs=epochs,
            exp_name=exp_name,
            gradient_clipping=grad_clipping,
            checkpoint_dir="../checkpoints",
            validation_set='val',
            scheduler=scheduler,
            refresh_optimiser=refresh_optimiser,
            early_stopping=earlystopping,
        )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")    

domains = ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']

testing_scenarios = {
    # 'nodisentanglement_joint_noreplay.nomask': ('nomask', 60, 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)], ['image_path'], False, nn.MSELoss(), {'branch':'mobilenetv2', 'ablation':'focus'}, True, False),
    # 'disentanglement_joint_noreplay.base': ('base', 60, 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, True, False),
    # 'nodisentanglement_cl_noreplay.nomask': ('nomask', 60, 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)], ['image_path'], False, nn.MSELoss(), {'branch':'mobilenetv2', 'ablation':'focus'}, False, False),
    # 'nodisentanglement_cl_replay.nomask': ('nomask', 60, 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)], ['image_path'], False, nn.MSELoss(), {'branch':'mobilenetv2', 'ablation':'focus'}, False, True),
    # 'disentanglement_cl_replay.base': ('base', 60, 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, False, True),
    'disentanglement_cl_noreplay.base': ('base', 60, 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, False, False),
}
    
for name, (ablation, epochs, buffer_size, train_val_path, test_path, hdf5_path, transform_list, img_path_cols, scene_as_label, loss_fn, setup, joint_training, use_buffer) in testing_scenarios.items():
        train_df = pd.read_pickle(train_val_path) if train_val_path is not None else None
        test_df = pd.read_pickle(test_path) if test_path is not None else None
        hdf5_dataset_path = hdf5_path
        setup=setup #{'branch':'mobilenetv2'}
        seed=42
        set_seed(seed)
        grad_clipping=True
        batch=(32, 64, 64)
        buffer_size=buffer_size
        branch_norm=True
        earlystopping=True
        epochs=epochs
        joint_training=joint_training
        scene_as_label=scene_as_label
        pin_memory=True
        persistent_workers=False
        num_workers=0
        use_buffer=use_buffer


        for fold in range(2,5):
            print(f"\nTesting fold: {fold}")

            fold_hdf5_dataset_path = hdf5_dataset_path[:-5] + f'_fold{fold}.hdf5'

            if hdf5_path:
                domain_dataloaders = get_domain_dataloaders_from_hdf5(hdf5_path=fold_hdf5_dataset_path, domains=domains, img_path_cols=img_path_cols, num_workers=num_workers, set_first_element_as_domain_label=scene_as_label, pin_memory=pin_memory, persistent_workers=persistent_workers)
            else:
                domain_dataloaders = get_domain_dataloaders(train_df, seed=seed, batch_sizes=batch, img_path_cols=img_path_cols, transforms=transform_list, num_workers=num_workers, include_test=test_df, set_first_element_as_domain_label=scene_as_label, pin_memory=pin_memory, persistent_workers=persistent_workers)
            
            if joint_training:
                domain_dataloaders = pool_domain_dataloaders(domain_dataloaders)

            print(f"\nTesting: {name} Ablation: {ablation}")

            if ablation == 'nomask':
                setup['ablation'] = 'focus'
            elif ablation == 'onlysoc':
                setup['ablation'] = 'scene'
            elif ablation == 'onlyenv':
                setup['ablation'] = 'focus'
            else:
                setup['ablation'] = False

            if scene_as_label:
                setup['scene'] = 'label'
            dropout_rate=0.3
            model = DualBranchModel(dropout_rate=dropout_rate, setup=setup, branch_norm=branch_norm)
            dual_model = model.to(device)
            trainable_params = [p for p in dual_model.parameters() if p.requires_grad]
            lr=1e-3
            optimizer = torch.optim.Adam(trainable_params, lr=lr)
            buffer = NaiveRehearsalBuffer(buffer_size=buffer_size) if use_buffer else None

            epochs=epochs
            exp_name = f"{name}_{fold=}_{buffer_size=}_{epochs=}_{seed=}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
            
            scheduler=(get_linear_schedule_with_warmup, 0.05)
            refresh_optimiser=False

            dualbranch_kwargs = {
                    'mse_criterion': loss_fn #nn.MSELoss(),
                }

            config = {
                "model": {
                    "name": str(type(model)),
                    "setup": setup,
                    "branch_norm":branch_norm,
                    "dropout_rate":dropout_rate,
                },
                "buffer": str(type(buffer)),
                "buffer_size": buffer_size,
                "optimizer": str(type(optimizer)),
                "learning_rate": lr,
                "scheduler": {
                    "type": "transformers.get_linear_schedule_with_warmup",
                    "warmup": scheduler[1],
                },
                "device": str(device),
                "loss": str(dualbranch_kwargs['mse_criterion']),
                "joint_training": joint_training, #trained on pooled domains, not continual learning
                "seed": seed,
                "domains_order": domains,
                "train_val_df": train_val_path,
                "test_df": test_path,
                "hdf5_dataset_path": hdf5_dataset_path,
                "input_columns": img_path_cols,
                "input_transforms": [serialize_transform(x) for x in transform_list],
                "dataloader": {
                    "batch_size": batch,
                    "num_workers":num_workers,
                    "pin_memory": pin_memory,
                    "persistent_workers": persistent_workers,
                },
                "epochs": epochs,
                "early_stopping": {
                    "patience":15,
                    "delta":1e-3,
                },
                "gradient_clipping": grad_clipping,
                "refresh_optimiser": refresh_optimiser,
            }

            with open(f"../checkpoints/{exp_name}_config.json", "w") as f:
                json.dump(config, f, indent=4)

            unified_train_loop(
                model=dual_model,
                domains=domains if not joint_training else ['joint'],
                domain_dataloaders=domain_dataloaders,
                buffer=buffer,
                optimizer=optimizer,
                device=device,
                batch_fn=heuristic_dualbranch_batch,
                batch_kwargs=dualbranch_kwargs,
                num_epochs=epochs,
                exp_name=exp_name,
                gradient_clipping=grad_clipping,
                checkpoint_dir="../checkpoints",
                validation_set='val',
                scheduler=scheduler,
                refresh_optimiser=refresh_optimiser,
                early_stopping=earlystopping,
            )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")    

domains = ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']

testing_scenarios = {
    'order_complexity.base': ('base', 60, 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, False, True, ['Hallway', 'SmallOffice', 'MeetingRoom', 'BigOffice-3', 'BigOffice-2', 'Home']),
    'order_diff1.base': ('base', 60, 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, False, True, ['MeetingRoom', 'Home', 'Hallway', 'BigOffice-2', 'SmallOffice', 'BigOffice-3']),
    'order_diff2.base': ('base', 60, 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, False, True, ['BigOffice-3', 'SmallOffice', 'Home', 'Hallway', 'MeetingRoom', 'BigOffice-2']),
    'order_midhouse.base': ('base', 60, 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, False, True, ['BigOffice-2', 'BigOffice-3', 'Hallway', 'Home', 'MeetingRoom', 'SmallOffice']),
    'order_default.base': ('base', 60, 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, False, True, ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']),
}
    
for name, (ablation, epochs, buffer_size, train_val_path, test_path, hdf5_path, transform_list, img_path_cols, scene_as_label, loss_fn, setup, joint_training, use_buffer, domains) in testing_scenarios.items():
        train_df = pd.read_pickle(train_val_path) if train_val_path is not None else None
        test_df = pd.read_pickle(test_path) if test_path is not None else None
        hdf5_dataset_path = hdf5_path
        setup=setup #{'branch':'mobilenetv2'}
        seed=42
        set_seed(seed)
        grad_clipping=True
        batch=(32, 64, 64)
        buffer_size=buffer_size
        branch_norm=True
        earlystopping=True
        epochs=epochs
        joint_training=joint_training
        scene_as_label=scene_as_label
        pin_memory=True
        persistent_workers=False
        num_workers=0
        use_buffer=use_buffer


        for fold in range(0,5):
            print(f"\nTesting fold: {fold}")

            fold_hdf5_dataset_path = hdf5_dataset_path[:-5] + f'_fold{fold}.hdf5'

            if hdf5_path:
                domain_dataloaders = get_domain_dataloaders_from_hdf5(hdf5_path=fold_hdf5_dataset_path, domains=domains, img_path_cols=img_path_cols, num_workers=num_workers, set_first_element_as_domain_label=scene_as_label, pin_memory=pin_memory, persistent_workers=persistent_workers)
            else:
                domain_dataloaders = get_domain_dataloaders(train_df, seed=seed, batch_sizes=batch, img_path_cols=img_path_cols, transforms=transform_list, num_workers=num_workers, include_test=test_df, set_first_element_as_domain_label=scene_as_label, pin_memory=pin_memory, persistent_workers=persistent_workers)
            
            if joint_training:
                domain_dataloaders = pool_domain_dataloaders(domain_dataloaders)

            print(f"\nTesting: {name} Ablation: {ablation}")

            if ablation == 'nomask':
                setup['ablation'] = 'focus'
            elif ablation == 'onlysoc':
                setup['ablation'] = 'scene'
            elif ablation == 'onlyenv':
                setup['ablation'] = 'focus'
            else:
                setup['ablation'] = False

            if scene_as_label:
                setup['scene'] = 'label'
            dropout_rate=0.3
            model = DualBranchModel(dropout_rate=dropout_rate, setup=setup, branch_norm=branch_norm)
            dual_model = model.to(device)
            trainable_params = [p for p in dual_model.parameters() if p.requires_grad]
            lr=1e-3
            optimizer = torch.optim.Adam(trainable_params, lr=lr)
            buffer = NaiveRehearsalBuffer(buffer_size=buffer_size) if use_buffer else None

            epochs=epochs
            exp_name = f"{name}_{fold=}_{buffer_size=}_{epochs=}_{seed=}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
            
            scheduler=(get_linear_schedule_with_warmup, 0.05)
            refresh_optimiser=False

            dualbranch_kwargs = {
                    'mse_criterion': loss_fn #nn.MSELoss(),
                }

            config = {
                "model": {
                    "name": str(type(model)),
                    "setup": setup,
                    "branch_norm":branch_norm,
                    "dropout_rate":dropout_rate,
                },
                "buffer": str(type(buffer)),
                "buffer_size": buffer_size,
                "optimizer": str(type(optimizer)),
                "learning_rate": lr,
                "scheduler": {
                    "type": "transformers.get_linear_schedule_with_warmup",
                    "warmup": scheduler[1],
                },
                "device": str(device),
                "loss": str(dualbranch_kwargs['mse_criterion']),
                "joint_training": joint_training, #trained on pooled domains, not continual learning
                "seed": seed,
                "domains_order": domains,
                "train_val_df": train_val_path,
                "test_df": test_path,
                "hdf5_dataset_path": hdf5_dataset_path,
                "input_columns": img_path_cols,
                "input_transforms": [serialize_transform(x) for x in transform_list],
                "dataloader": {
                    "batch_size": batch,
                    "num_workers":num_workers,
                    "pin_memory": pin_memory,
                    "persistent_workers": persistent_workers,
                },
                "epochs": epochs,
                "early_stopping": {
                    "patience":15,
                    "delta":1e-3,
                },
                "gradient_clipping": grad_clipping,
                "refresh_optimiser": refresh_optimiser,
            }

            with open(f"../checkpoints/{exp_name}_config.json", "w") as f:
                json.dump(config, f, indent=4)

            unified_train_loop(
                model=dual_model,
                domains=domains if not joint_training else ['joint'],
                domain_dataloaders=domain_dataloaders,
                buffer=buffer,
                optimizer=optimizer,
                device=device,
                batch_fn=heuristic_dualbranch_batch,
                batch_kwargs=dualbranch_kwargs,
                num_epochs=epochs,
                exp_name=exp_name,
                gradient_clipping=grad_clipping,
                checkpoint_dir="../checkpoints",
                validation_set='val',
                scheduler=scheduler,
                refresh_optimiser=refresh_optimiser,
                early_stopping=earlystopping,
            )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")    

default_domains = ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']

testing_scenarios = {
    'double_env.base': ('base', 60, 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path', 'image_path'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, False, True, default_domains),
    'silhouette.base': ('base', 60, 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, False, True, default_domains),
    'order_complexity_reversed.base': ('base', 60, 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, False, True, ['Home', 'BigOffice-2', 'BigOffice-3', 'MeetingRoom', 'SmallOffice', 'Hallway']),
}
    
for name, (ablation, epochs, buffer_size, train_val_path, test_path, hdf5_path, transform_list, img_path_cols, scene_as_label, loss_fn, setup, joint_training, use_buffer, domains) in testing_scenarios.items():
        train_df = pd.read_pickle(train_val_path) if train_val_path is not None else None
        test_df = pd.read_pickle(test_path) if test_path is not None else None
        hdf5_dataset_path = hdf5_path
        setup=setup #{'branch':'mobilenetv2'}
        seed=42
        set_seed(seed)
        grad_clipping=True
        batch=(32, 64, 64)
        buffer_size=buffer_size
        branch_norm=True
        earlystopping=True
        epochs=epochs
        joint_training=joint_training
        scene_as_label=scene_as_label
        pin_memory=True
        persistent_workers=False
        num_workers=0
        use_buffer=use_buffer


        for fold in range(0,5):
            print(f"\nTesting fold: {fold}")

            fold_hdf5_dataset_path = hdf5_dataset_path[:-5] + f'_fold{fold}.hdf5'

            if hdf5_path:
                domain_dataloaders = get_domain_dataloaders_from_hdf5(hdf5_path=fold_hdf5_dataset_path, domains=domains, img_path_cols=img_path_cols, num_workers=num_workers, set_first_element_as_domain_label=scene_as_label, pin_memory=pin_memory, persistent_workers=persistent_workers)
            else:
                domain_dataloaders = get_domain_dataloaders(train_df, seed=seed, batch_sizes=batch, img_path_cols=img_path_cols, transforms=transform_list, num_workers=num_workers, include_test=test_df, set_first_element_as_domain_label=scene_as_label, pin_memory=pin_memory, persistent_workers=persistent_workers)
            
            if joint_training:
                domain_dataloaders = pool_domain_dataloaders(domain_dataloaders)

            print(f"\nTesting: {name} Ablation: {ablation}")

            if ablation == 'nomask':
                setup['ablation'] = 'focus'
            elif ablation == 'onlysoc':
                setup['ablation'] = 'scene'
            elif ablation == 'onlyenv':
                setup['ablation'] = 'focus'
            else:
                setup['ablation'] = False

            if scene_as_label:
                setup['scene'] = 'label'
            dropout_rate=0.3
            model = DualBranchModel(dropout_rate=dropout_rate, setup=setup, branch_norm=branch_norm)
            dual_model = model.to(device)
            trainable_params = [p for p in dual_model.parameters() if p.requires_grad]
            lr=1e-3
            optimizer = torch.optim.Adam(trainable_params, lr=lr)
            buffer = NaiveRehearsalBuffer(buffer_size=buffer_size) if use_buffer else None

            epochs=epochs
            exp_name = f"{name}_{fold=}_{buffer_size=}_{epochs=}_{seed=}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
            
            scheduler=(get_linear_schedule_with_warmup, 0.05)
            refresh_optimiser=False

            dualbranch_kwargs = {
                    'mse_criterion': loss_fn #nn.MSELoss(),
                }

            config = {
                "model": {
                    "name": str(type(model)),
                    "setup": setup,
                    "branch_norm":branch_norm,
                    "dropout_rate":dropout_rate,
                },
                "buffer": str(type(buffer)),
                "buffer_size": buffer_size,
                "optimizer": str(type(optimizer)),
                "learning_rate": lr,
                "scheduler": {
                    "type": "transformers.get_linear_schedule_with_warmup",
                    "warmup": scheduler[1],
                },
                "device": str(device),
                "loss": str(dualbranch_kwargs['mse_criterion']),
                "joint_training": joint_training, #trained on pooled domains, not continual learning
                "seed": seed,
                "domains_order": domains,
                "train_val_df": train_val_path,
                "test_df": test_path,
                "hdf5_dataset_path": hdf5_dataset_path,
                "input_columns": img_path_cols,
                "input_transforms": [serialize_transform(x) for x in transform_list],
                "dataloader": {
                    "batch_size": batch,
                    "num_workers":num_workers,
                    "pin_memory": pin_memory,
                    "persistent_workers": persistent_workers,
                },
                "epochs": epochs,
                "early_stopping": {
                    "patience":15,
                    "delta":1e-3,
                },
                "gradient_clipping": grad_clipping,
                "refresh_optimiser": refresh_optimiser,
            }

            with open(f"../checkpoints/{exp_name}_config.json", "w") as f:
                json.dump(config, f, indent=4)

            unified_train_loop(
                model=dual_model,
                domains=domains if not joint_training else ['joint'],
                domain_dataloaders=domain_dataloaders,
                buffer=buffer,
                optimizer=optimizer,
                device=device,
                batch_fn=heuristic_dualbranch_batch,
                batch_kwargs=dualbranch_kwargs,
                num_epochs=epochs,
                exp_name=exp_name,
                gradient_clipping=grad_clipping,
                checkpoint_dir="../checkpoints",
                validation_set='val',
                scheduler=scheduler,
                refresh_optimiser=refresh_optimiser,
                early_stopping=earlystopping,
            )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")    

default_domains = ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']

testing_scenarios = {
    'robotfocus_128_2.base': ('base', 60, 120, None, None, "../data/robotfocus128_pepper_data.hdf5", [get_transform((144,256), IMAGENET_NORM), get_transform((128,128), IMAGENET_NORM)], ['image_path_scene', 'image_path_focus_x2'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, False, True, default_domains),
}
    
for name, (ablation, epochs, buffer_size, train_val_path, test_path, hdf5_path, transform_list, img_path_cols, scene_as_label, loss_fn, setup, joint_training, use_buffer, domains) in testing_scenarios.items():
        train_df = pd.read_pickle(train_val_path) if train_val_path is not None else None
        test_df = pd.read_pickle(test_path) if test_path is not None else None
        hdf5_dataset_path = hdf5_path
        setup=setup #{'branch':'mobilenetv2'}
        seed=42
        set_seed(seed)
        grad_clipping=True
        batch=(32, 64, 64)
        buffer_size=buffer_size
        branch_norm=True
        earlystopping=True
        epochs=epochs
        joint_training=joint_training
        scene_as_label=scene_as_label
        pin_memory=True
        persistent_workers=False
        num_workers=0
        use_buffer=use_buffer


        for fold in range(0,5):
            print(f"\nTesting fold: {fold}")

            fold_hdf5_dataset_path = hdf5_dataset_path[:-5] + f'_fold{fold}.hdf5'

            if hdf5_path:
                domain_dataloaders = get_domain_dataloaders_from_hdf5(hdf5_path=fold_hdf5_dataset_path, domains=domains, img_path_cols=img_path_cols, num_workers=num_workers, set_first_element_as_domain_label=scene_as_label, pin_memory=pin_memory, persistent_workers=persistent_workers)
            else:
                domain_dataloaders = get_domain_dataloaders(train_df, seed=seed, batch_sizes=batch, img_path_cols=img_path_cols, transforms=transform_list, num_workers=num_workers, include_test=test_df, set_first_element_as_domain_label=scene_as_label, pin_memory=pin_memory, persistent_workers=persistent_workers)
            
            if joint_training:
                domain_dataloaders = pool_domain_dataloaders(domain_dataloaders)

            print(f"\nTesting: {name} Ablation: {ablation}")

            if ablation == 'nomask':
                setup['ablation'] = 'focus'
            elif ablation == 'onlysoc':
                setup['ablation'] = 'scene'
            elif ablation == 'onlyenv':
                setup['ablation'] = 'focus'
            else:
                setup['ablation'] = False

            if scene_as_label:
                setup['scene'] = 'label'
            dropout_rate=0.3
            model = DualBranchModel(dropout_rate=dropout_rate, setup=setup, branch_norm=branch_norm)
            dual_model = model.to(device)
            trainable_params = [p for p in dual_model.parameters() if p.requires_grad]
            lr=1e-3
            optimizer = torch.optim.Adam(trainable_params, lr=lr)
            buffer = NaiveRehearsalBuffer(buffer_size=buffer_size) if use_buffer else None

            epochs=epochs
            exp_name = f"{name}_{fold=}_{buffer_size=}_{epochs=}_{seed=}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
            
            scheduler=(get_linear_schedule_with_warmup, 0.05)
            refresh_optimiser=False

            dualbranch_kwargs = {
                    'mse_criterion': loss_fn #nn.MSELoss(),
                }

            config = {
                "model": {
                    "name": str(type(model)),
                    "setup": setup,
                    "branch_norm":branch_norm,
                    "dropout_rate":dropout_rate,
                },
                "buffer": str(type(buffer)),
                "buffer_size": buffer_size,
                "optimizer": str(type(optimizer)),
                "learning_rate": lr,
                "scheduler": {
                    "type": "transformers.get_linear_schedule_with_warmup",
                    "warmup": scheduler[1],
                },
                "device": str(device),
                "loss": str(dualbranch_kwargs['mse_criterion']),
                "joint_training": joint_training, #trained on pooled domains, not continual learning
                "seed": seed,
                "domains_order": domains,
                "train_val_df": train_val_path,
                "test_df": test_path,
                "hdf5_dataset_path": hdf5_dataset_path,
                "input_columns": img_path_cols,
                "input_transforms": [serialize_transform(x) for x in transform_list],
                "dataloader": {
                    "batch_size": batch,
                    "num_workers":num_workers,
                    "pin_memory": pin_memory,
                    "persistent_workers": persistent_workers,
                },
                "epochs": epochs,
                "early_stopping": {
                    "patience":15,
                    "delta":1e-3,
                },
                "gradient_clipping": grad_clipping,
                "refresh_optimiser": refresh_optimiser,
            }

            with open(f"../checkpoints/{exp_name}_config.json", "w") as f:
                json.dump(config, f, indent=4)

            unified_train_loop(
                model=dual_model,
                domains=domains if not joint_training else ['joint'],
                domain_dataloaders=domain_dataloaders,
                buffer=buffer,
                optimizer=optimizer,
                device=device,
                batch_fn=heuristic_dualbranch_batch,
                batch_kwargs=dualbranch_kwargs,
                num_epochs=epochs,
                exp_name=exp_name,
                gradient_clipping=grad_clipping,
                checkpoint_dir="../checkpoints",
                validation_set='val',
                scheduler=scheduler,
                refresh_optimiser=refresh_optimiser,
                early_stopping=earlystopping,
            )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")    

default_domains = ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']

testing_scenarios = {
    'gatefusion.base': ('base', 60, 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2', 'fusion':'gated'}, False, True, default_domains),
    'compoundloss.base': ('base', 60, 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, CompoundLossFixedAlpha(alpha=0.4), {'branch':'mobilenetv2', 'fusion':'concat'}, False, True, default_domains),
    'gatedfusion_compoundloss.base': ('base', 60, 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, CompoundLossFixedAlpha(alpha=0.4), {'branch':'mobilenetv2', 'fusion':'gated'}, False, True, default_domains),

}
    
for name, (ablation, epochs, buffer_size, train_val_path, test_path, hdf5_path, transform_list, img_path_cols, scene_as_label, loss_fn, setup, joint_training, use_buffer, domains) in testing_scenarios.items():
        train_df = pd.read_pickle(train_val_path) if train_val_path is not None else None
        test_df = pd.read_pickle(test_path) if test_path is not None else None
        hdf5_dataset_path = hdf5_path
        setup=setup #{'branch':'mobilenetv2'}
        seed=42
        set_seed(seed)
        grad_clipping=True
        batch=(32, 64, 64)
        buffer_size=buffer_size
        branch_norm=True
        earlystopping=True
        epochs=epochs
        joint_training=joint_training
        scene_as_label=scene_as_label
        pin_memory=True
        persistent_workers=False
        num_workers=0
        use_buffer=use_buffer


        for fold in range(0,5):
            print(f"\nTesting fold: {fold}")

            fold_hdf5_dataset_path = hdf5_dataset_path[:-5] + f'_fold{fold}.hdf5'

            if hdf5_path:
                domain_dataloaders = get_domain_dataloaders_from_hdf5(hdf5_path=fold_hdf5_dataset_path, domains=domains, img_path_cols=img_path_cols, num_workers=num_workers, set_first_element_as_domain_label=scene_as_label, pin_memory=pin_memory, persistent_workers=persistent_workers)
            else:
                domain_dataloaders = get_domain_dataloaders(train_df, seed=seed, batch_sizes=batch, img_path_cols=img_path_cols, transforms=transform_list, num_workers=num_workers, include_test=test_df, set_first_element_as_domain_label=scene_as_label, pin_memory=pin_memory, persistent_workers=persistent_workers)
            
            if joint_training:
                domain_dataloaders = pool_domain_dataloaders(domain_dataloaders)

            print(f"\nTesting: {name} Ablation: {ablation}")

            if ablation == 'nomask':
                setup['ablation'] = 'focus'
            elif ablation == 'onlysoc':
                setup['ablation'] = 'scene'
            elif ablation == 'onlyenv':
                setup['ablation'] = 'focus'
            else:
                setup['ablation'] = False

            if scene_as_label:
                setup['scene'] = 'label'
            dropout_rate=0.3
            model = DualBranchModel_fusions(dropout_rate=dropout_rate, setup=setup, branch_norm=branch_norm)
            dual_model = model.to(device)
            trainable_params = [p for p in dual_model.parameters() if p.requires_grad]
            lr=1e-3
            optimizer = torch.optim.Adam(trainable_params, lr=lr)
            buffer = NaiveRehearsalBuffer(buffer_size=buffer_size) if use_buffer else None

            epochs=epochs
            exp_name = f"{name}_{fold=}_{buffer_size=}_{epochs=}_{seed=}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
            
            scheduler=(get_linear_schedule_with_warmup, 0.05)
            refresh_optimiser=False

            dualbranch_kwargs = {
                    'mse_criterion': loss_fn #nn.MSELoss(),
                }

            config = {
                "model": {
                    "name": str(type(model)),
                    "setup": setup,
                    "branch_norm":branch_norm,
                    "dropout_rate":dropout_rate,
                },
                "buffer": str(type(buffer)),
                "buffer_size": buffer_size,
                "optimizer": str(type(optimizer)),
                "learning_rate": lr,
                "scheduler": {
                    "type": "transformers.get_linear_schedule_with_warmup",
                    "warmup": scheduler[1],
                },
                "device": str(device),
                "loss": str(dualbranch_kwargs['mse_criterion']),
                "joint_training": joint_training, #trained on pooled domains, not continual learning
                "seed": seed,
                "domains_order": domains,
                "train_val_df": train_val_path,
                "test_df": test_path,
                "hdf5_dataset_path": hdf5_dataset_path,
                "input_columns": img_path_cols,
                "input_transforms": [serialize_transform(x) for x in transform_list],
                "dataloader": {
                    "batch_size": batch,
                    "num_workers":num_workers,
                    "pin_memory": pin_memory,
                    "persistent_workers": persistent_workers,
                },
                "epochs": epochs,
                "early_stopping": {
                    "patience":15,
                    "delta":1e-3,
                },
                "gradient_clipping": grad_clipping,
                "refresh_optimiser": refresh_optimiser,
            }

            with open(f"../checkpoints/{exp_name}_config.json", "w") as f:
                json.dump(config, f, indent=4)

            unified_train_loop(
                model=dual_model,
                domains=domains if not joint_training else ['joint'],
                domain_dataloaders=domain_dataloaders,
                buffer=buffer,
                optimizer=optimizer,
                device=device,
                batch_fn=heuristic_dualbranch_batch,
                batch_kwargs=dualbranch_kwargs,
                num_epochs=epochs,
                exp_name=exp_name,
                gradient_clipping=grad_clipping,
                checkpoint_dir="../checkpoints",
                validation_set='val',
                scheduler=scheduler,
                refresh_optimiser=refresh_optimiser,
                early_stopping=earlystopping,
            )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")    

default_domains = ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']

testing_scenarios = {
    'weightedsum.base': ('base', 60, 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2', 'fusion':'weighted_sum_alpha'}, False, True, default_domains),

}
    
for name, (ablation, epochs, buffer_size, train_val_path, test_path, hdf5_path, transform_list, img_path_cols, scene_as_label, loss_fn, setup, joint_training, use_buffer, domains) in testing_scenarios.items():
        train_df = pd.read_pickle(train_val_path) if train_val_path is not None else None
        test_df = pd.read_pickle(test_path) if test_path is not None else None
        hdf5_dataset_path = hdf5_path
        setup=setup #{'branch':'mobilenetv2'}
        seed=42
        set_seed(seed)
        grad_clipping=True
        batch=(32, 64, 64)
        buffer_size=buffer_size
        branch_norm=True
        earlystopping=True
        epochs=epochs
        joint_training=joint_training
        scene_as_label=scene_as_label
        pin_memory=True
        persistent_workers=False
        num_workers=0
        use_buffer=use_buffer


        for fold in range(0,5):
            print(f"\nTesting fold: {fold}")

            fold_hdf5_dataset_path = hdf5_dataset_path[:-5] + f'_fold{fold}.hdf5'

            if hdf5_path:
                domain_dataloaders = get_domain_dataloaders_from_hdf5(hdf5_path=fold_hdf5_dataset_path, domains=domains, img_path_cols=img_path_cols, num_workers=num_workers, set_first_element_as_domain_label=scene_as_label, pin_memory=pin_memory, persistent_workers=persistent_workers)
            else:
                domain_dataloaders = get_domain_dataloaders(train_df, seed=seed, batch_sizes=batch, img_path_cols=img_path_cols, transforms=transform_list, num_workers=num_workers, include_test=test_df, set_first_element_as_domain_label=scene_as_label, pin_memory=pin_memory, persistent_workers=persistent_workers)
            
            if joint_training:
                domain_dataloaders = pool_domain_dataloaders(domain_dataloaders)

            print(f"\nTesting: {name} Ablation: {ablation}")

            if ablation == 'nomask':
                setup['ablation'] = 'focus'
            elif ablation == 'onlysoc':
                setup['ablation'] = 'scene'
            elif ablation == 'onlyenv':
                setup['ablation'] = 'focus'
            else:
                setup['ablation'] = False

            if scene_as_label:
                setup['scene'] = 'label'
            dropout_rate=0.3
            model = DualBranchModel_fusions(dropout_rate=dropout_rate, setup=setup, branch_norm=branch_norm)
            dual_model = model.to(device)
            trainable_params = [p for p in dual_model.parameters() if p.requires_grad]
            lr=1e-3
            optimizer = torch.optim.Adam(trainable_params, lr=lr)
            buffer = NaiveRehearsalBuffer(buffer_size=buffer_size) if use_buffer else None

            epochs=epochs
            exp_name = f"{name}_{fold=}_{buffer_size=}_{epochs=}_{seed=}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
            
            scheduler=(get_linear_schedule_with_warmup, 0.05)
            refresh_optimiser=False

            dualbranch_kwargs = {
                    'mse_criterion': loss_fn #nn.MSELoss(),
                }

            config = {
                "model": {
                    "name": str(type(model)),
                    "setup": setup,
                    "branch_norm":branch_norm,
                    "dropout_rate":dropout_rate,
                },
                "buffer": str(type(buffer)),
                "buffer_size": buffer_size,
                "optimizer": str(type(optimizer)),
                "learning_rate": lr,
                "scheduler": {
                    "type": "transformers.get_linear_schedule_with_warmup",
                    "warmup": scheduler[1],
                },
                "device": str(device),
                "loss": str(dualbranch_kwargs['mse_criterion']),
                "joint_training": joint_training, #trained on pooled domains, not continual learning
                "seed": seed,
                "domains_order": domains,
                "train_val_df": train_val_path,
                "test_df": test_path,
                "hdf5_dataset_path": hdf5_dataset_path,
                "input_columns": img_path_cols,
                "input_transforms": [serialize_transform(x) for x in transform_list],
                "dataloader": {
                    "batch_size": batch,
                    "num_workers":num_workers,
                    "pin_memory": pin_memory,
                    "persistent_workers": persistent_workers,
                },
                "epochs": epochs,
                "early_stopping": {
                    "patience":15,
                    "delta":1e-3,
                },
                "gradient_clipping": grad_clipping,
                "refresh_optimiser": refresh_optimiser,
            }

            with open(f"../checkpoints/{exp_name}_config.json", "w") as f:
                json.dump(config, f, indent=4)

            unified_train_loop(
                model=dual_model,
                domains=domains if not joint_training else ['joint'],
                domain_dataloaders=domain_dataloaders,
                buffer=buffer,
                optimizer=optimizer,
                device=device,
                batch_fn=heuristic_dualbranch_batch,
                batch_kwargs=dualbranch_kwargs,
                num_epochs=epochs,
                exp_name=exp_name,
                gradient_clipping=grad_clipping,
                checkpoint_dir="../checkpoints",
                validation_set='val',
                scheduler=scheduler,
                refresh_optimiser=refresh_optimiser,
                early_stopping=earlystopping,
            )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")    

default_domains = ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']

testing_scenarios = {
    'default_90160.base': ('base', 60, 120, None, None, "../data/mean_data_pepper.hdf5", [get_transform((90,160), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, False, True, default_domains),
    'default_b60.base': ('base', 60, 60, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, False, True, default_domains),
    'single_b60.nomask': ('nomask', 60, 60, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)], ['image_path'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, False, True, default_domains),
    'default_ft_b60.base': ('base', 60, 60, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, False, False, default_domains),
    'single_ft_b60.nomask': ('nomask', 60, 60, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)], ['image_path'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, False, False, default_domains),

}
    
for name, (ablation, epochs, buffer_size, train_val_path, test_path, hdf5_path, transform_list, img_path_cols, scene_as_label, loss_fn, setup, joint_training, use_buffer, domains) in testing_scenarios.items():
        train_df = pd.read_pickle(train_val_path) if train_val_path is not None else None
        test_df = pd.read_pickle(test_path) if test_path is not None else None
        hdf5_dataset_path = hdf5_path
        setup=setup #{'branch':'mobilenetv2'}
        seed=42
        set_seed(seed)
        grad_clipping=True
        batch=(32, 64, 64)
        buffer_size=buffer_size
        branch_norm=True
        earlystopping=True
        epochs=epochs
        joint_training=joint_training
        scene_as_label=scene_as_label
        pin_memory=True
        persistent_workers=False
        num_workers=0
        use_buffer=use_buffer


        for fold in range(0,5):
            # if fold != 0:
            #     continue
            print(f"\nTesting fold: {fold}")

            fold_hdf5_dataset_path = hdf5_dataset_path[:-5] + f'_fold{fold}.hdf5'

            trans=[T.Resize((90,160))]*2 if '90160' in name else [None]*len(img_path_cols)

            if hdf5_path:
                domain_dataloaders = get_domain_dataloaders_from_hdf5(hdf5_path=fold_hdf5_dataset_path, domains=domains, img_path_cols=img_path_cols, num_workers=num_workers, set_first_element_as_domain_label=scene_as_label, pin_memory=pin_memory, persistent_workers=persistent_workers, transforms=trans)
            else:
                domain_dataloaders = get_domain_dataloaders(train_df, seed=seed, batch_sizes=batch, img_path_cols=img_path_cols, transforms=transform_list, num_workers=num_workers, include_test=test_df, set_first_element_as_domain_label=scene_as_label, pin_memory=pin_memory, persistent_workers=persistent_workers)
            
            if joint_training:
                domain_dataloaders = pool_domain_dataloaders(domain_dataloaders)

            print(f"\nTesting: {name} Ablation: {ablation}")

            if ablation == 'nomask':
                setup['ablation'] = 'focus'
            elif ablation == 'onlysoc':
                setup['ablation'] = 'scene'
            elif ablation == 'onlyenv':
                setup['ablation'] = 'focus'
            else:
                setup['ablation'] = False

            if scene_as_label:
                setup['scene'] = 'label'
            dropout_rate=0.3
            model = DualBranchModel(dropout_rate=dropout_rate, setup=setup, branch_norm=branch_norm)
            dual_model = model.to(device)
            trainable_params = [p for p in dual_model.parameters() if p.requires_grad]
            lr=1e-3
            optimizer = torch.optim.Adam(trainable_params, lr=lr)
            buffer = NaiveRehearsalBuffer(buffer_size=buffer_size) if use_buffer else None

            epochs=epochs
            exp_name = f"{name}_{fold=}_{buffer_size=}_{epochs=}_{seed=}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
            
            scheduler=(get_linear_schedule_with_warmup, 0.05)
            refresh_optimiser=False

            dualbranch_kwargs = {
                    'mse_criterion': loss_fn #nn.MSELoss(),
                }

            config = {
                "model": {
                    "name": str(type(model)),
                    "setup": setup,
                    "branch_norm":branch_norm,
                    "dropout_rate":dropout_rate,
                },
                "buffer": str(type(buffer)),
                "buffer_size": buffer_size,
                "optimizer": str(type(optimizer)),
                "learning_rate": lr,
                "scheduler": {
                    "type": "transformers.get_linear_schedule_with_warmup",
                    "warmup": scheduler[1],
                },
                "device": str(device),
                "loss": str(dualbranch_kwargs['mse_criterion']),
                "joint_training": joint_training, #trained on pooled domains, not continual learning
                "seed": seed,
                "domains_order": domains,
                "train_val_df": train_val_path,
                "test_df": test_path,
                "hdf5_dataset_path": hdf5_dataset_path,
                "input_columns": img_path_cols,
                "input_transforms": [serialize_transform(x) for x in transform_list],
                "dataloader": {
                    "batch_size": batch,
                    "num_workers":num_workers,
                    "pin_memory": pin_memory,
                    "persistent_workers": persistent_workers,
                },
                "epochs": epochs,
                "early_stopping": {
                    "patience":15,
                    "delta":1e-3,
                },
                "gradient_clipping": grad_clipping,
                "refresh_optimiser": refresh_optimiser,
            }

            with open(f"../checkpoints/{exp_name}_config.json", "w") as f:
                json.dump(config, f, indent=4)

            unified_train_loop(
                model=dual_model,
                domains=domains if not joint_training else ['joint'],
                domain_dataloaders=domain_dataloaders,
                buffer=buffer,
                optimizer=optimizer,
                device=device,
                batch_fn=heuristic_dualbranch_batch,
                batch_kwargs=dualbranch_kwargs,
                num_epochs=epochs,
                exp_name=exp_name,
                gradient_clipping=grad_clipping,
                checkpoint_dir="../checkpoints",
                validation_set='val',
                scheduler=scheduler,
                refresh_optimiser=refresh_optimiser,
                early_stopping=earlystopping,
            )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")    

default_domains = ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']

testing_scenarios = {
    'dual_b30.base': ('base', 60, 30, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, False, True, default_domains),
    'single_b30.nomask': ('nomask', 60, 30, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)], ['image_path'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, False, True, default_domains),
    # 'dual_ft_b30.base': ('base', 60, 30, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, False, False, default_domains),
    # 'single_ft_b30.nomask': ('nomask', 60, 30, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)], ['image_path'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, False, False, default_domains),
    # 'silh.base': ('base', 60, 30, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, False, True, default_domains),
    # 'closeup.base': ('base', 60, 30, None, None, "../data/robotfocus128_pepper_data.hdf5", [get_transform((144,256), IMAGENET_NORM), get_transform((128,128), IMAGENET_NORM)], ['image_path_scene', 'image_path_focus_x2'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, False, True, default_domains),
    # 'order_complexup.base': ('base', 60, 30, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, False, True, default_domains),
    # 'order_complexdown.base': ('base', 60, 30, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, False, True, default_domains),
    # 'order_contrA.base': ('base', 60, 30, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, False, True, default_domains),
    # 'order_contrB.base': ('base', 60, 30, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, False, True, default_domains),
}
    
for name, (ablation, epochs, buffer_size, train_val_path, test_path, hdf5_path, transform_list, img_path_cols, scene_as_label, loss_fn, setup, joint_training, use_buffer, domains) in testing_scenarios.items():
        train_df = pd.read_pickle(train_val_path) if train_val_path is not None else None
        test_df = pd.read_pickle(test_path) if test_path is not None else None
        main_hdf5_dataset_path = hdf5_path
        setup=setup #{'branch':'mobilenetv2'}
        seed=42
        set_seed(seed)
        grad_clipping=True
        batch=(32, 64, 64)
        buffer_size=buffer_size
        branch_norm=True
        earlystopping=True
        epochs=epochs
        joint_training=joint_training
        scene_as_label=scene_as_label
        pin_memory=True
        persistent_workers=False
        num_workers=0
        use_buffer=use_buffer


        for fold in range(0,5):
            if fold != 0:
                continue
            print(f"\nTesting fold: {fold}")

            hdf5_dataset_path = main_hdf5_dataset_path[:-5] + f'_fold{fold}.hdf5'

            if hdf5_path:
                domain_dataloaders = get_domain_dataloaders_from_hdf5(hdf5_path=hdf5_dataset_path, domains=domains, img_path_cols=img_path_cols, num_workers=num_workers, set_first_element_as_domain_label=scene_as_label, pin_memory=pin_memory, persistent_workers=persistent_workers)
            else:
                domain_dataloaders = get_domain_dataloaders(train_df, seed=seed, batch_sizes=batch, img_path_cols=img_path_cols, transforms=transform_list, num_workers=num_workers, include_test=test_df, set_first_element_as_domain_label=scene_as_label, pin_memory=pin_memory, persistent_workers=persistent_workers)
            
            if joint_training:
                domain_dataloaders = pool_domain_dataloaders(domain_dataloaders)

            print(f"\nTesting: {name} Ablation: {ablation}")

            if ablation == 'nomask':
                setup['ablation'] = 'focus'
            elif ablation == 'onlysoc':
                setup['ablation'] = 'scene'
            elif ablation == 'onlyenv':
                setup['ablation'] = 'focus'
            else:
                setup['ablation'] = False

            if scene_as_label:
                setup['scene'] = 'label'
            dropout_rate=0.3
            model = DualBranchModel(dropout_rate=dropout_rate, setup=setup, branch_norm=branch_norm)
            dual_model = model.to(device)
            trainable_params = [p for p in dual_model.parameters() if p.requires_grad]
            lr=1e-3
            optimizer = torch.optim.Adam(trainable_params, lr=lr)
            buffer = NaiveRehearsalBuffer(buffer_size=buffer_size) if use_buffer else None

            epochs=epochs
            exp_name = f"{name}_{fold=}_{buffer_size=}_{epochs=}_{seed=}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
            
            scheduler=(get_linear_schedule_with_warmup, 0.05)
            refresh_optimiser=False

            dualbranch_kwargs = {
                    'mse_criterion': loss_fn #nn.MSELoss(),
                }

            config = {
                "model": {
                    "name": str(type(model)),
                    "setup": setup,
                    "branch_norm":branch_norm,
                    "dropout_rate":dropout_rate,
                },
                "buffer": str(type(buffer)),
                "buffer_size": buffer_size,
                "optimizer": str(type(optimizer)),
                "learning_rate": lr,
                "scheduler": {
                    "type": "transformers.get_linear_schedule_with_warmup",
                    "warmup": scheduler[1],
                },
                "device": str(device),
                "loss": str(dualbranch_kwargs['mse_criterion']),
                "joint_training": joint_training, #trained on pooled domains, not continual learning
                "seed": seed,
                "domains_order": domains,
                "train_val_df": train_val_path,
                "test_df": test_path,
                "hdf5_dataset_path": hdf5_dataset_path,
                "input_columns": img_path_cols,
                "input_transforms": [serialize_transform(x) for x in transform_list],
                "dataloader": {
                    "batch_size": batch,
                    "num_workers":num_workers,
                    "pin_memory": pin_memory,
                    "persistent_workers": persistent_workers,
                },
                "epochs": epochs,
                "early_stopping": {
                    "patience":15,
                    "delta":1e-3,
                },
                "gradient_clipping": grad_clipping,
                "refresh_optimiser": refresh_optimiser,
            }

            with open(f"../checkpoints/{exp_name}_config.json", "w") as f:
                json.dump(config, f, indent=4)

            unified_train_loop(
                model=dual_model,
                domains=domains if not joint_training else ['joint'],
                domain_dataloaders=domain_dataloaders,
                buffer=buffer,
                optimizer=optimizer,
                device=device,
                batch_fn=heuristic_dualbranch_batch,
                batch_kwargs=dualbranch_kwargs,
                num_epochs=epochs,
                exp_name=exp_name,
                gradient_clipping=grad_clipping,
                checkpoint_dir="../checkpoints",
                validation_set='val',
                scheduler=scheduler,
                refresh_optimiser=refresh_optimiser,
                early_stopping=earlystopping,
            )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")    

default_domains = ['Home', 'BigOffice-2', 'BigOffice-3', 'Hallway', 'MeetingRoom', 'SmallOffice']

testing_scenarios = {
    'silh.base': ('base', 60, 60, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, False, True, default_domains),
    'closeup.base': ('base', 60, 60, None, None, "../data/robotfocus128_pepper_data.hdf5", [get_transform((144,256), IMAGENET_NORM), get_transform((128,128), IMAGENET_NORM)], ['image_path_scene', 'image_path_focus_x2'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, False, True, default_domains),
    'order_complexup.base': ('base', 60, 60, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, False, True, ['Hallway', 'SmallOffice', 'MeetingRoom', 'BigOffice-3', 'BigOffice-2', 'Home']),
    'order_complexdown.base': ('base', 60, 60, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, False, True, ['Home', 'BigOffice-2', 'BigOffice-3', 'MeetingRoom', 'SmallOffice', 'Hallway']),
    'order_contrA.base': ('base', 60, 60, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, False, True, ['BigOffice-3', 'SmallOffice', 'Home', 'Hallway', 'MeetingRoom', 'BigOffice-2']),
    'order_contrB.base': ('base', 60, 60, None, None, "../data/mean_data_pepper.hdf5", [get_transform((144,256), IMAGENET_NORM)]*2, ['image_path_env_boxes_plus', 'image_path_soc'], False, nn.MSELoss(), {'branch':'mobilenetv2'}, False, True, ['MeetingRoom', 'Home', 'Hallway', 'BigOffice-2', 'SmallOffice', 'BigOffice-3']),
}
    
for name, (ablation, epochs, buffer_size, train_val_path, test_path, hdf5_path, transform_list, img_path_cols, scene_as_label, loss_fn, setup, joint_training, use_buffer, domains) in testing_scenarios.items():
        train_df = pd.read_pickle(train_val_path) if train_val_path is not None else None
        test_df = pd.read_pickle(test_path) if test_path is not None else None
        main_hdf5_dataset_path = hdf5_path
        setup=setup #{'branch':'mobilenetv2'}
        seed=42
        set_seed(seed)
        grad_clipping=True
        batch=(32, 64, 64)
        buffer_size=buffer_size
        branch_norm=True
        earlystopping=True
        epochs=epochs
        joint_training=joint_training
        scene_as_label=scene_as_label
        pin_memory=True
        persistent_workers=False
        num_workers=0
        use_buffer=use_buffer


        for fold in range(0,5):
            print(f"\nTesting fold: {fold}")

            hdf5_dataset_path = main_hdf5_dataset_path[:-5] + f'_fold{fold}.hdf5'

            if hdf5_path:
                domain_dataloaders = get_domain_dataloaders_from_hdf5(hdf5_path=hdf5_dataset_path, domains=domains, img_path_cols=img_path_cols, num_workers=num_workers, set_first_element_as_domain_label=scene_as_label, pin_memory=pin_memory, persistent_workers=persistent_workers)
            else:
                domain_dataloaders = get_domain_dataloaders(train_df, seed=seed, batch_sizes=batch, img_path_cols=img_path_cols, transforms=transform_list, num_workers=num_workers, include_test=test_df, set_first_element_as_domain_label=scene_as_label, pin_memory=pin_memory, persistent_workers=persistent_workers)
            
            if joint_training:
                domain_dataloaders = pool_domain_dataloaders(domain_dataloaders)

            print(f"\nTesting: {name} Ablation: {ablation}")

            if ablation == 'nomask':
                setup['ablation'] = 'focus'
            elif ablation == 'onlysoc':
                setup['ablation'] = 'scene'
            elif ablation == 'onlyenv':
                setup['ablation'] = 'focus'
            else:
                setup['ablation'] = False

            if scene_as_label:
                setup['scene'] = 'label'
            dropout_rate=0.3
            model = DualBranchModel(dropout_rate=dropout_rate, setup=setup, branch_norm=branch_norm)
            dual_model = model.to(device)
            trainable_params = [p for p in dual_model.parameters() if p.requires_grad]
            lr=1e-3
            optimizer = torch.optim.Adam(trainable_params, lr=lr)
            buffer = NaiveRehearsalBuffer(buffer_size=buffer_size) if use_buffer else None

            epochs=epochs
            exp_name = f"{name}_{fold=}_{buffer_size=}_{epochs=}_{seed=}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
            
            scheduler=(get_linear_schedule_with_warmup, 0.05)
            refresh_optimiser=False

            dualbranch_kwargs = {
                    'mse_criterion': loss_fn #nn.MSELoss(),
                }

            config = {
                "timestamp": datetime.datetime.now().strftime('%Y%m%d_%H%M%S'),
                "model": {
                    "name": str(type(model)),
                    "setup": setup,
                    "branch_norm":branch_norm,
                    "dropout_rate":dropout_rate,
                },
                "buffer": str(type(buffer)),
                "buffer_size": buffer_size,
                "optimizer": str(type(optimizer)),
                "learning_rate": lr,
                "scheduler": {
                    "type": "transformers.get_linear_schedule_with_warmup",
                    "warmup": scheduler[1],
                },
                "device": str(device),
                "loss": str(dualbranch_kwargs['mse_criterion']),
                "joint_training": joint_training, #trained on pooled domains, not continual learning
                "seed": seed,
                "domains_order": domains,
                "train_val_df": train_val_path,
                "test_df": test_path,
                "hdf5_dataset_path": hdf5_dataset_path,
                "input_columns": img_path_cols,
                "input_transforms": [serialize_transform(x) for x in transform_list],
                "dataloader": {
                    "batch_size": batch,
                    "num_workers":num_workers,
                    "pin_memory": pin_memory,
                    "persistent_workers": persistent_workers,
                },
                "epochs": epochs,
                "early_stopping": {
                    "patience":15,
                    "delta":1e-3,
                },
                "gradient_clipping": grad_clipping,
                "refresh_optimiser": refresh_optimiser,
            }

            with open(f"../checkpoints/{exp_name}_config.json", "w") as f:
                json.dump(config, f, indent=4)

            unified_train_loop(
                model=dual_model,
                domains=domains if not joint_training else ['joint'],
                domain_dataloaders=domain_dataloaders,
                buffer=buffer,
                optimizer=optimizer,
                device=device,
                batch_fn=heuristic_dualbranch_batch,
                batch_kwargs=dualbranch_kwargs,
                num_epochs=epochs,
                exp_name=exp_name,
                gradient_clipping=grad_clipping,
                checkpoint_dir="../checkpoints",
                validation_set='val',
                scheduler=scheduler,
                refresh_optimiser=refresh_optimiser,
                early_stopping=earlystopping,
            )
